# %% [markdown]
# #Homework 8 (10 pt)
# <font color=red>**Danger zone:**</font> you'll be fine-tuning a model to generate positive, negative or even toxic reviews. We'll be doing this for fun, but this is also the technique for [review bombing](https://en.wikipedia.org/wiki/Review_bomb), bot farms on social media and other less than dignified stuff. It is ultimately your decision how you apply this knowledge, but before you choose, ask yourself: is this why you chose to learn ML?
#
#
# # LLMs Alignment with Reinforcement Learning from human feedback (RLHF).
#
# _based on the [notebook](https://github.com/yandexdataschool/nlp_course/blob/2024/week08_rlhf/practice.ipynb) based the [original notebook](https://github.com/antndlcrx/oxford-llms-workshop/blob/main/materials/seminars/day_3/8_LLMs%20alignment%20with%20RLHF.ipynb) by Ilya Boytsov for the Oxford LLMs workshop_

# %% [markdown]
# In this session, you're gonna fine-tune a language model with reinforcement learning to make it generate good (or bad) reviews.
#
# To perform RL-based fine-tuning, we'll use a new (in this course) library called [Transformer Reinforcement Learning (TRL)](https://huggingface.co/docs/trl). TRL implements the main reinforcement learning components of RLHF: reward modeling and fine-tuning with PPO.
#
# ![img](https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/TRL-readme.png)

# %%
# !pip install --quiet --upgrade transformers trl peft
#datasets-3.4.1 peft-0.15.0 transformers-4.50.1 trl-0.16.0 xxhash-3.5.0
# In the original notebook
# %pip install -q trl==0.7.4 transformers==4.33.1 datasets==2.14.4 peft==0.5.0

# %% [markdown]
# ### Tutorial: align the model to generate positive movie reviews
#
# To see how TRL works, we'll use it to align GPT2 on IMDB dataset to generate positive (or negative) movie reviews. In fact, __it's your choice whether you want positive or negative reviews.__
#
# But before you choose, let's take a look at the baseline model: a GPT-2 fine-tuned on generating arbitrary movie reviews.

# %%
import torch
import transformers
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_model = transformers.AutoModelForCausalLM.from_pretrained("lvwerra/gpt2-imdb", device_map=device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
inputs = main_tokenizer("The movie", return_tensors='pt').to(device)
generated_ids = main_model.generate(**inputs, max_new_tokens=50, do_sample=True)
print("\nGenerated text:", main_tokenizer.decode(generated_ids.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Generated text: The movie could have been much, much better made with just as much acting and actors as this. I highly recommend to watch this one for that reason alone.<|endoftext|>

# %% [markdown]
# If you run this cell a couple of times, you'll see that the model generates both positive, negative and neutral reviews in some proportion. What we're gonna do next is teach the model to generate more positive (or negative) reviews.
#
# Similarly to InstructGPT, we're gonna do that in 2 stages:
# - **train a reward model** to assign higher values to positive (or negative) reviews
# - fine-tune the language model to **maximize that reward using [proximal policy optimization](https://openai.com/research/openai-baselines-ppo)**

# %% [markdown]
# ## Stage 1: train a reward model (2 points)
#
# First, we'll train a BERT-like model as our reward model. We'll generate a synthetic pairwise rankings to emulate human rankings.
#
# __Q:__ why do I need a reward model? Can I just use a pre-trained sentiment classifier? <br> __A:__ Yes, you can - but that only works for movie reviews. But this tutorial will teach you how to do RLHF for any kind objective.
#
#
# __If you actually want to maximize sentiment (or other "label") instead of human preferences, train reward model as a classifier! (see week5)__

# %%
# We'll be fine-tuning a small BERT-like model for now. Please try other models for the main assignment.
reward_model = transformers.AutoModelForSequenceClassification.from_pretrained("distilbert-base-cased", device_map=device)
reward_tokenizer = transformers.AutoTokenizer.from_pretrained("distilbert-base-cased")
# Out:
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %% [markdown]
# __Note that__ the reward model has a separate tokenizer, different from the main model. They don't need to be the same for RLHF fine-tuning.

# %%
# To train a reward model, you need a dataset (or generator) of positive-negative pairs.
# Each training sample should be a dict with 4 keys:
#  - input_ids_chosen, attention_mask_chosen = tokenizer("A sentence that human labeler likes more")
#  - input_ids_rejected, attention_mask_rejected = tokenizer("A sentence that human labeler likes less")

#import torch
import datasets

class IMDBPairwiseDataset(torch.utils.data.Dataset):
    """ A dataset of all possible pairs of chosen and rejected texts in TRT reward training format """
    def __init__(self, imdb, tokenizer, accepted_label: int):
        super().__init__()
        self.tokenizer = tokenizer
        self.chosen_texts = [row['text'] for row in imdb if row['label'] == accepted_label]
        self.rejected_texts = [row['text'] for row in imdb if row['label'] != accepted_label]

        assert self.chosen_texts, f"no texts with label {accepted_label}"

        print(f"Found {len(self.chosen_texts)} chosen and {len(self.rejected_texts)} rejected texts, {len(self)} pairs")

        # Add column_names attribute for compatibility
        self.column_names = [
            "input_ids_chosen",
            "attention_mask_chosen",
            "input_ids_rejected",
            "attention_mask_rejected"
        ]

    def __len__(self):
        return len(self.chosen_texts) * len(self.rejected_texts)

    def __getitem__(self, index: int):
        chosen = self.tokenizer(
            self.chosen_texts[index // len(self.chosen_texts)],
            truncation=True,
            padding="max_length",
            max_length=512,
            return_tensors="pt"
        )

        rejected = self.tokenizer(
            self.rejected_texts[index % len(self.rejected_texts)],
            truncation=True,
            padding="max_length",
            max_length=512,
            return_tensors="pt"
        )

        return {
            "input_ids_chosen": chosen["input_ids"].squeeze(),
            "attention_mask_chosen": chosen["attention_mask"].squeeze(),
            "input_ids_rejected": rejected["input_ids"].squeeze(),
            "attention_mask_rejected": rejected["attention_mask"].squeeze(),
        }

# %%
TARGET_LABEL = 1 #<YOUR CHOICE - either 0 or 1>   # and make sure it works by reviewing the sample printed below
imdb = datasets.load_dataset("imdb", split='train')
reward_data = IMDBPairwiseDataset(imdb, reward_tokenizer, accepted_label=TARGET_LABEL)

sample = reward_data[31337]
print('CHOSEN:', reward_tokenizer.decode(sample['input_ids_chosen']))
print('REJECTED:', reward_tokenizer.decode(sample['input_ids_rejected']))
# Out:
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Found 12500 chosen and 12500 rejected texts, 156250000 pairs
# CHOSEN: [CLS] Lars Von Trier is never backward in trying out new techniques. Some of them are very original while others are best forgotten. < br / > < br / > He depicts postwar Germany as a nightmarish train journey. With so many cities lying in ruins, Leo Kessler a young American of German descent feels obliged to help in their restoration. It is not a simple task as he quickly finds out. < br / > < br / > His uncle finds him a job as a night conductor on the Zentropa Railway Line. His job is to attend to the needs of the passengers. When the shoes are polished a chalk mark is made on the soles. A terrible argument ensues when a passenger ' s shoes are not chalked despite the fact they have been polished. There are many allusions to the German fanaticism of adherence to such stupid details. < br / > < br / > The railway journey is like an allegory representing man ' s procession through life with all its trials and tribulations. In one sequence Leo dashes through the back carriages to discover them filled with half - starved bodies appearing to have just escaped from Auschwitz. These images, horrible as they are, are fleeting as in a dream, each with its own terrible impact yet unconnected. < br / > < br / > At a station called Urmitz Leo jumps from the train with a parceled bomb. In view of many by - standers he connects the bomb to the underside of a carriage. He returns to his cabin and makes a connection to a time clock. Later he jumps from the train ( at high speed ) and lies in the cool grass on a river bank. Looking at the stars above he decides that his job is to build and not destroy. Subsequently as he sees the train approaching a giant bridge he runs at breakneck speed to board the train and stop the clock. If you care to analyse the situation it is a completely impossible task. Quite ridiculous in fact. It could only happen in a dream. < br / > < br / > It ' s strange how one remembers little details such as a row of cups hanging on hooks and rattling away with the swaying of the train. < br / > < br / > Despite the fact that this film is widely acclaimed, I prefer Lars Von Trier ' s later films ( Breaking the Waves and The Idiots ). The bomb scene described above really put me off. Perhaps I ' m a [SEP]
# REJECTED: [CLS] I saw this movie in 1979, I was 17 or 18, when it was released. The theater was perhaps 1 / 4 full when the movie started. Ten minutes into the movie me and the friend who went with me to see the film were the only two people in the theater. The movie was really weird and had no plot or reason to its script and people demanded their money back. We decided to stay for the ENTIRE movie.... why endure such torture??... here ' s why. We wanted to be true movie critics... to have a standard to base all other movies on it is hard to justify saying you have seen the best movie ( a 10 ) they always come up with something better. But, it is easy to be able to base all other movies off of the worst movie ever made ( and this is it... a 1 at best ). There may be other movies out there that truly qualify as a 1, but I have yet to see them. I now base all movies I see on a scale based on this worst.... I AM A TRUE MOVIE CRITIC... he he. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %% [markdown]
# We'll be using `trl.RewardTrainer` - a special case of `transformers.Trainer` that you used in the past. `RewardTrainer` accepts the same format of training arguments (e.g. batch size, gradient checkpointing) as before, except that it trains the model for the pairwise reward objective from [the InstructGPT paper](https://arxiv.org/pdf/2203.02155.pdf):
#
# ![img](https://i.imgur.com/2JzNAPs.png)
#
# Note that the model itself does not score pairs: it processes chosen ($y_w$) and rejected ($y_l$) samples independently. To minimize this loss, the reward model needs to score chosen sample higher than the rejected one. Note that the formula also assumes some context $x$, which is useful for seq2seq tasks. In our case of movie reviews, $x$ is empty.

# %%
import datasets
from trl import RewardTrainer, RewardConfig
from transformers import DataCollatorWithPadding

# Define Dataset Class
class IMDBPairwiseDataset(torch.utils.data.Dataset):
    """ Creates a dataset of paired (chosen, rejected) texts for reward training. """
    def __init__(self, imdb, tokenizer, accepted_label: int):
        super().__init__()
        self.tokenizer = tokenizer
        self.chosen_texts = [row['text'] for row in imdb if row['label'] == accepted_label]
        self.rejected_texts = [row['text'] for row in imdb if row['label'] != accepted_label]

        assert self.chosen_texts, f"no texts with label {accepted_label}"
        print(f"Found {len(self.chosen_texts)} chosen and {len(self.rejected_texts)} rejected texts, {len(self)} pairs")

        # Add column_names attribute for RewardTrainer compatibility
        self.column_names = [
            "input_ids_chosen",
            "attention_mask_chosen",
            "input_ids_rejected",
            "attention_mask_rejected"
        ]

    def __len__(self):
        return min(len(self.chosen_texts), len(self.rejected_texts))

    def __getitem__(self, index: int):
        chosen_text = self.chosen_texts[index % len(self.chosen_texts)]
        rejected_text = self.rejected_texts[index % len(self.rejected_texts)]

        chosen_tokenized = self.tokenizer(chosen_text, truncation=True, padding="max_length", max_length=512, return_tensors="pt")
        rejected_tokenized = self.tokenizer(rejected_text, truncation=True, padding="max_length", max_length=512, return_tensors="pt")

        return {
            "input_ids_chosen": chosen_tokenized["input_ids"].squeeze(),
            "attention_mask_chosen": chosen_tokenized["attention_mask"].squeeze(),
            "input_ids_rejected": rejected_tokenized["input_ids"].squeeze(),
            "attention_mask_rejected": rejected_tokenized["attention_mask"].squeeze(),
        }

# Create Dataset
TARGET_LABEL = 1  # Change to 0 for negative reviews
reward_data = IMDBPairwiseDataset(imdb, reward_tokenizer, accepted_label=TARGET_LABEL)
# Sample check
sample = reward_data[31337]
print('CHOSEN:', reward_tokenizer.decode(sample['input_ids_chosen']))
print('REJECTED:', reward_tokenizer.decode(sample['input_ids_rejected']))
# Out:
# Found 12500 chosen and 12500 rejected texts, 12500 pairs
# CHOSEN: [CLS] This movie has some things that are pretty amazing. First, it is supposed to be based on a true story. That, in itself, is amazing that multiple tornadoes would hit the same town at night in the fall - in Nebraska. I wonder if the real town ' s name was close to " Blainsworth " ( which is the town ' s name in the movie ). There is an Ainsworth, Nebraska, but there is also a town that starts with Blains - something. < br / > < br / > It does show the slowest moving tornadoes on record in the the seen where the boys are in the house. On the other hand, the scene where the TV goes fuzzy is based in fact. Before Doppler radar and weather radio, we were taught that if you turned your TV to a particular channel ( not on cable ) and tuned the brightness just right, you could tell if there was a tornado coming. The problem was that by then you would be able to hear it. < br / > < br / > Since I know something about midwest tornadoes, it made this movie fun for me. I enjoy it more than Twister. I mean, give me a break - there is no way you could make it through and F5 by chaining yourself to a pipe in a well house. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# REJECTED: [CLS] I saw this movie in 1979, I was 17 or 18, when it was released. The theater was perhaps 1 / 4 full when the movie started. Ten minutes into the movie me and the friend who went with me to see the film were the only two people in the theater. The movie was really weird and had no plot or reason to its script and people demanded their money back. We decided to stay for the ENTIRE movie.... why endure such torture??... here ' s why. We wanted to be true movie critics... to have a standard to base all other movies on it is hard to justify saying you have seen the best movie ( a 10 ) they always come up with something better. But, it is easy to be able to base all other movies off of the worst movie ever made ( and this is it... a 1 at best ). There may be other movies out there that truly qualify as a 1, but I have yet to see them. I now base all movies I see on a scale based on this worst.... I AM A TRUE MOVIE CRITIC... he he. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %%
# Define Data Collator (Handles Padding)
class RewardDataCollator:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer
        self.default_collator = DataCollatorWithPadding(tokenizer)

    def __call__(self, batch):
        batch_chosen = [{"input_ids": ex["input_ids_chosen"], "attention_mask": ex["attention_mask_chosen"]} for ex in batch]
        batch_rejected = [{"input_ids": ex["input_ids_rejected"], "attention_mask": ex["attention_mask_rejected"]} for ex in batch]

        collated_chosen = self.default_collator(batch_chosen)
        collated_rejected = self.default_collator(batch_rejected)

        return {
            "input_ids_chosen": collated_chosen["input_ids"],
            "attention_mask_chosen": collated_chosen["attention_mask"],
            "input_ids_rejected": collated_rejected["input_ids"],
            "attention_mask_rejected": collated_rejected["attention_mask"],
        }

data_collator = RewardDataCollator(reward_tokenizer)

# Define Training Arguments
training_args = RewardConfig(
    output_dir="reward_model",
    remove_unused_columns=False,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=2,
    learning_rate=1e-5,
    max_steps=1000,
    logging_steps=50,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    fp16=True if torch.cuda.is_available() else False,
    report_to="none"
)

# Train the Reward Model
trainer = RewardTrainer(
    model=reward_model,
    args=training_args,
    train_dataset=reward_data,
    data_collator=data_collator,  # Use custom collator instead of RewardDataProcessor
    peft_config=None
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 09:04, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.559900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.194400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.143700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.122300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.091000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.110100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.108000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.079400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.061100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.063500</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.047500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.058400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.060600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.045900</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.036300</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.044000</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.027500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.028700</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.036200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.028300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1000, training_loss=0.09733659958839416, metrics={'train_runtime': 545.2964, 'train_samples_per_second': 58.684, 'train_steps_per_second': 1.834, 'total_flos': 0.0, 'train_loss': 0.09733659958839416, 'epoch': 2.557544757033248})

# %%
reward_model.gradient_checkpointing_disable()
reward_model.eval()
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0, inplace=False)
# )

# %% [markdown]
# ### Sanity-check the reward model (1 point)
#
# Let's check how our reward model performs.
#
# __Your task__ is to measure how often does your reward model can rank a pair of (chosen and rejected) reviews correctly. Please measure this separately for train data (`imdb`) and a separate test set loaded below.

# %%
for sample_index in 45, 16000:
  print('TEXT:', imdb[sample_index]['text'])
  inputs = reward_tokenizer(
      imdb[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
  with torch.no_grad():
    reward = reward_model(**inputs).logits[0, 0].item()
    print("REWARD:", reward)
  print('LABEL:', imdb[sample_index]['label'])
  print()
# Out:
# TEXT: This movie sucked. It really was a waste of my life. The acting was atrocious, the plot completely implausible. Long, long story short, these people get "terrorized" by this pathetic "crazed killer", but completely fail to fight back in any manner. And this is after they take a raft on a camping trip, with no gear, and show up at a campsite that is already assembled and completely stocked with food and clothes and the daughters headphones. Additionally, after their boat goes missing, they panic that they're stuck in the woods, but then the daughters boyfriend just shows up and they apparently never consider that they could just hike out of the woods like he did to get to them. Like I said, this movie sucks. A complete joke. Don't let your girlfriend talk you into watching it.
# REWARD: -5.015625
# LABEL: 0
#
# TEXT: Good: Engaging cinematic firefights, great presentation, vehicles are actually fun to drive, fairly appealing multiplayer, faithful to the movie, and the list goes on.<br /><br />Bad: Main missions are a bit short.<br /><br />This game defines what a "good" third person shooter(not necessarily a spy-game) is. Great firefights carry on the story and make you want to complete EVERY single mission through, and unlock all the genuine bonuses the game has to offer. The hype this game had, was lived up to, and I personally think you should buy it, and hook up with a couple of friends and play this one. Loads of fun. <br /><br />The sound in this game, is a rip-roaring achievement from a few previous bond games, and firing a weapon, really feels like you're firing a weapon. It ties in with the aspect that you are a deadly and ruthless spy.<br /><br />All in all, this game makes you excited and satisfied after you make it through, and some multiplayer that can compete with the standards of the crafty James Bond "Nightfire" game for gamecube.
# REWARD: 4.87109375
# LABEL: 1

# %%
imdb_test = datasets.load_dataset("imdb", split='test')

# %%
imdb_test[24999]
# Out:
# {'text': 'I caught this movie on the Sci-Fi channel recently. It actually turned out to be pretty decent as far as B-list horror/suspense films go. Two guys (one naive and one loud mouthed a**) take a road trip to stop a wedding but have the worst possible luck when a maniac in a freaky, make-shift tank/truck hybrid decides to play cat-and-mouse with them. Things are further complicated when they pick up a ridiculously whorish hitchhiker. What makes this film unique is that the combination of comedy and terror actually work in this movie, unlike so many others. The two guys are likable enough and there are some good chase/suspense scenes. Nice pacing and comic timing make this movie more than passable for the horror/slasher buff. Definitely worth checking out.',
#  'label': 1}

# %%
correct_predictions = 0
for sample_index in range(len(imdb_test)):
  inputs = reward_tokenizer(
      imdb_test[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
  with torch.no_grad():
    reward = reward_model(**inputs).logits[0, 0].item()
#     print(reward, imdb_test[sample_index]['label'])
    if (reward < 0 and imdb_test[sample_index]['label'] == 0) or (reward >= 0 and imdb_test[sample_index]['label'] == 1):
        correct_predictions += 1
print('Accuracy on imdb_test = ', correct_predictions / len(imdb_test))
# Out:
# Accuracy on imdb_test =  0.91444

# %%
correct_predictions = 0
for sample_index in range(len(imdb)):
    inputs = reward_tokenizer(
      imdb[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
        reward = reward_model(**inputs).logits[0, 0].item()
        if (reward < 0 and imdb[sample_index]['label'] == 0) or (reward >= 0 and imdb[sample_index]['label'] == 1):
            correct_predictions += 1
print('Accuracy on imdb_train = ', correct_predictions / len(imdb))
# Out:
# Accuracy on imdb_train =  0.93612

# %% [markdown]
# ### Reward-guided generation (8 points)
#
# If you did everything right, by now you should have a decent reward model. Before we use it for reinforcement learning, let's see if we can align model samples without any training.
#
# To do so, you can use reward-guided inference: __generate N=16 samples, then select the one with the highest reward__ (according to your reward model).
#
# For this problem, it's on you to demonstrate whether or not your code works. Find at least 5 neutral prompts such as "This movie is" (...), "It was" (...), "I'd like to say", generate samples, rank them based on reward and show which samples get the highest reward.
#
# Note: it is faster to generate samples in parallel, rather than sequentially, as follows:

# %%
inputs = main_tokenizer(["It was"] * 5, return_tensors='pt').to(device)
for candidate in main_model.generate(**inputs, max_new_tokens=50, do_sample=True):
    print("Sample:", main_tokenizer.decode(candidate.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample: It was interesting seeing the same team from the previous year as they had the same problems.<br /><br />This was the first time I felt this much sympathy for them. Then again you get the drift of the series. The series is so predictable and
# Sample: It was like sitting around with the dog - the dog walked around, ran, and never came back. When we finally came back to the house, I was so scared we didn't even know what to do." She remembers this as someone who tried repeatedly in
# Sample: It was supposed to be the story (about a beautiful young woman who kills herself for no apparent reason, etc.) but it wasn't in the actual movie, nor the story. Just in my opinion the best thing about the movie is that it didn't really
# Sample: It was too much for me after I read the reviews, and what I have to say is, that the movie was a good idea - and actually it got a lot of "comparable" movies on a level. But overall, the movie is too dull
# Sample: It was good that the movie was based on actual facts. I guess the truth is, the actual fact that everyone in North America was white at the time is nothing new. But if you don't know something about the story or can't see it coming,

# %%
# <YOUR CODE HERE>
prompts = ["It was", "I think that", "To be honest", "In my opinion", "I believe that", "When I saw this movie", "I would say that", "This movie was", ]
prompt_dict = {}

# %%
for prompt in prompts:
  print(prompt)
  prompt_dict[prompt] = {"generated_text": [], "rewards": {}}
  inputs = main_tokenizer([prompt] * 16, return_tensors='pt').to(device)
  generated_ids = main_model.generate(**inputs, max_new_tokens=50, do_sample=True)
  for candidate in generated_ids:
    generated_text = main_tokenizer.decode(candidate.flatten().cpu().numpy().tolist())
    prompt_dict[prompt]["generated_text"].append(generated_text)
  prompt_dict[prompt]["rewards"] = {}
  for t in prompt_dict[prompt]["generated_text"]:
    inputs = reward_tokenizer(
        t, truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
      reward = reward_model(**inputs).logits[0, 0].item()
      prompt_dict[prompt]["rewards"][t] = reward
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# It was
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I think that
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# To be honest
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# In my opinion
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I believe that
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# When I saw this movie
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I would say that
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# This movie was

# %%
prompt_dict
# Out:
# {'It was': {'generated_text': ["It was one of the funniest shows I've ever seen. The show was totally original, funny, and unique. I thought that was the way it was going to be.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    'It was a mistake.<br /><br />I think this was a good idea.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    'It was like watching a silent movie and then the camera moves again..<br /><br />The "hero" is so evil that his evil personality just keeps getting lost. He really is a monster and is the real face of death. He is just',
#    "It was very good to see the actors playing people who had not seen the previous two film and didn't have the chance to watch the first one. This film would have been a lot better if the actors had done better. A movie I wish I could still",
#    "It was one of those weird romantic comedies that made me want to cry.<br /><br />But here, I've got a different viewpoint.<br /><br />As any good romantic comedy in film history would, this one would have probably had",
#    'It was just so bad, that you can see my heart sinking.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    "It was, as I recall, the first film I ever saw, which was on BBC2, and it was not well liked on DVD (I can't believe he died). I did find it quite cool (almost like a documentary) so I did what",
#    'It was very interesting as far as sex, but not for the slightest bit of sex. The scene was not really good, but when we got to the middle section of it, it was just plain horrible. The scene where a girl is shot and then left',
#    "It was definitely a work of art, and I was very happy that I was able to see it when I went in. (It looks like I taped it to the big wall at my school library.) It's hard to believe it was made, and I",
#    'It was so funny, too. There are some great quotes from the first episode, and I just laughed as a teenager.<br /><br />Then, in the final episode of Buffy And The Beast, the villain dies and gets revenge on Buffy, who',
#    "It was quite entertaining and the script was very good too, which made up the bulk of the film's appeal.<br /><br />This film doesn't need a story, but it does have great acting & performances from the cast.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    "It was always one of the first horror films, so one can't discount all these great directors like Mr. Roddy McDowall as the chief horror film maker.<br /><br />But I was right. There is a lot to do. I",
#    "It was funny. It was really stupid. Not funny for many reasons.<br /><br />In the beginning it just seemed like a straight forward thriller but that was after the first scene in the beginning was stupid really I'm afraid. It just kind of",
#    "It was very well scripted but some plot development wasn't as prominent. However, I feel this film is well worth watching. I believe it really will have a very positive impact on everyone on the planet.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    "It was a waste of ten minutes of time and money that you really paid to watch this crap. I'm not really sure if you are an avid follower of the occult or a critic. No one should have to go out of their way to see this,",
#    'It was the best movie I ever saw. This is one thing that was overlooked in this movie: the plot just was a bit too much for my liking, even over the course of 2 hrs: "The Godfather" and "The Amazing Hulk."<'],
#   'rewards': {"It was one of the funniest shows I've ever seen. The show was totally original, funny, and unique. I thought that was the way it was going to be.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": 4.25390625,
#    'It was a mistake.<br /><br />I think this was a good idea.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': -1.5478515625,
#    'It was like watching a silent movie and then the camera moves again..<br /><br />The "hero" is so evil that his evil personality just keeps getting lost. He really is a monster and is the real face of death. He is just': -2.736328125,
#    "It was very good to see the actors playing people who had not seen the previous two film and didn't have the chance to watch the first one. This film would have been a lot better if the actors had done better. A movie I wish I could still": 4.15234375,
#    "It was one of those weird romantic comedies that made me want to cry.<br /><br />But here, I've got a different viewpoint.<br /><br />As any good romantic comedy in film history would, this one would have probably had": -0.94580078125,
#    'It was just so bad, that you can see my heart sinking.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': -2.34375,
#    "It was, as I recall, the first film I ever saw, which was on BBC2, and it was not well liked on DVD (I can't believe he died). I did find it quite cool (almost like a documentary) so I did what": 1.8662109375,
#    'It was very interesting as far as sex, but not for the slightest bit of sex. The scene was not really good, but when we got to the middle section of it, it was just plain horrible. The scene where a girl is shot and then left': -4.484375,
#    "It was definitely a work of art, and I was very happy that I was able to see it when I went in. (It looks like I taped it to the big wall at my school library.) It's hard to believe it was made, and I": 3.810546875,
#    'It was so funny, too. There are some great quotes from the first episode, and I just laughed as a teenager.<br /><br />Then, in the final episode of Buffy And The Beast, the villain dies and gets revenge on Buffy, who': 2.896484375,
#    "It was quite entertaining and the script was very good too, which made up the bulk of the film's appeal.<br /><br />This film doesn't need a story, but it does have great acting & performances from the cast.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>": 4.43359375,
#    "It was always one of the first horror films, so one can't discount all these great directors like Mr. Roddy McDowall as the chief horror film maker.<br /><br />But I was right. There is a lot to do. I": 2.30078125,
#    "It was funny. It was really stupid. Not funny for many reasons.<br /><br />In the beginning it just seemed like a straight forward thriller but that was after the first scene in the beginning was stupid really I'm afraid. It just kind of": -3.677734375,
#    "It was very well scripted but some plot development wasn't as prominent. However, I feel this film is well worth watching. I believe it really will have a very positive impact on everyone on the planet.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": 4.3671875,
#    "It was a waste of ten minutes of time and money that you really paid to watch this crap. I'm not really sure if you are an avid follower of the occult or a critic. No one should have to go out of their way to see this,": -4.3359375,
#    'It was the best movie I ever saw. This is one thing that was overlooked in this movie: the plot just was a bit too much for my liking, even over the course of 2 hrs: "The Godfather" and "The Amazing Hulk."<': 2.66015625}},
#  'I think that': {'generated_text': ["I think that you have to work, to be successful. You have to be, especially as a performer. I would not take the advice from other people that he wants to act like a play in a big movie. He says he wants to be. That's",
#    'I think that he could have done a wonderful job, and that his character would have had been appreciated by the viewer. He was well done, and the story would have been very interesting. I think we should not miss anything in the movie, especially the ending.',
#    'I think that this is a good opportunity for the future of TV shows, especially if you have grown up in the 80s.<br /><br />I found it odd that the writers are apparently trying to make fun of those who have seen some of its most',
#    'I think that this film is not a good film, I don\'t see it being made in the same way as "The Dark Knight of Death." However, the film I think is the best ever made in its time. I don\'t think this film will ever',
#    'I think that is the best way to go." <br /><br />In an interview with Vanity Fair, he described the scene in the theater with one of his "friends." He said: "I saw this scene at the theater, and I thought,',
#    'I think that was a mistake...<br /><br />There were two movies that I actually liked: "Little Dragon" and "The Wolf\'s Castle". The first was a very low budget horror that was directed by the same one, by the same company',
#    'I think that this was the best thing that came out of the show, no matter how bad it may have been, and that if we are going to have a good one then we need to make it better. There is something very charming about them. They have',
#    "I think that by having these types of characters in the film, this film just isn't good, in any way. The first half of the film is just a bunch of actors, each with their own personality, and it takes some sort of a self-cent",
#    "I think that this film is actually quite good. It takes its time, to get to the 'points'. I found that the film has a few interesting moments.<br /><br />The music is definitely not the biggest part. The acting is good enough that",
#    'I think that there is also a difference between how the two films feel about each other. What is most interesting about this film from a technical point of view is that it is based on a real story that is told in close to realtime, not in a dream',
#    'I think that every good writer of fiction should see a story.<br /><br />I saw this series the same night in Chicago by the library. I saw it at the same time the next day, and found that I loved it. It is well written',
#    "I think that is what they really wanted the film to be.<br /><br />The most important thing he's done is make it a movie of the old world; he never forgot the old world.<br /><br />But I'm a sucker for",
#    'I think that director/writer John Carradine does a great job capturing the feel of a life in an urban setting where everything seems relatively "normal". The story is also written to build suspense, with the most memorable scenes from the film being at the end when',
#    "I think that, for a man of only 15, Mr. Lautner might be called to the role, but I'm sure there are a great many roles available! The director certainly did good enough work to showcase the range of personalities at work in this fine",
#    'I think that there\'s a connection but the film seems to have some very obvious holes in it.<br /><br />It\'s funny how you don\'t ever think that\'s the case or that\'s the case... if you watch it you\'re thinking, "',
#    "I think that that, in all fairness, the plot wasn't great and that it didn't carry the mood so well as it should have. The characters were pretty simple, like what they could be expected to be if they weren't involved with what was happening on"],
#   'rewards': {"I think that you have to work, to be successful. You have to be, especially as a performer. I would not take the advice from other people that he wants to act like a play in a big movie. He says he wants to be. That's": 0.95654296875,
#    'I think that he could have done a wonderful job, and that his character would have had been appreciated by the viewer. He was well done, and the story would have been very interesting. I think we should not miss anything in the movie, especially the ending.': 4.23828125,
#    'I think that this is a good opportunity for the future of TV shows, especially if you have grown up in the 80s.<br /><br />I found it odd that the writers are apparently trying to make fun of those who have seen some of its most': 0.09881591796875,
#    'I think that this film is not a good film, I don\'t see it being made in the same way as "The Dark Knight of Death." However, the film I think is the best ever made in its time. I don\'t think this film will ever': 2.783203125,
#    'I think that is the best way to go." <br /><br />In an interview with Vanity Fair, he described the scene in the theater with one of his "friends." He said: "I saw this scene at the theater, and I thought,': 2.662109375,
#    'I think that was a mistake...<br /><br />There were two movies that I actually liked: "Little Dragon" and "The Wolf\'s Castle". The first was a very low budget horror that was directed by the same one, by the same company': -3.06640625,
#    'I think that this was the best thing that came out of the show, no matter how bad it may have been, and that if we are going to have a good one then we need to make it better. There is something very charming about them. They have': 3.435546875,
#    "I think that by having these types of characters in the film, this film just isn't good, in any way. The first half of the film is just a bunch of actors, each with their own personality, and it takes some sort of a self-cent": -4.29296875,
#    "I think that this film is actually quite good. It takes its time, to get to the 'points'. I found that the film has a few interesting moments.<br /><br />The music is definitely not the biggest part. The acting is good enough that": 4.109375,
#    'I think that there is also a difference between how the two films feel about each other. What is most interesting about this film from a technical point of view is that it is based on a real story that is told in close to realtime, not in a dream': 2.88671875,
#    'I think that every good writer of fiction should see a story.<br /><br />I saw this series the same night in Chicago by the library. I saw it at the same time the next day, and found that I loved it. It is well written': 4.8515625,
#    "I think that is what they really wanted the film to be.<br /><br />The most important thing he's done is make it a movie of the old world; he never forgot the old world.<br /><br />But I'm a sucker for": -3.640625,
#    'I think that director/writer John Carradine does a great job capturing the feel of a life in an urban setting where everything seems relatively "normal". The story is also written to build suspense, with the most memorable scenes from the film being at the end when': 3.71484375,
#    "I think that, for a man of only 15, Mr. Lautner might be called to the role, but I'm sure there are a great many roles available! The director certainly did good enough work to showcase the range of personalities at work in this fine": 4.3046875,
#    'I think that there\'s a connection but the film seems to have some very obvious holes in it.<br /><br />It\'s funny how you don\'t ever think that\'s the case or that\'s the case... if you watch it you\'re thinking, "': -0.3193359375,
#    "I think that that, in all fairness, the plot wasn't great and that it didn't carry the mood so well as it should have. The characters were pretty simple, like what they could be expected to be if they weren't involved with what was happening on": -2.275390625}},
#  'To be honest': {'generated_text': ['To be honest I wasn\'t quite as impressed by "Escape to the Deep", but I do have to say that the story is brilliant and worth exploring. There are a few things that made me cringe, but this isn\'t one of them. For starters,',
#    'To be honest here, there wasn\'t enough good ideas going, and the ending was way too anticlimactic. <br /><br />It\'s an interesting movie. It\'s not like another "Black Moon" where the plot got in the way. And',
#    'To be honest, I didn\'t care what anyone was talking about! The best part about "The One" is how it was filmed. The whole scene was totally unnecessary and I hate to be associated with people who can make fun of movies for the sake of it',
#    'To be honest, though, after watching this it had absolutely nothing to do with the film. The production values were terrible. There was probably an under-researched script, too many scenes that were not clear-cut enough, bad direction, unrealistic pacing',
#    "To be honest, my love for this movie is not as strong or fresh as it sounds. There's some cool special effects and some very nice photography/shot editing. I'm not sure how important its role is, but the movie certainly made a statement for the",
#    'To be honest I\'m sure they could\'ve kept this film and brought it back in the box, i\'m also glad that I bought it now. I was really looking forward to seeing it, but it really seemed too "cute", and it turned out a',
#    "To be honest with you, the second half of this film is one of cinema's greatest moments. The best moments in the film are at the funeral for the victims of the first war. The film opens with an ending that is like a film of old. The",
#    "To be honest, I loved and appreciated what they were doing at the time and I'll never forget them.<br /><br />I loved the acting, the dialogue and they were able to put them on stage that really touched me. If there's one thing",
#    "To be honest: The plot is awful, and as such is not worth your time. I wish I'd have known what all the fuss was about before the film. I'll watch it once. Thank you for coming to see this wonderful film.<|endoftext|><|endoftext|><|endoftext|>",
#    'To be honest I actually believe in something this film is about. I mean the reason I watched the movie, by the way, was because I was at a movie theater. But when I look back it really made me think about how great movies are, and what',
#    'To be honest I am the only person who feels that this guy really can play a small part here or even a large part in the show, but I am sure that his character will have a lot to do with who we will know and what will ultimately affect our',
#    "To be honest, I don't quite know how a story would work but it is one I remember seeing so many times - particularly after I moved to Berlin. It's not like I saw everything there. I would try to figure out what was happening if this particular",
#    "To be honest, I'm not sure I remember any one in particular who is better behind the camera..but I think there are several of them...<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    'To be honest, when I walked out of the movie they said I looked like a ditz like Dolph Lundgren. I thought, "why? Why didn\'t they make him look like I was there in the first place?" so I went back, bought',
#    "To be honest, I was not expecting anything but an insult to a good laugh! No wonder I thought this is such a bad film! As for the acting though, I wasn't expecting much, but then again, is a bad film. As for the editing",
#    'To be honest about, I was surprised to see that the film was shot on a small budget. After watching this movie, I was truly surprised how small the budget was given. I mean, who knew? Even though it appeared to be an early film, it'],
#   'rewards': {'To be honest I wasn\'t quite as impressed by "Escape to the Deep", but I do have to say that the story is brilliant and worth exploring. There are a few things that made me cringe, but this isn\'t one of them. For starters,': 3.6015625,
#    'To be honest here, there wasn\'t enough good ideas going, and the ending was way too anticlimactic. <br /><br />It\'s an interesting movie. It\'s not like another "Black Moon" where the plot got in the way. And': -0.129638671875,
#    'To be honest, I didn\'t care what anyone was talking about! The best part about "The One" is how it was filmed. The whole scene was totally unnecessary and I hate to be associated with people who can make fun of movies for the sake of it': -4.75,
#    'To be honest, though, after watching this it had absolutely nothing to do with the film. The production values were terrible. There was probably an under-researched script, too many scenes that were not clear-cut enough, bad direction, unrealistic pacing': -4.8984375,
#    "To be honest, my love for this movie is not as strong or fresh as it sounds. There's some cool special effects and some very nice photography/shot editing. I'm not sure how important its role is, but the movie certainly made a statement for the": 4.09765625,
#    'To be honest I\'m sure they could\'ve kept this film and brought it back in the box, i\'m also glad that I bought it now. I was really looking forward to seeing it, but it really seemed too "cute", and it turned out a': 2.919921875,
#    "To be honest with you, the second half of this film is one of cinema's greatest moments. The best moments in the film are at the funeral for the victims of the first war. The film opens with an ending that is like a film of old. The": 4.42578125,
#    "To be honest, I loved and appreciated what they were doing at the time and I'll never forget them.<br /><br />I loved the acting, the dialogue and they were able to put them on stage that really touched me. If there's one thing": 4.484375,
#    "To be honest: The plot is awful, and as such is not worth your time. I wish I'd have known what all the fuss was about before the film. I'll watch it once. Thank you for coming to see this wonderful film.<|endoftext|><|endoftext|><|endoftext|>": 0.68359375,
#    'To be honest I actually believe in something this film is about. I mean the reason I watched the movie, by the way, was because I was at a movie theater. But when I look back it really made me think about how great movies are, and what': 4.0390625,
#    'To be honest I am the only person who feels that this guy really can play a small part here or even a large part in the show, but I am sure that his character will have a lot to do with who we will know and what will ultimately affect our': 3.43359375,
#    "To be honest, I don't quite know how a story would work but it is one I remember seeing so many times - particularly after I moved to Berlin. It's not like I saw everything there. I would try to figure out what was happening if this particular": 2.513671875,
#    "To be honest, I'm not sure I remember any one in particular who is better behind the camera..but I think there are several of them...<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": -0.328125,
#    'To be honest, when I walked out of the movie they said I looked like a ditz like Dolph Lundgren. I thought, "why? Why didn\'t they make him look like I was there in the first place?" so I went back, bought': -2.697265625,
#    "To be honest, I was not expecting anything but an insult to a good laugh! No wonder I thought this is such a bad film! As for the acting though, I wasn't expecting much, but then again, is a bad film. As for the editing": -5.0234375,
#    'To be honest about, I was surprised to see that the film was shot on a small budget. After watching this movie, I was truly surprised how small the budget was given. I mean, who knew? Even though it appeared to be an early film, it': -0.81640625}},
#  'In my opinion': {'generated_text': ['In my opinion, this film is simply so terrible. It deals with a man named Jack Daniels (played by William Hurt) who gets caught in the middle of drug use when he was just one or two years old and who lives alone on his property. There are',
#    "In my opinion it's the worst movie ever.<br /><br />Maybe you will understand when reading that the movie was directed by Frank Sinatra. Or better yet, for your time's sake, take my word for that.<br /><br />What",
#    'In my opinion, the idea of one individual getting to take a trip to an area under the command of the military is really a pretty good "curse", but the film is so bad because it\'s so stupid that the action isn\'t good enough to save anyone',
#    'In my opinion this is a good film- I just gave it 1 star on the DVD. The acting was really awful that made some people jump and even some people who had seen the movie liked it quite a bit.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    'In my opinion, however, "Boredom in Sweden" gives this movie a bad enough name, despite the fact this movie is made in Germany. Of course, as an international film this film was made in Germany in 1955, but it was still made in',
#    "In my opinion. And I think it's very important to me that the movie actually had a good time. The opening scene was just excellent -- though I guess that's to be expected from a film set in a very rural setting. There was some real blood at",
#    "In my opinion, the most disappointing element about this movie is the fact that it was a film I was able to watch through a DVD. While I'm sure there are many people out there that can't watch films for reasons beyond the technical limitations that the disc is",
#    'In my opinion, this has all the qualities that a good comedy can provide. And if this is an "Oh wow, this is really scary!" video shoot then you could do a lot worse than this. Otherwise, this is one of those movies that has a',
#    "In my opinion, they are a very good family movie. The plot is great and all the actors seem normal and it was a waste of a good time. But, that's another reason why no one commented on the movie.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    'In my opinion the only reason to take this film for a rent and maybe even a purchase is that it is based around "The Dark World". The film is about a man, an Indian hunter and a woman. What happens in this world is not really well told',
#    "In my opinion, the film is a good film if you want to give a good watch out of it. The characters in the film are believable, the camera work is professional and if you're into action with little thought to others, you won't be disappointed.",
#    'In my opinion I think this is one of the best movies of all time because it was all about a man who was trying to change the world. <br /><br />I have seen this little gem a handful of times now for no apparent reason other than',
#    "In my opinion, and judging from the reviews I read on this app, I really felt sorry for a film producer that had to show just a bunch of clips that may have been completely different footage. This film was so horribly, horribly bad I couldn't even get",
#    'In my opinion, this movie is very well made, extremely well acted, and definitely worth watching if you enjoy cheesy or just for kicks.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    'In my opinion, the movie fails at both the acting and even in the direction, and this was a little hard to make. The story line is just unbelievable (or was it????) for some reason and when it came to characters or scenes, the writing was',
#    'In my opinion, this film is terrible as a cinema, just watch it.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'],
#   'rewards': {'In my opinion, this film is simply so terrible. It deals with a man named Jack Daniels (played by William Hurt) who gets caught in the middle of drug use when he was just one or two years old and who lives alone on his property. There are': -4.28125,
#    "In my opinion it's the worst movie ever.<br /><br />Maybe you will understand when reading that the movie was directed by Frank Sinatra. Or better yet, for your time's sake, take my word for that.<br /><br />What": -4.73046875,
#    'In my opinion, the idea of one individual getting to take a trip to an area under the command of the military is really a pretty good "curse", but the film is so bad because it\'s so stupid that the action isn\'t good enough to save anyone': -4.88671875,
#    'In my opinion this is a good film- I just gave it 1 star on the DVD. The acting was really awful that made some people jump and even some people who had seen the movie liked it quite a bit.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': -0.9443359375,
#    'In my opinion, however, "Boredom in Sweden" gives this movie a bad enough name, despite the fact this movie is made in Germany. Of course, as an international film this film was made in Germany in 1955, but it was still made in': -3.36328125,
#    "In my opinion. And I think it's very important to me that the movie actually had a good time. The opening scene was just excellent -- though I guess that's to be expected from a film set in a very rural setting. There was some real blood at": 3.240234375,
#    "In my opinion, the most disappointing element about this movie is the fact that it was a film I was able to watch through a DVD. While I'm sure there are many people out there that can't watch films for reasons beyond the technical limitations that the disc is": -4.56640625,
#    'In my opinion, this has all the qualities that a good comedy can provide. And if this is an "Oh wow, this is really scary!" video shoot then you could do a lot worse than this. Otherwise, this is one of those movies that has a': 0.1278076171875,
#    "In my opinion, they are a very good family movie. The plot is great and all the actors seem normal and it was a waste of a good time. But, that's another reason why no one commented on the movie.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": 1.0771484375,
#    'In my opinion the only reason to take this film for a rent and maybe even a purchase is that it is based around "The Dark World". The film is about a man, an Indian hunter and a woman. What happens in this world is not really well told': -2.990234375,
#    "In my opinion, the film is a good film if you want to give a good watch out of it. The characters in the film are believable, the camera work is professional and if you're into action with little thought to others, you won't be disappointed.": 4.6796875,
#    'In my opinion I think this is one of the best movies of all time because it was all about a man who was trying to change the world. <br /><br />I have seen this little gem a handful of times now for no apparent reason other than': 4.4453125,
#    "In my opinion, and judging from the reviews I read on this app, I really felt sorry for a film producer that had to show just a bunch of clips that may have been completely different footage. This film was so horribly, horribly bad I couldn't even get": -4.67578125,
#    'In my opinion, this movie is very well made, extremely well acted, and definitely worth watching if you enjoy cheesy or just for kicks.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': 4.60546875,
#    'In my opinion, the movie fails at both the acting and even in the direction, and this was a little hard to make. The story line is just unbelievable (or was it????) for some reason and when it came to characters or scenes, the writing was': -4.84375,
#    'In my opinion, this film is terrible as a cinema, just watch it.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': -2.8125}},
#  'I believe that': {'generated_text': ['I believe that if the main characters are not "out of the blue" and "under the control" of these two characters, the film could still hold its own within its genre limits - however I doubt that the "out of the blue" elements of each film',
#    'I believe that we still have two films that have merit on the table today...the first one is "The House of Games", and this second is the one based on the story of the old family house. I think at this point you would have to see the',
#    "I believe that's the only place in the movie that I really can say that no one else's work was so excellent as well. I have the very best idea on such issues, I cannot believe that so many people couldn't find something good they loved and didn",
#    'I believe that you deserve your money back or, that you should return your money for a refund. I cannot speak but I feel certain that we are in the end not being able to find another film that we loved after all these years!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    "I believe that they wanted the worst for their movie. In the end, it is a very good movie. It doesn't feel like an awful horror movie. It has some great scares and is very fun. It's got some good scares, fun moments and some",
#    "I believe that this movie will be one of the best of the year.<br /><br />In short, it's a great movie. But, I'd rather buy the DVD than rent it. It's certainly a shame I can't even get this on",
#    'I believe that the only characters being shown are the two who died. The real tragedy in this movie is the movie is made on an even more elaborate plot, the plot that is completely out of character, and the "plot that is also ridiculous". If you\'ve',
#    "I believe that it's more a matter of if you're a hardcore baseball fan or not.<br /><br />The acting is so, so bad. Why did this show keep on being broadcast? Why did it get canceled? What about the plot of the",
#    "I believe that the best way forward would be to use the more open-ended and naturalistic direction. We were given plenty to work with, but I think the original concept was better. In any case, it's a very unique and ambitious project (with all",
#    'I believe that it looks quite realistic. I also remember that a lot was done there, and it was great to watch. I really enjoy the movie that most people are not. It was only a good 10 minutes or a few minutes. But with a movie like',
#    'I believe that there is never a doubt in my mind that this film is a brilliant movie. As it begins with the characters and their situations, you have all the great moments that you want from a movie, and none of them occur in this movie. The ending',
#    "I believe that they made a mistake in thinking it would not be interesting to us in the first place.<br /><br />The last ten minutes of the film, after the final revelation that the secret weapon of the evil Cabal's power over humans is the",
#    "I believe that this was my first film which I liked and I'm glad it was made. The actors did a good job in creating a film which makes it an easy viewing. The cinematography reminded me of the kind of art you find in a film by the",
#    'I believe that Mr. Giger (who was a part of this film - no-one ever said that!) has the power that can make anyone, and then in some other way he can change that and have it become a reality in some way. At least',
#    'I believe that the audience would understand what I was saying, or perhaps even have been entertained from any point of view. There is no suspense, no suspense, no suspense! You could hardly sit through this movie with a full head of hair standing between you and the',
#    "I believe that is when the director's eyes light up, then it is clear why they did what they did. When the actors look in the mirror, and there is nowhere to go back, you can't help but notice the reflection of your face like a picture"],
#   'rewards': {'I believe that if the main characters are not "out of the blue" and "under the control" of these two characters, the film could still hold its own within its genre limits - however I doubt that the "out of the blue" elements of each film': 1.244140625,
#    'I believe that we still have two films that have merit on the table today...the first one is "The House of Games", and this second is the one based on the story of the old family house. I think at this point you would have to see the': 3.2265625,
#    "I believe that's the only place in the movie that I really can say that no one else's work was so excellent as well. I have the very best idea on such issues, I cannot believe that so many people couldn't find something good they loved and didn": 3.41015625,
#    'I believe that you deserve your money back or, that you should return your money for a refund. I cannot speak but I feel certain that we are in the end not being able to find another film that we loved after all these years!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>': 0.59326171875,
#    "I believe that they wanted the worst for their movie. In the end, it is a very good movie. It doesn't feel like an awful horror movie. It has some great scares and is very fun. It's got some good scares, fun moments and some": 4.8828125,
#    "I believe that this movie will be one of the best of the year.<br /><br />In short, it's a great movie. But, I'd rather buy the DVD than rent it. It's certainly a shame I can't even get this on": 2.771484375,
#    'I believe that the only characters being shown are the two who died. The real tragedy in this movie is the movie is made on an even more elaborate plot, the plot that is completely out of character, and the "plot that is also ridiculous". If you\'ve': -3.50390625,
#    "I believe that it's more a matter of if you're a hardcore baseball fan or not.<br /><br />The acting is so, so bad. Why did this show keep on being broadcast? Why did it get canceled? What about the plot of the": -4.80859375,
#    "I believe that the best way forward would be to use the more open-ended and naturalistic direction. We were given plenty to work with, but I think the original concept was better. In any case, it's a very unique and ambitious project (with all": 3.884765625,
#    'I believe that it looks quite realistic. I also remember that a lot was done there, and it was great to watch. I really enjoy the movie that most people are not. It was only a good 10 minutes or a few minutes. But with a movie like': 4.640625,
#    'I believe that there is never a doubt in my mind that this film is a brilliant movie. As it begins with the characters and their situations, you have all the great moments that you want from a movie, and none of them occur in this movie. The ending': 4.73828125,
#    "I believe that they made a mistake in thinking it would not be interesting to us in the first place.<br /><br />The last ten minutes of the film, after the final revelation that the secret weapon of the evil Cabal's power over humans is the": -0.32421875,
#    "I believe that this was my first film which I liked and I'm glad it was made. The actors did a good job in creating a film which makes it an easy viewing. The cinematography reminded me of the kind of art you find in a film by the": 4.76171875,
#    'I believe that Mr. Giger (who was a part of this film - no-one ever said that!) has the power that can make anyone, and then in some other way he can change that and have it become a reality in some way. At least': 0.8056640625,
#    'I believe that the audience would understand what I was saying, or perhaps even have been entertained from any point of view. There is no suspense, no suspense, no suspense! You could hardly sit through this movie with a full head of hair standing between you and the': -4.2734375,
#    "I believe that is when the director's eyes light up, then it is clear why they did what they did. When the actors look in the mirror, and there is nowhere to go back, you can't help but notice the reflection of your face like a picture": -0.04864501953125}},
#  'When I saw this movie': {'generated_text': ['When I saw this movie I was in heaven!!! I am a Christian who loves movies and am very impressed by American movies, especially those made in New York City!!I can say that the movie was not terrible!!!It is a good film and it is not bad - I',
#    'When I saw this movie I was shocked, shocked. Not only can someone like Richard Pryor ever have a career, but the entire movie seemed to be made up of a lot of these characters.<br /><br />I would have loved something if someone like Al Michaels had',
#    'When I saw this movie it made me feel very good, like I knew I had a movie to give back. And since i have been the son of a movie star for some years, I appreciate the acting ability of those in charge.<br /><br />The rest',
#    'When I saw this movie for the first time I found myself in disbelief, thinking that every horror piece has gone the way for a horror movie, but this one was the exception. This movie is the opposite! This movie is just like all real horror flicks and is definitely',
#    'When I saw this movie, I had a real scare. I feel as if it was filmed from a fake account of a film industry event that had been scheduled to happen to me. The actors played badly - their performances really did not fit in the movie.<br /><',
#    "When I saw this movie it struck me, as if there's something there. The story is not quite true to life. The characters are not quite likable. A few years ago, two young girls decided to go into business and in the end they left home. They",
#    "When I saw this movie, I didn't know anything about vampires. But after watching it I've come to the conclusion that it isn't much different than most. There's no blood, even if some blood is sprinkled around here or there. It's just a little scary",
#    'When I saw this movie I was absolutely entranced with it and even took a second to watch it. I don\'t know much about movies except for "The Godfather" (which I was surprised this was made) but I\'m not sure what has become of this',
#    'When I saw this movie, it was my first time seeing it and although I admit I was expecting a sequel, it wasn\'t the worst thing I\'ve ever seen. While some might think I\'m "stupid," and others would think I\'m stupid, if you want',
#    "When I saw this movie, the plot was pretty simple. Why can't they get away with these kind of things? In this case the answer is simple and, I won't say it badly enough. Even if there were some more plot details there's no excuse for not",
#    'When I saw this movie with a lot of friends, they all said "wow, this movie isn\'t that bad, it\'s funny, it\'s great acting, great scenes, and the acting and everything else is just great. But I just can\'t come up with the',
#    'When I saw this movie, I was entranced. It was incredible! I gave it a 9 or 10, and after watching it again, I am still amazed at how well it does soooo well in this genre. This film just oozed a sense of adventure',
#    "When I saw this movie on my TV, I cried my eyes out the whole time. I'm not a big fan of horror movies. Horror movies are supposed to have great scares, so maybe I'm doing it wrong. This actually was one of the worst movies I've",
#    'When I saw this movie I wondered how good of a movie this movie could have gotten. Well, after watching this movie the movie has improved. I was really surprised to see that the story of "Trouble in Paradise" was written by someone with no talent who had',
#    'When I saw this movie I was expecting a great comedy (of a kind), but it was a disaster. I was disappointed by this film, but I was disappointed by a comedy, too.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>',
#    'When I saw this movie, I was amazed to see how it did at first. I had an "aha" moment, but I quickly made things go away. It reminded me of what movies from the 80\'s were like and I was very captivated watching this. I'],
#   'rewards': {'When I saw this movie I was in heaven!!! I am a Christian who loves movies and am very impressed by American movies, especially those made in New York City!!I can say that the movie was not terrible!!!It is a good film and it is not bad - I': 4.48828125,
#    'When I saw this movie I was shocked, shocked. Not only can someone like Richard Pryor ever have a career, but the entire movie seemed to be made up of a lot of these characters.<br /><br />I would have loved something if someone like Al Michaels had': 0.80419921875,
#    'When I saw this movie it made me feel very good, like I knew I had a movie to give back. And since i have been the son of a movie star for some years, I appreciate the acting ability of those in charge.<br /><br />The rest': 4.8515625,
#    'When I saw this movie for the first time I found myself in disbelief, thinking that every horror piece has gone the way for a horror movie, but this one was the exception. This movie is the opposite! This movie is just like all real horror flicks and is definitely': 3.66015625,
# ...
#    'I would say that this was pretty good. It was very entertaining as far as the humor goes. It was in good form and it kept you off the edge. As a result, this movie is one of, if not THE best romantic comedies of all time.',
#    "I would say that it's a good movie for adults though it may be a little too dated (at least as a sequel to the one shown here). It probably does show the flaws of the whole thing, but it's okay if you haven't seen it.<br",
#    'I would say that that this film is a classic for anyone who loves films and not for people who enjoy big genre films. It is not about being a serious movie buff like most people are. It is about being deeply committed to discovering what makes a good mystery film,',
#    'I would say that this film is an excellent documentary, but I am unable to make it more accurate. But some people think that the only way to see this movie is to use its original name. I could see that this is a good alternative since those were the ones',
#    'I would say that the film really does have that quality about it. In addition to the fact that it was based around a female character, she managed to work through it and do a good job with her role. Her "other" character, meanwhile, was totally convincing',
#    "I would say that in this case this is the best movie I've seen to date featuring the famous Italian director Giovanni Cassini. His filmography has been well documented in many films and I wouldn't recommend this one as there are some outstanding actresses in this movie too.",
#    "I would say that this movie is better than its predecessor, although the DVD is a bit bigger than the first one, and the music may be a bit more off. Also, there is not much dialogue at all. There is at least a chance that Michael's first",
#    "I would say that the film didn't really shock me because I have known some of my old schoolers in my time. It was only when I started reading about it that I took it seriously. So in that context, and the other aspects of the film, I",
#    'I would say that every show on T.V. is good, even though people tend to think the characters are dull and bland. I just saw it again after some time. I recommend this show to people who were a little offended.<br /><br />My',
#    'I would say that this film is a great example of this story. The character played by David Warner is wonderful. He does everything to make this story stand out from a few other films I have seen that are not so known for their witty portrayal of life. His character',
#    'I would say that\'s an interesting book, although it comes off quite predictable at times. The two main girls are never in it, as they are rather irritating. The "evil genius" guy is a little more believable than we all thought, the other girls have their'],
#   'rewards': {"I would say that was the best story I've ever read. I saw one other movie one night and it was about a young couple who live with a group of friends. Unfortunately, they have no parents. The story involves a group of school kids who have the dream": 3.6015625,
#    "I would say that he is not quite on the par for the great James Bond in this sort of film, but his acting could be improved upon. He does better with a gun than others in the lead role. (I personally wouldn't count this as a bad film": 0.306884765625,
#    "I would say that is where the movie really shines.<br /><br />The characters are fantastic. They aren't just annoying, they're human, because of their expressions. I liked how the women were in the trailer, and how well they were trying to look": 4.49609375,
#    "I would say that the film is a really good one, to the point where it is an almost perfect showcase of what many of the cast do to perfection. I'd rate the film 10/10.<br /><br />I highly recommend the film, if you": 4.62109375,
#    "I would say that if you want the same thing then keep it with the same amount of effort. A couple of hours, and a lot of work on the plot, then you're done.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": -1.7119140625,
#    'I would say that this was pretty good. It was very entertaining as far as the humor goes. It was in good form and it kept you off the edge. As a result, this movie is one of, if not THE best romantic comedies of all time.': 4.96875,
#    "I would say that it's a good movie for adults though it may be a little too dated (at least as a sequel to the one shown here). It probably does show the flaws of the whole thing, but it's okay if you haven't seen it.<br": 1.4296875,
#    'I would say that that this film is a classic for anyone who loves films and not for people who enjoy big genre films. It is not about being a serious movie buff like most people are. It is about being deeply committed to discovering what makes a good mystery film,': 3.98046875,
#    'I would say that this film is an excellent documentary, but I am unable to make it more accurate. But some people think that the only way to see this movie is to use its original name. I could see that this is a good alternative since those were the ones': -0.58740234375,
#    'I would say that the film really does have that quality about it. In addition to the fact that it was based around a female character, she managed to work through it and do a good job with her role. Her "other" character, meanwhile, was totally convincing': 3.322265625,
#    "I would say that in this case this is the best movie I've seen to date featuring the famous Italian director Giovanni Cassini. His filmography has been well documented in many films and I wouldn't recommend this one as there are some outstanding actresses in this movie too.": 4.32421875,
#    "I would say that this movie is better than its predecessor, although the DVD is a bit bigger than the first one, and the music may be a bit more off. Also, there is not much dialogue at all. There is at least a chance that Michael's first": 0.58056640625,
#    "I would say that the film didn't really shock me because I have known some of my old schoolers in my time. It was only when I started reading about it that I took it seriously. So in that context, and the other aspects of the film, I": 2.392578125,
#    'I would say that every show on T.V. is good, even though people tend to think the characters are dull and bland. I just saw it again after some time. I recommend this show to people who were a little offended.<br /><br />My': 2.6484375,
#    'I would say that this film is a great example of this story. The character played by David Warner is wonderful. He does everything to make this story stand out from a few other films I have seen that are not so known for their witty portrayal of life. His character': 4.88671875,
#    'I would say that\'s an interesting book, although it comes off quite predictable at times. The two main girls are never in it, as they are rather irritating. The "evil genius" guy is a little more believable than we all thought, the other girls have their': 0.50537109375}},
#  'This movie was': {'generated_text': ['This movie was so stupid, it reminded me of a lot of my experiences. If you love movies like this, I encourage you to watch it! As a movie-going adult, the movie is so fun to take you home, make you laugh, and make',
#    'This movie was released by Visconti, but only for limited publicity, so that it would get a wider distribution. I had also heard of the movie in an early VHS release--but neither had seen it in a theatrical preview. Still, I was',
#    "This movie was so boring, it was difficult to believe i really watched it (i never knew it's like that). I thought that the lead character was hilarious, and that she really gave a brilliant performance. That girl was funny. Her acting was pretty poor.",
#    "This movie was definitely the worst I have ever seen. There just wasn't enough action and gore, and it didn't help that the plot never got in the way of suspense for the fans. If you're a fan of the genre, I think you'll be",
#    "This movie was not in a good state of the art.<br /><br />It went nowhere, but it's still a decent film.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    'This movie was in that category. The plot was bad and the script sucked as well as the story was too long and predictable. If not for Mr. Kringler, or David Morse, or Steve McQueen, it might be interesting. The other half of',
#    'This movie was written for a kid and it was not a very good movie at all...not really in the sense that it has great acting and characters, but the film had better acting than most action adventure films that have since been banned...this was the perfect example',
#    'This movie was really entertaining. Just how awesome was the acting of the actors? Did they do a really good job here in the movie! The dialogue was so good it was funny. Great. And i loved that this movie was nominated for an Oscar! It was',
#    'This movie was not worth the rental it cost. I thought the script was very interesting. We watch the story and the ending scenes. The music was excellent also I liked the ending credits... My favourite part was the special effects of the car, The car has a',
#    "This movie was a great way to spend a good afternoon at summer camp and enjoy every minute of it. I've watched it now and still am thoroughly intrigued by it. I'm also curious why the cast (who actually appear in several movies in the same period in",
#    'This movie was terrible as a horror movie.<br /><br />I feel terrible, because I think that if you were to watch this movie and see what the director had to say about it, no one would buy it because it was so bad! And the',
#    "This movie was awful. The cast is terrible I must say, it's not funny, the music is bad but the movie is bad, it's not cool. I can't give him a recommendation but he should watch it without a clue.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>",
#    'This movie was directed by the former acting director of this movie, the acting director of this movie was someone with experience in making films, which were so bad these days that its impossible not to see a movie like this. The music, the camera work, etc.',
#    'This movie was about people getting together and meeting, and then the story moves into a situation that has absolutely no relevance for the rest of the movie, the movie begins with one of the most unlikely characters in a whole series of weird and hilarious characters and then proceeds to',
#    "This movie was actually really good. Not everything is perfect, but this is a really good film and I have been watching it for about 6 or 7 years, which has always been the case. I've never thought that this movie could be the best the show has",
#    'This movie was based on the true story of a man sent to a different planet by aliens after having broken free of his world. If it hadn\'t been for the fact that so many times in the series we\'ve seen the "bad-bad-bad-good'],
#   'rewards': {'This movie was so stupid, it reminded me of a lot of my experiences. If you love movies like this, I encourage you to watch it! As a movie-going adult, the movie is so fun to take you home, make you laugh, and make': -0.483154296875,
#    'This movie was released by Visconti, but only for limited publicity, so that it would get a wider distribution. I had also heard of the movie in an early VHS release--but neither had seen it in a theatrical preview. Still, I was': -0.34326171875,
#    "This movie was so boring, it was difficult to believe i really watched it (i never knew it's like that). I thought that the lead character was hilarious, and that she really gave a brilliant performance. That girl was funny. Her acting was pretty poor.": -4.578125,
#    "This movie was definitely the worst I have ever seen. There just wasn't enough action and gore, and it didn't help that the plot never got in the way of suspense for the fans. If you're a fan of the genre, I think you'll be": -4.89453125,
#    "This movie was not in a good state of the art.<br /><br />It went nowhere, but it's still a decent film.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>": -1.85546875,
#    'This movie was in that category. The plot was bad and the script sucked as well as the story was too long and predictable. If not for Mr. Kringler, or David Morse, or Steve McQueen, it might be interesting. The other half of': -4.94921875,
#    'This movie was written for a kid and it was not a very good movie at all...not really in the sense that it has great acting and characters, but the film had better acting than most action adventure films that have since been banned...this was the perfect example': 2.7109375,
#    'This movie was really entertaining. Just how awesome was the acting of the actors? Did they do a really good job here in the movie! The dialogue was so good it was funny. Great. And i loved that this movie was nominated for an Oscar! It was': 4.68359375,
#    'This movie was not worth the rental it cost. I thought the script was very interesting. We watch the story and the ending scenes. The music was excellent also I liked the ending credits... My favourite part was the special effects of the car, The car has a': 4.2734375,
#    "This movie was a great way to spend a good afternoon at summer camp and enjoy every minute of it. I've watched it now and still am thoroughly intrigued by it. I'm also curious why the cast (who actually appear in several movies in the same period in": 4.7265625,
#    'This movie was terrible as a horror movie.<br /><br />I feel terrible, because I think that if you were to watch this movie and see what the director had to say about it, no one would buy it because it was so bad! And the': -4.6640625,
#    "This movie was awful. The cast is terrible I must say, it's not funny, the music is bad but the movie is bad, it's not cool. I can't give him a recommendation but he should watch it without a clue.<|endoftext|><|endoftext|><|endoftext|><|endoftext|>": -4.97265625,
#    'This movie was directed by the former acting director of this movie, the acting director of this movie was someone with experience in making films, which were so bad these days that its impossible not to see a movie like this. The music, the camera work, etc.': -4.51953125,
#    'This movie was about people getting together and meeting, and then the story moves into a situation that has absolutely no relevance for the rest of the movie, the movie begins with one of the most unlikely characters in a whole series of weird and hilarious characters and then proceeds to': -0.79296875,
#    "This movie was actually really good. Not everything is perfect, but this is a really good film and I have been watching it for about 6 or 7 years, which has always been the case. I've never thought that this movie could be the best the show has": 4.890625,
#    'This movie was based on the true story of a man sent to a different planet by aliens after having broken free of his world. If it hadn\'t been for the fact that so many times in the series we\'ve seen the "bad-bad-bad-good': 0.7578125}}}

# %%
prompt_to_reward = {}
for prompt in prompt_dict:
  # print(prompt)
  prompt_to_reward[prompt] = {"average_reward": 0, "highest_reward": 0}
  total_reward = 0
  for i, (text, reward) in enumerate(sorted(prompt_dict[prompt]["rewards"].items(), key=lambda item: item[1], reverse=True)):
    if i == 0:
      prompt_to_reward[prompt]["highest_reward"] = reward
    total_reward += reward
  # print(f"Total reward: {total_reward:.2f}")
  average_reward = total_reward / len(prompt_dict[prompt]["rewards"])
  prompt_to_reward[prompt]["average_reward"] = average_reward
prompt_to_reward
# Out:
# {'It was': {'average_reward': 0.666839599609375, 'highest_reward': 4.43359375},
#  'I think that': {'average_reward': 1.2779350280761719,
#   'highest_reward': 4.8515625},
#  'To be honest': {'average_reward': 0.7222442626953125,
#   'highest_reward': 4.484375},
#  'In my opinion': {'average_reward': -1.2449417114257812,
#   'highest_reward': 4.6796875},
#  'I believe that': {'average_reward': 1.3750419616699219,
#   'highest_reward': 4.8828125},
#  'When I saw this movie': {'average_reward': 0.7980499267578125,
#   'highest_reward': 4.8515625},
#  'I would say that': {'average_reward': 2.4853363037109375,
#   'highest_reward': 4.96875},
#  'This movie was': {'average_reward': -0.6256256103515625,
#   'highest_reward': 4.890625}}

# %%
# get the highest reward by average and by highest absolute reward
highest_average_reward = max(prompt_to_reward.items(), key=lambda item: item[1]["average_reward"])
highest_average_reward
# Out:
# ('I would say that',
#  {'average_reward': 2.4853363037109375, 'highest_reward': 4.96875})

# %%
highest_reward = max(prompt_to_reward.items(), key=lambda item: item[1]["highest_reward"])
highest_reward
# Out:
# ('I would say that',
#  {'average_reward': 2.4853363037109375, 'highest_reward': 4.96875})

# %% [markdown]
# ## Based on the experiment above, the best prompt to start with is "I would say that"

# %%
ranking_by_highest = sorted(prompt_to_reward.items(), key=lambda item: item[1]["highest_reward"], reverse=True)
ranking_by_highest
# Out:
# [('I would say that',
#   {'average_reward': 2.4853363037109375, 'highest_reward': 4.96875}),
#  ('This movie was',
#   {'average_reward': -0.6256256103515625, 'highest_reward': 4.890625}),
#  ('I believe that',
#   {'average_reward': 1.3750419616699219, 'highest_reward': 4.8828125}),
#  ('I think that',
#   {'average_reward': 1.2779350280761719, 'highest_reward': 4.8515625}),
#  ('When I saw this movie',
#   {'average_reward': 0.7980499267578125, 'highest_reward': 4.8515625}),
#  ('In my opinion',
#   {'average_reward': -1.2449417114257812, 'highest_reward': 4.6796875}),
#  ('To be honest',
#   {'average_reward': 0.7222442626953125, 'highest_reward': 4.484375}),
#  ('It was',
#   {'average_reward': 0.666839599609375, 'highest_reward': 4.43359375})]

# %%
ranking_by_average = sorted(prompt_to_reward.items(), key=lambda item: item[1]["average_reward"], reverse=True)
ranking_by_average
# Out:
# [('I would say that',
#   {'average_reward': 2.4853363037109375, 'highest_reward': 4.96875}),
#  ('I believe that',
#   {'average_reward': 1.3750419616699219, 'highest_reward': 4.8828125}),
#  ('I think that',
#   {'average_reward': 1.2779350280761719, 'highest_reward': 4.8515625}),
#  ('When I saw this movie',
#   {'average_reward': 0.7980499267578125, 'highest_reward': 4.8515625}),
#  ('To be honest',
#   {'average_reward': 0.7222442626953125, 'highest_reward': 4.484375}),
#  ('It was',
#   {'average_reward': 0.666839599609375, 'highest_reward': 4.43359375}),
#  ('This movie was',
#   {'average_reward': -0.6256256103515625, 'highest_reward': 4.890625}),
#  ('In my opinion',
#   {'average_reward': -1.2449417114257812, 'highest_reward': 4.6796875})]

# %% [markdown]
# # Fine-tune the main model with RL (FOR PROJECT)
#
#
# For this tutorial, we will optimize GPT2 to produce positive IMDB movie reviews using the reward model you trained above.
#
# Unlike supervised fine-tuning, RL allows model to generate it's own sentences on each training step. Then, it calculates the reward of those specific sentences, and finally, updates the model to increase the probability of sentences with high reward.
#
# Thus, each RLHF consists of three stages: __Rollout__, __Evaluation__ and __Update__
#
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_bert_training.png' width='600'>
#
# The update stage depends on the specific RL algorithm. We'll be using Proximal Policy Optimization, or [PPO](https://arxiv.org/abs/1707.06347), similarly to what was used for InstructGPT.
#
# Before we run those 3 stages, however, we need to create a dataset of "queries" - partial reviews in our case.

# %%
import trl

# %%
import random

class LengthSampler:
    def __init__(self, min_length, max_length):
        self.min_length = min_length
        self.max_length = max_length

    def __call__(self):
        return random.randint(self.min_length, self.max_length)

sample_length = LengthSampler(2, 8)  # use the first 2-8 tokens as query

# %%
def select_query_and_tokenize(sample):
    query_ids = main_tokenizer.encode(sample["text"])[: sample_length()]
    sample["query"] = main_tokenizer.decode(query_ids)  # query is the only required column
    sample["input_ids"] = query_ids  # to avoid re-tokenizing later
    return sample  # we do not need the rest - it will be generated by the model

imdb_for_rlhf = imdb.filter(lambda row: len(row['text']) > 200, batched=False)
imdb_for_rlhf = imdb_for_rlhf.remove_columns(['label'])
imdb_for_rlhf = imdb_for_rlhf.map(select_query_and_tokenize, batched=False)
imdb_for_rlhf.set_format(type="torch")
# Out:
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Next, let's prepare your reward model to predict rewards on whatever reviews were generated. Note that we use plaintext reviews because main model uses a different tokenizer from the reward model.

# %%
#!g2.1
from typing import List
def compute_reward(texts: List[str]) -> torch.Tensor:
  inputs = reward_tokenizer(texts, truncation=True, padding=True, return_tensors='pt').to(device)
  with torch.no_grad():
    return reward_model(**inputs).logits[:, 0]

# %%
#!g2.1
compute_reward([imdb[45]['text'], imdb[16000]['text']])  # test on human-written reviews
# Out:
# tensor([-4.6484,  4.9336], device='cuda:0')

# %% [markdown]
# Finally, we move to RL training. In this tutorial, we'll train LoRA adapters and not the full model.

# %%
#!g2.1
import peft
peft_config = peft.LoraConfig(
    task_type=peft.TaskType.CAUSAL_LM, r=32, lora_alpha=32, lora_dropout=0.0, inference_mode=False
)

# reload main model as AutoModelForCausalLMWithValueHead - with an extra head needed for PPO
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_tokenizer.pad_token = main_tokenizer.eos_token

main_model = trl.AutoModelForCausalLMWithValueHead.from_pretrained("lvwerra/gpt2-imdb", device_map=device)
main_model = peft.get_peft_model(main_model, peft_config, adapter_name='default')
main_model.print_trainable_parameters()
# Out:
# trainable params: 1,179,648 || all params: 125,620,225 || trainable%: 0.9391
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py:1768: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %% [markdown]
# Same as before, trl has a special type of trainer that minimize PPO-specific pseudo-loss. You can read more on this trainer [here](https://huggingface.co/docs/trl/main/en/ppo_trainer).

# %%
#!g2.1
training_args = trl.PPOConfig(
    model_name=main_model.config._name_or_path,
    gradient_accumulation_steps=1,
    learning_rate=1.41e-5,
    batch_size=64,
    ppo_epochs=4,                 # PPO performs this many updates per training batch
)

ppo_trainer = trl.PPOTrainer(
    training_args, model=main_model.model, tokenizer=main_tokenizer,
    dataset=imdb_for_rlhf, data_collator=lambda data: dict((key, [d[key] for d in data]) for key in data[0])
)  # note: we pass main_model.model because PPOTrainer checks for one of several supported model types ...
# ... main_model.model is a model with adapters, which is supported. main_model itself is a wrapper that is not supported
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b65815fcaa35> in <cell line: 0>()
#       1 #!g2.1
# ----> 2 training_args = trl.PPOConfig(
#       3     model_name=main_model.config._name_or_path,
#       4     gradient_accumulation_steps=1,
#       5     learning_rate=1.41e-5,
#
# TypeError: PPOConfig.__init__() got an unexpected keyword argument 'model_name'

# %%
#!g2.1
from tqdm.auto import tqdm
max_steps = 50   # can be insufficient for some tasks - watch your learning curves
generation_kwargs = dict(
    min_length=-1, max_new_tokens=128, do_sample=True, top_k=0, top_p=1.0, pad_token_id=main_tokenizer.eos_token_id)
#                                  ^-- task-specific parameter!
with tqdm(enumerate(ppo_trainer.dataloader), total=max_steps) as progressbar:
  # note: ppo_trainer.dataloader is just a regular dataloader of queries, no RL-specific magic :)
  for epoch, batch in progressbar:
    if epoch >= max_steps:
        break

    # Rollout stage: generate continuations from batch queries using main_model
    response_tensors = ppo_trainer.generate(batch['input_ids'], **generation_kwargs)
    # ^-- list of tensors of token ids from main model tokenizer

    # de-tokenize responses to strings (since reward model uses a different tokenizer)
    batch["response"] = [main_tokenizer.decode(response.squeeze()) for response in response_tensors]
    # note: response_tensors already contain query tokens, so we don't need to add queries manually.
    # This may not be true for other tasks: check this manually by viewing batch["response"] and batch["query"]


    # Evaluation stage
    rewards = compute_reward(batch['response'])

    # Update stage
    stats = ppo_trainer.step(batch['input_ids'], response_tensors, list(rewards.split(1)))
    stats['rewards/mean'] = rewards.mean().item()

    print("-" * 30, 'STEP', epoch, '-' * 30)
    print(f'rewards/mean:\t{stats["rewards/mean"]:.9f}\t<---- average reward over this batch (higher=better, noisy)')
    print(f'ppo/returns/mean:\t{stats["ppo/returns/mean"]:.9f}\t<---- model-estimated average discounted reward')
    print(f'objective/kl:\t{stats["objective/kl"]:.9f}\t<---- how far we are from the original model (regularizer)')
    print()

    ppo_trainer.log_stats(stats, batch, list(rewards.split(1)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ------------------------------ STEP 0 ------------------------------
# rewards/mean:	-0.033458710	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.419863880	<---- model-estimated average discounted reward
# objective/kl:	0.000000000	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 1 ------------------------------
# rewards/mean:	0.278663635	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.253651321	<---- model-estimated average discounted reward
# objective/kl:	0.424308300	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 2 ------------------------------
# rewards/mean:	0.573652029	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.073742464	<---- model-estimated average discounted reward
# objective/kl:	0.916751623	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 3 ------------------------------
# rewards/mean:	0.680272102	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.014293447	<---- model-estimated average discounted reward
# objective/kl:	1.611181498	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 4 ------------------------------
# rewards/mean:	0.637197495	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.117953703	<---- model-estimated average discounted reward
# objective/kl:	2.776535749	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 5 ------------------------------
# rewards/mean:	1.090905190	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.169604033	<---- model-estimated average discounted reward
# objective/kl:	3.811805725	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 6 ------------------------------
# rewards/mean:	1.654058456	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.348742217	<---- model-estimated average discounted reward
# objective/kl:	4.794001579	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 7 ------------------------------
# rewards/mean:	1.492575169	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.495564699	<---- model-estimated average discounted reward
# objective/kl:	5.485957146	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 8 ------------------------------
# rewards/mean:	2.335594177	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.842965126	<---- model-estimated average discounted reward
# objective/kl:	6.395464420	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 9 ------------------------------
# rewards/mean:	1.561879158	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.669689775	<---- model-estimated average discounted reward
# objective/kl:	6.702696323	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 10 ------------------------------
# rewards/mean:	2.590698481	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.993873358	<---- model-estimated average discounted reward
# objective/kl:	7.981188774	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 11 ------------------------------
# rewards/mean:	2.106279373	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.975338578	<---- model-estimated average discounted reward
# objective/kl:	7.828726768	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 12 ------------------------------
# rewards/mean:	2.388473511	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.095461369	<---- model-estimated average discounted reward
# objective/kl:	9.245917320	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 13 ------------------------------
# rewards/mean:	2.576652527	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.267282486	<---- model-estimated average discounted reward
# objective/kl:	9.062112808	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 14 ------------------------------
# rewards/mean:	2.509240627	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.300251245	<---- model-estimated average discounted reward
# objective/kl:	10.028444290	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 15 ------------------------------
# rewards/mean:	2.929592133	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.450162172	<---- model-estimated average discounted reward
# objective/kl:	9.795566559	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 16 ------------------------------
# rewards/mean:	2.296215773	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.360654354	<---- model-estimated average discounted reward
# objective/kl:	9.118740082	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 17 ------------------------------
# rewards/mean:	3.076555252	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.661263227	<---- model-estimated average discounted reward
# objective/kl:	9.311429977	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 18 ------------------------------
# rewards/mean:	2.517547607	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.610380411	<---- model-estimated average discounted reward
# objective/kl:	10.609040260	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 19 ------------------------------
# rewards/mean:	3.498115540	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.983959317	<---- model-estimated average discounted reward
# objective/kl:	11.616748810	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 20 ------------------------------
# rewards/mean:	3.006476402	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.935671329	<---- model-estimated average discounted reward
# objective/kl:	11.283543587	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 21 ------------------------------
# rewards/mean:	3.373206139	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.001257420	<---- model-estimated average discounted reward
# objective/kl:	13.147975922	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 22 ------------------------------
# rewards/mean:	3.395843506	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.090600014	<---- model-estimated average discounted reward
# objective/kl:	12.343813896	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 23 ------------------------------
# rewards/mean:	3.547855377	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.211441755	<---- model-estimated average discounted reward
# objective/kl:	12.460732460	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 24 ------------------------------
# rewards/mean:	3.668563843	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.232666731	<---- model-estimated average discounted reward
# objective/kl:	13.552862167	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 25 ------------------------------
# rewards/mean:	3.558746338	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.340235233	<---- model-estimated average discounted reward
# objective/kl:	12.332838058	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 26 ------------------------------
# rewards/mean:	4.116277695	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.485009670	<---- model-estimated average discounted reward
# objective/kl:	14.513065338	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 27 ------------------------------
# rewards/mean:	3.592343330	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.315751076	<---- model-estimated average discounted reward
# objective/kl:	14.873290062	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 28 ------------------------------
# rewards/mean:	4.258361816	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.629878521	<---- model-estimated average discounted reward
# objective/kl:	14.515798569	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 29 ------------------------------
# rewards/mean:	3.839004517	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.503781319	<---- model-estimated average discounted reward
# objective/kl:	14.475437164	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 30 ------------------------------
# rewards/mean:	4.268234253	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.806118488	<---- model-estimated average discounted reward
# objective/kl:	13.404888153	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 31 ------------------------------
# rewards/mean:	4.048920155	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.651010036	<---- model-estimated average discounted reward
# objective/kl:	14.467522621	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 32 ------------------------------
# rewards/mean:	3.393676758	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.499082088	<---- model-estimated average discounted reward
# objective/kl:	15.021280289	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 33 ------------------------------
# rewards/mean:	3.963635921	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.690418243	<---- model-estimated average discounted reward
# objective/kl:	13.968084335	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 34 ------------------------------
# rewards/mean:	4.075362682	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.754722118	<---- model-estimated average discounted reward
# objective/kl:	15.962810516	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 35 ------------------------------
# rewards/mean:	4.204570770	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.755409241	<---- model-estimated average discounted reward
# objective/kl:	16.192779541	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 36 ------------------------------
# rewards/mean:	4.112086296	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.734297276	<---- model-estimated average discounted reward
# objective/kl:	15.588475227	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 37 ------------------------------
# rewards/mean:	4.101501465	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.744776249	<---- model-estimated average discounted reward
# objective/kl:	15.384011269	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 38 ------------------------------
# rewards/mean:	4.490764618	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.849191666	<---- model-estimated average discounted reward
# objective/kl:	17.840660095	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 39 ------------------------------
# rewards/mean:	4.198875427	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.791370392	<---- model-estimated average discounted reward
# objective/kl:	16.089687347	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 40 ------------------------------
# rewards/mean:	4.316064835	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.717653275	<---- model-estimated average discounted reward
# objective/kl:	15.130897522	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 41 ------------------------------
# rewards/mean:	4.028503418	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.756909847	<---- model-estimated average discounted reward
# objective/kl:	15.464221001	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 42 ------------------------------
# rewards/mean:	4.519897461	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.827311993	<---- model-estimated average discounted reward
# objective/kl:	17.389547348	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 43 ------------------------------
# rewards/mean:	3.798522949	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.683984756	<---- model-estimated average discounted reward
# objective/kl:	14.894588470	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 44 ------------------------------
# rewards/mean:	4.409133911	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.695876598	<---- model-estimated average discounted reward
# objective/kl:	15.236425400	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 45 ------------------------------
# rewards/mean:	4.256340027	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.821741581	<---- model-estimated average discounted reward
# objective/kl:	15.233748436	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 46 ------------------------------
# rewards/mean:	4.467102051	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.964675903	<---- model-estimated average discounted reward
# objective/kl:	15.735445023	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 47 ------------------------------
# rewards/mean:	3.935731888	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.648492575	<---- model-estimated average discounted reward
# objective/kl:	14.590065002	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 48 ------------------------------
# rewards/mean:	3.884203911	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.771272421	<---- model-estimated average discounted reward
# objective/kl:	14.206766129	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 49 ------------------------------
# rewards/mean:	4.287136078	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.812275410	<---- model-estimated average discounted reward
# objective/kl:	15.256341934	<---- how far we are from the original model (regularizer)

# %%
#!g2.1
print("-" * 30, 'STEP', epoch, '-' * 30)
print(f'rewards/mean:\t{stats["rewards/mean"]:.9f}\t<---- average reward over this batch (higher=better, noisy)')
print(f'ppo/returns/mean:\t{stats["ppo/returns/mean"]:.9f}\t<---- model-estimated average discounted reward')
print(f'objective/kl:\t{stats["objective/kl"]:.9f}\t<---- how far we are from the original model (regularizer)')
print()
# Out:
# ------------------------------ STEP 50 ------------------------------
# rewards/mean:	4.287136078	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.812275410	<---- model-estimated average discounted reward
# objective/kl:	15.256341934	<---- how far we are from the original model (regularizer)

# %% [markdown]
# ## Main assignment - <u>actually</u> train the model
#
#
# Your main task for this week is to use the RLHF pipeline to train a model for a reward of your choice. Here's what you can choose from:
#
# __A. Toxicity fine-tuning:__ train the model to be less (or more!) toxic. For this task, you may use the data from [jigsaw toxic comments](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge) and [lmsys/toxic-chat](https://huggingface.co/datasets/lmsys/toxic-chat),  or any other source. Alternatively, you may use toxicity scores from [oasst1](https://huggingface.co/datasets/OpenAssistant/oasst1).
#
#
# __B. Actual human feedback:__ use one of the existing datasets with pairwise human feedback to align your langauge model. You may use [anthropic's hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf), [OpenAssistant dataset](https://huggingface.co/datasets/OpenAssistant/oasst1) or any other data you see fit. You may also turn the tables and train the model to [minimize](https://habrastorage.org/getpro/geektimes/post_images/ac7/2ad/827/ac72ad82767d4132164a4b6b76196c42.jpg) human preferences, as long as your model does not degrade to gibberish.
#
# __C. Controlled generation:__ Instead of training a reward model from human feedback, you may define the reward function as the text length (longer or shorter) or number of times the model uses specific words (e.g. "sorry", "apologize"). If you choose specific words, make sure the model generates them at least sometimes.
#
# __Alternatively,__ you may choose a different task. However, unless your task is very similar to one of the above, there is a chance that it will be **significantly** harder to solve, requiring orders of magnitude more compute and tuning. If you are in doubt, please ask the course staff. If they are AFK (again >.<), please prefer one of the recommended tasks.
#
#
# #### General tips & tricks
#
#
# Things to look out for:
# - during PPO stage, the reward model should be in eval mode (dropout disabled)
# - make sure max_length and max_new_tokens are enough for your chosen dataset - at least most of the time
# - when in doubt, view the data manually or inspect how the model performs on a few samples
#
#
# We highly recommend that you manually check the performance after each sub-stage:
# 1. when you assembled the pairwise dataset, inspect a couple of from of *your* dataset class and detokenize them. Make sure that you-the-human understand why one sample was accepted and the other - rejected. At least most of the time. This also lets you spot tokenization/truncation errors.
# 2. after you trained a reward model, measure how accurate this model is in isolation. If your reward model is poor, any subsequent RLHF will also fail.
# 3. once you've trained the main model with RL, ask it to generate examples and explore how well it does. If it produces an obviously bad output, check if the reward model assigns high reward to that output. If yes, reward model is the culprit; if no, it's a question of better/longer PPO training.
#
# __It is also a good idea to periodically print samples during training.__
#
# __When stuck, simplify the problem.__ If you've spent a several hours enchanting the reward model but it still won't budge, try switching to a simple subtask. For instance, if you're training on hh-rlhf, try limiting it the dataset to 10% of the shortest sequences - they are typically easier to learn.
#
#
# ## Assignment stages (and grading)
#
# Regardless of the specific task you chose, your solution needs to contain several parts that will be graded separately.
#
#
# #### Stage 1: reward model
#
# Construct a dataset for training the reward model on your problem. Then, train a reward model on that dataset and evaluate how well can your model predict preferences on a hold-out (test) subset of your data.
#
# Please make sure that the part of your notebook where you evaluate reward model is clearly visible and reasonably easy to read. And for all that is holy, do not call it IMDB unless it actually **is** data of imdb movie reviews :)
#
# __Not all tasks require a reward model for later PPO fine-tuning.__ For instance, there's no reason to train a reward model if your reward equals sentence length. Likewise, toxicity reward can be estimated with a pre-trained toxicity classifier. __If your task does not require training a reward model, please train an unrelated model on [hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf) as though you were solving assignment version B.__ This is for grading purposes only, you won't use this model for stage 2.
#
#
# #### Stage 2: RL fine-tuning
#
# Once the reward model is ready - or you can compute rewards without a model - it is time to maximize that reward with PPO. Optionally, you may replace PPO with another RL algorithm (or unlikelihood learning scheme), but only if you're feeling adventurous.
#
#
# First, you need to choose a language model to be fine-tuned. You may choose any model, but make sure that your model **can** generate the data in your format. For instance, [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) is a general purpose LM and may (or may not) need prompt engineering to generate chat assistant responses. For that reason, it is best if you **do not use `"lvwerra/gpt2-imdb"` unless you're generating only movie reviews**.
#
#
#
# There are two "difficulty modes" for this task:
# For the **easy mode**, use [gpt2-large](https://huggingface.co/gpt2-large) or [opt-1.3b](https://huggingface.co/facebook/opt-1.3b) with minimal code changes.
# If you want the **Hard mode:** use a larger (e.g. 7B) model in combination with `load_in_4bit` and LoRA, the same way we did last week.
# Some reasonable model choices are [LLaMA-7B](https://huggingface.co/Enoch/llama-7b-hf), [Falcon-7b](https://huggingface.co/tiiuae/falcon-7b), [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) for general-purpose LM or [guanaco-7b](https://huggingface.co/timdettmers/guanaco-7b), [vicuna-7b](https://huggingface.co/lmsys/vicuna-7b-v1.5) for chat-based tasks, though there are many more (see [leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)). In the hard mode, you will need to modify the training arguments to enable 4-bit fine-tuning. Furthermore, your experiments will take somewhat longer to complete. On the plus side, your model will produce significantly better results.
#
# __High reward is not enough!__ RL algorithms are famous for [cheating their reward functions](https://openai.com/research/faulty-reward-functions). To ensure that your model is actually doing what you want it to do, you will need some additional evaluation. To get the full grade, provide at least 20 side-by-side examples of your fine-tuned model vs original model predictions and a short summary.
#
# Alternatively, you may provide 5 examples and some extrinsic evaluation metric over many examples. For instance, you may use a different pre-trained toxicity score for option A. When dealing with human preferences, you may choose to [enlist actual humans](https://toloka.ai/) or [ask GPT4/Claude](https://arxiv.org/pdf/2304.03277.pdf) to compare your model's predictions. For task C, when optimizing for simple rewards like sentence lengths, it is enough to compare histograms of rewards (e.g. average lengths).
