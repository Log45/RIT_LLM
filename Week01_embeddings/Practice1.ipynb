# %% [markdown]
# ## Practice 1: Fun with Word Embeddings (2 points)
#
# Today we gonna play with word embeddings: train our own little embeddings, load one from gensim model zoo and use it to visualize text corpora.
#
# This whole thing is gonna happen on top of embedding dataset.
#
# __Requirements:__  `pip install --upgrade nltk gensim bokeh` , but only if you're running locally.

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt 
#https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# zsh:1: no matches found: https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1

# %%
# !pip install --upgrade nltk gensim bokeh
# Out:
# Requirement already satisfied: nltk in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: gensim in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (4.3.3)
# Requirement already satisfied: bokeh in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: click in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from gensim) (7.1.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (1.3.0)
# Requirement already satisfied: packaging>=16.8 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from bokeh) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: wrapt in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Requirement already satisfied: six>=1.5 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)

# %%
import numpy as np

with open("./quora.txt", encoding="utf-8") as file:
    data = list(file)

data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %% [markdown]
# __Tokenization:__ a typical first step for an NLP task is to split raw data into words.
# The text we're working with has punctuation and emoticons attached to some words, so a simple str.split won't work.
#
# Let's use __`nltk`__ - a library that handles many NLP tasks like tokenization, stemming or part-of-speech tagging.

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
# TASK: lowercase everything and extract tokens with tokenizer.
# data_tok should be a list of lists of tokens for each line in data.

data_tok = [tokenizer.tokenize(line.lower()) for line in data]
data_tok
# Out:
# [['can',
#   'i',
#   'get',
#   'back',
#   'with',
#   'my',
#   'ex',
#   'even',
#   'though',
#   'she',
#   'is',
#   'pregnant',
#   'with',
#   'another',
#   'guy',
#   "'",
#   's',
#   'baby',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'ways',
#   'to',
#   'overcome',
#   'a',
#   'fast',
#   'food',
#   'addiction',
#   '?'],
#  ['who',
#   'were',
#   'the',
#   'great',
#   'chinese',
#   'soldiers',
#   'and',
#   'leaders',
#   'who',
#   'fought',
#   'in',
#   'ww2',
#   '?'],
#  ['what', 'are', 'zip', 'codes', 'in', 'the', 'bay', 'area', '?'],
#  ['why',
#   'was',
#   'george',
#   'rr',
#   'martin',
#   'critical',
#   'of',
#   'jk',
#   'rowling',
#   'after',
#   'losing',
#   'the',
#   'hugo',
#   'award',
#   '?'],
#  ['what', 'can', 'i', 'do', 'to', 'improve', 'my', 'immune', 'system', '?'],
#  ['how',
#   'is',
#   'your',
#   'relationship',
#   'with',
#   'your',
#   'mother',
#   'in',
#   'law',
#   '?'],
#  ['how',
#   'does',
#   'one',
#   'get',
#   'free',
#   'psn',
#   'codes',
#   '/',
#   'vita',
#   'codes',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'osquery', '?'],
#  ['how', 'can', 'i', 'look', 'smart', 'and', 'act', 'smart', '?'],
#  ['which',
#   'brand',
#   'should',
#   'go',
#   'with',
#   'the',
#   'gtx',
#   '960',
#   'graphic',
#   'card',
#   ',',
#   'msi',
#   ',',
#   'zotac',
#   'or',
#   'asus',
#   '?'],
#  ['what', 'is', 'the', 'zip', 'code', 'of', 'india', '?'],
#  ['as',
#   'an',
#   'indian',
#   'doctor',
#   'practicing',
#   'in',
#   'my',
#   'own',
#   'private',
#   'clinic',
#   '.',
#   'how',
#   'can',
#   'i',
#   'earn',
#   'more',
#   '?',
#   'what',
#   'other',
#   'sources',
#   'of',
#   'income',
#   'can',
#   'i',
#   'use',
#   '?'],
#  ['is',
#   'windows',
#   'the',
#   'only',
#   'os',
#   'that',
#   'is',
#   'not',
#   'based',
#   'on',
#   'unix',
#   'or',
#   'linux',
#   '?'],
#  ['how', 'can', 'i', 'avoid', 'using', 'facebook', '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'a',
#   'norton',
#   'security',
#   'renewal',
#   'code',
#   '?'],
#  ['does',
#   'emc',
#   'plan',
#   'a',
#   'lightweight',
#   'web',
#   'client',
#   'for',
#   'documentum',
#   '?'],
#  ['where',
#   'is',
#   'the',
#   'strangest',
#   'place',
#   'you',
#   "'",
#   've',
#   'ever',
#   'masturbated',
#   '?'],
#  ['tamil',
#   'nadu',
#   ',',
#   'india',
#   ':',
#   'what',
#   'can',
#   'we',
#   'learn',
#   'from',
#   'ex',
#   'cm',
#   'j',
#   '.',
#   'jayalalitha',
#   '?'],
#  ['which',
#   'car',
#   'should',
#   'i',
#   'buy',
#   'out',
#   'of',
#   'tiago',
#   ',',
#   'kwid',
#   ',',
#   'figo',
#   ',',
#   'datsun',
#   'or',
#   'any',
#   'other',
#   '?'],
#  ['who', 'discovered', 'plate', 'tectonics', 'and', 'how', '?'],
#  ['is',
#   'the',
#   'earth',
#   'the',
#   'only',
#   'planet',
#   'that',
#   'has',
#   'life',
#   'on',
#   'it',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'get',
#   'a',
#   'ride',
#   'on',
#   'a',
#   'civilian',
#   'c',
#   '-',
#   '130',
#   '?'],
#  ['what', 'does', 'entertainment', 'mean', 'for', 'you', '?'],
#  ['how',
#   'is',
#   'the',
#   'experience',
#   'to',
#   'be',
#   'an',
#   'extra',
#   'on',
#   'the',
#   'show',
#   '-',
#   'how',
#   'i',
#   'met',
#   'your',
#   'mother',
#   '?'],
#  ['will',
#   'windows',
#   'run',
#   'well',
#   'enough',
#   'to',
#   'use',
#   'excel',
#   'and',
#   'outlook',
#   'in',
#   'a',
#   'vm',
#   'on',
#   'the',
#   'new',
#   '2015',
#   'macbook',
#   '?'],
#  ['is',
#   'it',
#   'true',
#   'that',
#   'ancient',
#   'china',
#   'had',
#   'no',
#   'glass',
#   '?',
#   'or',
#   'was',
#   'it',
#   'no',
#   'clear',
#   'glass',
#   '?',
#   'or',
#   'not',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'ipad', 'mini', '2', '?'],
#  ['what', 'is', 'the', 'purpose', 'of', 'steam', 'turbine', '?'],
#  ['when',
#   'do',
#   'you',
#   'really',
#   'need',
#   'to',
#   'create',
#   'an',
#   'abstract',
#   'class',
#   '?'],
#  ['how', 'are', 'dalmatian', 'dogs', 'like', 'as', 'pets', '?'],
#  ['are',
#   'drivers',
#   'within',
#   'rich',
#   'countries',
#   'less',
#   'likely',
#   'to',
#   'slow',
#   'down',
#   'when',
#   'they',
#   'see',
#   'a',
#   'driver',
#   "'",
#   's',
#   'turn',
#   'signal',
#   '?'],
#  ['are', 'asian', 'girls', 'attracted', 'to', 'black', 'guys', '?'],
#  ['from',
#   'where',
#   'can',
#   'i',
#   'buy',
#   'castor',
#   'oil',
#   'for',
#   'hair',
#   'in',
#   'mumbai',
#   '?'],
#  ['does',
#   'cvs',
#   'still',
#   'develop',
#   'film',
#   '?',
#   'why',
#   'or',
#   'why',
#   'not',
#   '?'],
#  ['can', 'china', 'always', 'print', 'money', '?'],
#  ['what', 'is', 'fake', 'software', '?'],
#  ['how', 'do', 'students', 'at', 'iit', 'get', 'foreign', 'internships', '?'],
#  ['how', 'do', 'i', 'find', 'my', 'life', "'", 's', 'goal', '?'],
#  ['what', 'are', 'the', 'upcoming', 'mobiles', '?'],
#  ['what',
#   'is',
#   'the',
#   'chemical',
#   'formula',
#   'for',
#   'hydrochloric',
#   'acid',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'biggest',
#   'disneyland',
#   'in',
#   'the',
#   'world',
#   '?',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'get',
#   'entrance',
#   'tickets',
#   'for',
#   'it',
#   '?'],
#  ['how', 'does', 'the', 'finance', 'credit', 'score', 'work', '?'],
#  ['how', 'do', 'i', 'meet', 'foreign', 'guys', 'in', 'hong', 'kong', '?'],
#  ['is', 'the', 'atm', 'business', 'still', 'viable', '?'],
#  ['how',
#   'can',
#   'i',
#   'learn',
#   'to',
#   'speak',
#   'english',
#   'well',
#   'in',
#   'non',
#   '-',
#   'english',
#   'environment',
#   '?'],
#  ['can',
#   'a',
#   'high',
#   'school',
#   'student',
#   'get',
#   'an',
#   'internship',
#   'at',
#   'goldman',
#   'sachs',
#   '?'],
#  ['who', 'are', 'the', 'top', 'business', 'coaches', 'in', 'australia', '?'],
#  ['why', 'do', 'girls', 'wait', 'for', 'boys', 'to', 'propose', '?'],
#  ['should',
#   'cricket',
#   'be',
#   'our',
#   'national',
#   'sport',
#   'and',
#   'not',
#   'hockey',
#   '?'],
#  ['what',
#   'tv',
#   'shows',
#   'or',
#   'books',
#   'help',
#   'you',
#   'read',
#   'people',
#   "'",
#   's',
#   'body',
#   'language',
#   '?'],
#  ['i',
#   'see',
#   'this',
#   'cute',
#   'girl',
#   'around',
#   'my',
#   'college',
#   '.',
#   'i',
#   "'",
#   'm',
#   'too',
#   'shy',
#   'to',
#   'approach',
#   'her',
#   '.',
#   'is',
#   'it',
#   'acceptable',
#   'to',
#   'leave',
#   'her',
#   'a',
#   'note',
#   'with',
#   'my',
#   'feelings',
#   'and',
#   'number',
#   '?'],
#  ['what',
#   'schools',
#   'can',
#   'i',
#   'apply',
#   'for',
#   'with',
#   'a',
#   'gre',
#   'score',
#   'of',
#   'q',
#   '-',
#   '165',
#   'v',
#   '-',
#   '153',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'solution',
#   'for',
#   'this',
#   'quickbooks',
#   'error',
#   '12031',
#   '?'],
#  ['do',
#   'you',
#   'think',
#   'the',
#   'aap',
#   'will',
#   'fulfill',
#   'the',
#   'promises',
#   'they',
#   'mentioned',
#   'in',
#   'their',
#   'manifesto',
#   '?',
#   'why',
#   'and',
#   'how',
#   '?'],
#  ['what',
#   'are',
#   'all',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'having',
#   'dual',
#   'citizenship',
#   '?'],
#  ['can',
#   'someone',
#   'translate',
#   'this',
#   'one',
#   'from',
#   'italian',
#   'or',
#   'latin',
#   '?'],
#  ['what', 'is', '“', 'directive', '”?'],
#  ['what', 'is', 'the', 'density', 'and', 'volume', 'of', 'black', 'hole', '?'],
#  ['what', 'does', '"', 'las', 'vegas', '"', 'mean', '?'],
#  ['is',
#   'it',
#   'possible',
#   'to',
#   'lick',
#   'a',
#   'toad',
#   'and',
#   'get',
#   'high',
#   '?'],
#  ['who', 'nominates', 'the', 'president', 'of', 'india', '?'],
#  ['how',
#   'does',
#   'linkedin',
#   'work',
#   '?',
#   'i',
#   "'",
#   'm',
#   'getting',
#   'connections',
#   'so',
#   'now',
#   'what',
#   '?',
#   'how',
#   'do',
#   'i',
#   'find',
#   'a',
#   'job',
#   '?'],
#  ['how', 'can', 'i', 'record', 'a', 'facetime', 'call', 'on', 'a', 'mac', '?'],
#  ['what', 'are', 'the', 'application', 'of', 'binary', 'search', 'trees', '?'],
#  ['why',
#   'do',
#   'symptoms',
#   'persist',
#   'even',
#   'when',
#   'you',
#   'know',
#   'they',
#   'are',
#   'psychosomatic',
#   '?'],
#  ['what', 'are', 'the', 'best', 'digital', 'marketing', 'agencies', '?'],
#  ['why',
#   'is',
#   'my',
#   '128gb',
#   'micro',
#   'sd',
#   'card',
#   "'",
#   's',
#   'capacity',
#   'reduced',
#   'to',
#   '119gb',
#   '?',
#   'in',
#   'linux',
#   'it',
#   'showed',
#   '128gb',
#   '.',
#   'but',
#   'now',
#   'it',
#   'only',
#   'shows',
#   'said',
#   'capacity',
#   'even',
#   'in',
#   'ubuntu',
#   '.'],
#  ['did', 'you', 'visit', 'vietnam', '?'],
#  ['are', 'there', 'any', 'nobel', 'prize', 'winners', 'on', 'quora', '?'],
#  ['what', 'are', 'the', 'alternatives', 'to', 'walkme', '?'],
#  ['is', 'love', 'the', 'most', 'precious', 'thing', 'in', 'life', '?'],
#  ['how',
#   'can',
#   'i',
#   'download',
#   'cool',
#   'stuff',
#   'on',
#   'my',
#   'iphone',
#   'like',
#   'they',
#   'have',
#   'on',
#   'cydia',
#   'cause',
#   'i',
#   "'",
#   'm',
#   'not',
#   'jailbroken',
#   '?'],
#  ['how', 'do', 'i', 'start', 'investing', 'in', 'stocks', 'with', '100', '€?'],
#  ['what',
#   'is',
#   'quantitative',
#   'analysis',
#   'in',
#   'finance',
#   '?',
#   'how',
#   'is',
#   'it',
#   'applied',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'be',
#   'a',
#   'guest',
#   'speaker',
#   'on',
#   'npr',
#   '?'],
#  ['we',
#   'can',
#   "'",
#   't',
#   'see',
#   'the',
#   'universe',
#   'beyond',
#   'our',
#   'time',
#   'and',
#   'mind',
#   '.',
#   'why',
#   '?'],
#  ['what', 'does', 'a', 'programmer', 'do', 'at', 'their', 'job', '?'],
#  ['why',
#   'does',
#   'china',
#   'not',
#   'want',
#   'to',
#   'be',
#   'seen',
#   'as',
#   'a',
#   'superpower',
#   '?',
#   'while',
#   'india',
#   'is',
#   'very',
#   'keen',
#   'on',
#   'being',
#   'seen',
#   'as',
#   'one',
#   '?'],
#  ['for',
#   'the',
#   'g',
#   '+',
#   '5',
#   'building',
#   ',',
#   'what',
#   'is',
#   'the',
#   'minimum',
#   'steel',
#   'section',
#   'used',
#   'as',
#   'bracings',
#   'in',
#   'staad',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'most',
#   'epic',
#   'photos',
#   'ever',
#   'taken',
#   '?'],
#  ['why',
#   'do',
#   'our',
#   'feet',
#   'and',
#   'other',
#   'body',
#   'parts',
#   '"',
#   'fall',
#   'asleep',
#   '"?'],
#  ['who', 'are', 'the', 'true', 'muslims', ',', 'shia', 'or', 'sunni', '?'],
#  ['how',
#   'much',
#   'can',
#   'be',
#   'served',
#   'with',
#   'a',
#   'liter',
#   'bottle',
#   'of',
#   'vodka',
#   '?'],
#  ['why',
#   'do',
#   'people',
#   'pay',
#   'for',
#   'netflix',
#   'when',
#   'they',
#   'can',
#   'stream',
#   'online',
#   'for',
#   'free',
#   'and',
#   'in',
#   'better',
#   'quality',
#   '?'],
#  ['is', 'euthanasia', 'ever', 'morally', 'permissible', '?'],
#  ['is',
#   'it',
#   'worth',
#   'it',
#   'to',
#   'loose',
#   'your',
#   'virginity',
#   'as',
#   'a',
#   'freshman',
#   'in',
#   'high',
#   'school',
#   '?'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'about',
#   'rbi',
#   'directive',
#   'of',
#   'allowing',
#   'only',
#   'once',
#   'to',
#   'deposit',
#   'old',
#   'notes',
#   'in',
#   'bank',
#   'account',
#   '?'],
#  ['what',
#   'hill',
#   'station',
#   '/',
#   'picnic',
#   'spot',
#   'is',
#   'of',
#   'equal',
#   'distance',
#   'from',
#   'bangalore',
#   'and',
#   'pune',
#   '?'],
#  ['how', 'can', 'i', 'make', 'myself', 'read', 'an', 'entire', 'book', '?'],
#  ['how', 'do', 'you', 'become', 'chancellor', 'of', 'a', 'university', '?'],
#  ['if', 'trump', 'wins', 'will', 'there', 'be', 'a', 'nuclear', 'war', '?'],
#  ['how',
#   'do',
#   'i',
#   'prevent',
#   'users',
#   'on',
#   'the',
#   'same',
#   'netflix',
#   'account',
#   'from',
#   'seeing',
#   'my',
#   'profile',
#   '?'],
#  ['what', 'was', 'osama', 'bin', 'laden', 'like', 'as', 'a', 'person', '?'],
#  ['which',
#   'was',
#   'the',
#   'best',
#   'porn',
#   'video',
#   'you',
#   'have',
#   'ever',
#   'seen',
#   '?',
#   'why',
#   'was',
#   'that',
#   'the',
#   'best',
#   'one',
#   '?'],
#  ['how', 'can', 'i', 'get', 'sbi', 'transaction', 'id', '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'way',
#   'to',
#   'start',
#   'studying',
#   'for',
#   'a',
#   'career',
#   'in',
#   'cybersecurity',
#   '?'],
#  ['what', 'are', 'the', 'components', 'of', 'fitness', '?'],
#  ['what',
#   'is',
#   'the',
#   'good',
#   'approach',
#   'to',
#   'implement',
#   'rest',
#   'api',
#   'either',
#   'to',
#   'go',
#   'with',
#   'http',
#   'status',
#   'codes',
#   'or',
#   'creating',
#   'custom',
#   'error',
#   'field',
#   'by',
#   'always',
#   'returning',
#   '200',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'iupac',
#   'name',
#   'of',
#   'tert',
#   '-',
#   'butyl',
#   'chloride',
#   '?'],
#  ['how', 'similar', 'are', 'soylent', 'and', 'ensure', 'nutritionally', '?'],
#  ['what', 'is', 'the', 'future', 'of', 'sociology', 'education', '?'],
#  ['how', 'can', 'i', 'choose', 'to', 'make', 'the', 'right', 'decision', '?'],
#  ['what', 'does', 'void', '*', 'p', '=', '&', 'p', 'mean', 'in', 'c', '++?'],
#  ['can',
#   'you',
#   'take',
#   'mucinex',
#   'if',
#   'you',
#   'have',
#   'high',
#   'blood',
#   'pressure',
#   '?'],
#  ['which',
#   'universities',
#   'have',
#   'good',
#   'ph',
#   '.',
#   'd',
#   'programs',
#   'in',
#   'image',
#   'processing',
#   'and',
#   'computer',
#   'vision',
#   '?'],
#  ['what', 'is', 'your', 'favorite', 'moment', 'with', 'quora', '?'],
#  ['how', 'can', 'i', 'make', 'studying', 'more', 'interesting', '?'],
#  ['how',
#   'are',
#   'the',
#   'balloons',
#   'designed',
#   'and',
#   'built',
#   'for',
#   'the',
#   'macy',
#   "'",
#   's',
#   'thanksgiving',
#   'day',
#   'parade',
#   '?'],
#  ['what', 'is', 'the', 'significance', 'of', 'bicsi', 'cec', '?'],
#  ['how', 'do', 'you', 'set', 'a', 'honeywell', 'thermostat', '?'],
#  ['which',
#   'needs',
#   'more',
#   'power',
#   'in',
#   'a',
#   'laptop',
#   ',',
#   'gaming',
#   'or',
#   'video',
#   'editing',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'a',
#   'hindi',
#   'word',
#   'ब',
#   'े',
#   'दब',
#   'ी?'],
#  ['what',
#   'are',
#   'some',
#   'good',
#   'books',
#   'to',
#   'learn',
#   'data',
#   'structures',
#   'and',
#   'algorithms',
#   'for',
#   'a',
#   'beginner',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'answers',
#   'written',
#   'on',
#   'women',
#   'empowerment',
#   '?'],
#  ['what',
#   'makes',
#   'isis',
#   'attractive',
#   'for',
#   'the',
#   'youth',
#   'living',
#   'in',
#   'the',
#   'western',
#   'countries',
#   '?'],
#  ['what', 'is', 'adding', '1', '/', '2', 'to', '1', '/', '4', 'equals', '?'],
#  ['how',
#   'do',
#   'i',
#   'differentiate',
#   'between',
#   'human',
#   'and',
#   'animal',
#   'blood',
#   '?'],
#  ['what', 'is', 'the', 'difference', 'between', 'watts', 'and', 'lumens', '?'],
#  ['how', 'does', 'getting', 'a', 'divorce', 'change', 'your', 'life', '?'],
#  ['what', 'happens', 'to', 'my', 'stock', 'options', 'when', 'i', 'quit', '?'],
#  ['do', 'fetuses', 'suffer', 'during', 'an', 'abortion', '?'],
#  ['chefs',
#   ',',
#   'do',
#   'you',
#   'write',
#   'your',
#   'own',
#   'menus',
#   'for',
#   'cooking',
#   'at',
#   'home',
#   '?',
#   'i',
#   'made',
#   'a',
#   'static',
#   'menu',
#   'with',
#   'three',
#   'cuisines',
#   '.',
#   'do',
#   'you',
#   'have',
#   'tips',
#   'for',
#   'writing',
#   'menus',
#   '?'],
#  ['how', 'do', 'i', 'make', 'best', 'use', 'of', 'ieee', '?'],
#  ['what', 'are', 'the', 'uga', 'sat', 'score', 'requirements', '?'],
#  ['i',
#   'get',
#   'aroused',
#   'when',
#   'i',
#   'see',
#   'movie',
#   'scene',
#   'where',
#   'slave',
#   'get',
#   'whipped',
#   'and',
#   'get',
#   'excited',
#   'when',
#   'see',
#   'red',
#   'strips',
#   'on',
#   'their',
#   'back',
#   '.',
#   'is',
#   'it',
#   'normal',
#   '?'],
#  ['what',
#   'distinguishes',
#   'litigation',
#   'from',
#   'other',
#   'forms',
#   'of',
#   'legal',
#   'intervention',
#   '?'],
#  ['are', 'all', 'good', 'deeds', 'inherently', 'selfish', '?'],
#  ['which',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'horror',
#   'hollywood',
#   'movies',
#   'to',
#   'watch',
#   '?'],
#  ['in',
#   'the',
#   'case',
#   'of',
#   'a',
#   'power',
#   'plant',
#   ',',
#   'what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'synchronous',
#   'generator',
#   'and',
#   'an',
#   'asynchronous',
#   'generator',
#   '?',
#   'which',
#   'is',
#   'preferred',
#   'and',
#   'why',
#   '?'],
#  ['if',
#   'the',
#   'education',
#   'system',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'is',
#   'really',
#   'bad',
#   ',',
#   'why',
#   'are',
#   'people',
#   'all',
#   'over',
#   'the',
#   'world',
#   'coming',
#   'to',
#   'the',
#   'u',
#   '.',
#   's',
#   '.',
#   'for',
#   'education',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'scope',
#   'of',
#   'material',
#   'science',
#   'engineering',
#   '?'],
#  ['as',
#   'a',
#   'practising',
#   'financial',
#   'planner',
#   'in',
#   'india',
#   ',',
#   'how',
#   'much',
#   'have',
#   'you',
#   'been',
#   'able',
#   'to',
#   'make',
#   'in',
#   'terms',
#   'of',
#   'advisory',
#   'fee',
#   'alone',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'digital',
#   'marketing',
#   'company',
#   'in',
#   'pune',
#   '?'],
#  ['what',
#   'stats',
#   'prove',
#   'that',
#   'after',
#   'school',
#   'activities',
#   'combat',
#   'the',
#   'achievement',
#   'gap',
#   'and',
#   'promote',
#   'college',
#   'admissions',
#   '?'],
#  ['how', 'do', 'i', 'pronounce', 'òló', '?'],
#  ['i',
#   'have',
#   'not',
#   'paid',
#   'amount',
#   'for',
#   'taking',
#   'parents',
#   'in',
#   'tu',
#   'convocation',
#   ',',
#   'can',
#   'i',
#   'take',
#   'them',
#   '?'],
#  ['opportunities', 'after', 'phd', 'in', 'sweden', 'in', 'medicine', '?'],
#  ['what',
#   'are',
#   'the',
#   'automobile',
#   'projects',
#   'related',
#   'to',
#   'design',
#   'and',
#   'analysis',
#   'of',
#   'automobile',
#   'part',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'basic',
#   'computer',
#   'knowledge',
#   'that',
#   'everyone',
#   'should',
#   'know',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'well',
#   'known',
#   'start',
#   '-',
#   'up',
#   'or',
#   'venture',
#   'capital',
#   'firms',
#   '?'],
#  ['which',
#   'are',
#   'the',
#   'best',
#   'colleges',
#   'in',
#   'usa',
#   'for',
#   'aerospace',
#   'engineering',
#   '?'],
#  ['why',
#   'are',
#   'some',
#   'items',
#   'made',
#   'of',
#   'wool',
#   'so',
#   'itchy',
#   ',',
#   'but',
#   'others',
#   'soft',
#   '?'],
#  ['how',
#   'do',
#   'people',
#   'get',
#   'obese',
#   '?',
#   'do',
#   'they',
#   'eat',
#   'a',
#   'lot',
#   'more',
#   'than',
#   'the',
#   'average',
#   'person',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'wireless',
#   'internet',
#   'for',
#   'a',
#   'desktop',
#   'computer',
#   '?'],
#  ['what', 'is', 'your', 'favorite', 'song', 'at', 'the', 'moment', '?'],
#  ['can', 'cancer', 'be', 'cured', 'by', 'healing', '?'],
#  ['what', 'kind', 'of', 'pens', 'write', 'much', 'better', '?'],
#  ['why',
#   'men',
#   'don',
#   "'",
#   't',
#   'take',
#   'divorced',
#   'woman',
#   'seriously',
#   '?'],
#  ['can', 'we', 'trust', 'chegg', '?', 'did', 'anybody', 'got', 'paid', '?'],
#  ['which',
#   'is',
#   'better',
#   ',',
#   '5',
#   'gb',
#   'ram',
#   'with',
#   'core',
#   'i3',
#   'or',
#   '2',
#   'gb',
#   'ram',
#   'with',
#   'i5',
#   'processor',
#   'for',
#   'android',
#   'studio',
#   '?'],
#  ['have', 'you', 'ever', 'changed', 'a', 'deeply', 'held', 'opinion', '?'],
#  ['what', 'is', 'depersonalization', 'disorder', '?'],
#  ['why',
#   'can',
#   "'",
#   't',
#   'you',
#   'use',
#   'wifi',
#   'while',
#   'running',
#   'a',
#   'wifi',
#   'hotspot',
#   '?'],
#  ['what', 'is', 'the', 'best', 'lg', 'g3', 'app', '?'],
#  ['what',
#   'are',
#   'the',
#   'expectations',
#   'of',
#   'indian',
#   'women',
#   'from',
#   'their',
#   'partners',
#   'during',
#   'sex',
#   '?'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'the',
#   'story',
#   'of',
#   'my',
#   'experiments',
#   'with',
#   'truth',
#   '(',
#   'book',
#   ')',
#   'by',
#   'mahatma',
#   'gandhi',
#   '?'],
#  ['what', 'is', 'the', 'most', 'beautiful', 'scandinavian', 'country', '?'],
#  ['where', 'can', 'i', 'download', 'a', 'free', 'ebook', 'in', 'french', '?'],
#  ['what',
#   'is',
#   'something',
#   'that',
#   'you',
#   'know',
#   'that',
#   'i',
#   'don',
#   "'",
#   't',
#   '?'],
#  ['how',
#   'did',
#   'the',
#   'academy',
#   'awards',
#   'come',
#   'to',
#   'be',
#   'called',
#   '"',
#   'the',
#   'oscars',
#   '"?'],
#  ['does', 'the', 'percy', 'jackson', 'movie', 'suck', '?'],
#  ['what',
#   'is',
#   'the',
#   'easy',
#   'way',
#   'to',
#   'use',
#   'a',
#   'delhi',
#   'bike',
#   'in',
#   'hyderabad',
#   '?'],
#  ['was',
#   'muhammed',
#   'a',
#   'narcissist',
#   'who',
#   'used',
#   'to',
#   'receive',
#   'convenient',
#   'revelations',
#   'for',
#   'his',
#   'benefit',
#   '?'],
#  ['what', 'is', 'the', 'force', 'of', 'a', 'wolf', 'bite', '?'],
#  ['how',
#   'do',
#   'you',
#   'use',
#   'the',
#   'slack',
#   'tool',
#   'for',
#   'team',
#   'communication',
#   '?',
#   'what',
#   'pain',
#   'points',
#   'is',
#   'it',
#   'solving',
#   'for',
#   'you',
#   '?',
#   'how',
#   'do',
#   'you',
#   'share',
#   'files',
#   'with',
#   'slack',
#   'for',
#   'team',
#   'review',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'intermediate',
#   'value',
#   'theorem',
#   '?',
#   'how',
#   'do',
#   'you',
#   'find',
#   'it',
#   '?'],
#  ['what',
#   'is',
#   'meant',
#   'by',
#   'mainstream',
#   'culture',
#   'and',
#   'what',
#   'would',
#   'be',
#   'a',
#   'noteworthy',
#   'example',
#   'of',
#   'it',
#   '?'],
#  ['what',
#   'causes',
#   'the',
#   'underside',
#   'of',
#   'my',
#   'eye',
#   'to',
#   'twitch',
#   '?'],
#  ['does',
#   'santa',
#   'live',
#   'at',
#   'the',
#   'north',
#   'pole',
#   ',',
#   'or',
#   'was',
#   'there',
#   'really',
#   'a',
#   'mandela',
#   'effect',
#   'that',
#   'moved',
#   'him',
#   'to',
#   'finland',
#   '?'],
#  ['what', 'are', 'the', 'main', 'components', 'of', 'a', 'cologne', '?'],
#  ['did', 'noam', 'chomsky', 'ever', 'meet', 'bertrand', 'russell', '?'],
#  ['i',
#   "'",
#   'm',
#   'a',
#   '23',
#   'year',
#   'old',
#   'boy',
#   'with',
#   '58',
#   'kgs',
#   'weight',
#   'and',
#   'my',
#   'height',
#   'is',
#   '168',
#   'cms',
#   '.',
#   'do',
#   'i',
#   'still',
#   'have',
#   'a',
#   'chance',
#   'to',
#   'increase',
#   'my',
#   'height',
#   '?',
#   'if',
#   'yes',
#   ',',
#   'what',
#   'food',
#   'habits',
#   'should',
#   'i',
#   'follow',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'calculate',
#   'the',
#   'required',
#   'length',
#   'of',
#   'a',
#   'water',
#   'filled',
#   'pipe',
#   'that',
#   'is',
#   'gravity',
#   'fed',
#   'into',
#   'a',
#   'container',
#   '?',
#   'i',
#   "'",
#   'd',
#   'want',
#   'to',
#   'avoid',
#   'overfilling',
#   'the',
#   'container',
#   '.'],
#  ['how',
#   'do',
#   'i',
#   'keep',
#   'myself',
#   'motivated',
#   'during',
#   'hard',
#   'times',
#   '?'],
#  ['is', 'drinking', 'redbull', 'bad', 'for', 'health', '?'],
#  ['which', 'are', 'best', 'wifi', 'devices', '?'],
#  ['which', 'is', 'best', 'phone', 'under', '12k', '?'],
#  ['as',
#   'an',
#   'engineering',
#   'student',
#   'who',
#   'loves',
#   'science',
#   'but',
#   'is',
#   'coming',
#   'to',
#   'hate',
#   'engineering',
#   ',',
#   'what',
#   'possible',
#   'cure',
#   'do',
#   'i',
#   'have',
#   '?'],
#  ['how',
#   'is',
#   'your',
#   'jet',
#   'black',
#   'iphone',
#   '7',
#   'holding',
#   'up',
#   'against',
#   'scratches',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'convert',
#   'a',
#   'kolkata',
#   'registration',
#   'privately',
#   'owned',
#   'car',
#   'to',
#   'commercial',
#   'one',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'tips',
#   'for',
#   'investing',
#   'in',
#   'an',
#   'airbnb',
#   'property',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'expensive',
#   'phone',
#   'in',
#   'the',
#   'world',
#   '?'],
#  ['i',
#   'sent',
#   'a',
#   'message',
#   'in',
#   'whatsapp',
#   '.',
#   'it',
#   'says',
#   'sent',
#   ',',
#   'not',
#   'delivered',
#   '.',
#   'was',
#   'it',
#   'seen',
#   '?'],
#  ['what', 'are', 'some', 'good', 'early', 'morning', 'habits', '?'],
#  ['which', 'custom', 'rom', 'is', 'best', '?'],
#  ['does',
#   'whatsapp',
#   'web',
#   'work',
#   'even',
#   'if',
#   'the',
#   'computer',
#   'and',
#   'the',
#   'phone',
#   'are',
#   'kilometers',
#   'away',
#   '?',
#   'is',
#   'an',
#   'internet',
#   'connection',
#   'the',
#   'only',
#   'requirement',
#   '?'],
#  ['how', 'do', 'i', 'hit', 'big', 'shots', 'in', 'cricket', '?'],
#  ['i',
#   'am',
#   'a',
#   'female',
#   'capricorn',
#   'sun',
#   'sign',
#   ',',
#   'cancer',
#   'moon',
#   'sign',
#   'and',
#   'libra',
#   'rising',
#   'star',
#   '.',
#   'can',
#   'you',
#   'guess',
#   'what',
#   'i',
#   "'",
#   'm',
#   'like',
#   '?'],
#  ['can', 'i', 'find', 'some', 'answers', 'to', 'etg', 'testing', '?'],
#  ['what', 'are', 'some', 'examples', 'of', 'monopolies', 'in', 'india', '?'],
#  ['what', 'are', 'the', 'pros', '&', 'cons', 'of', 'having', 'children', '?'],
#  ['what', 'does', 'stack', 'overflow', 'lack', '?'],
#  ['how', 'can', 'i', 'find', 'a', 'pro', 'bono', 'lawyer', '?'],
#  ['two', 'bank', 'accounts', 'in', 'same', 'bank', '?'],
#  ['what', 'do', 'you', 'think', 'this', 'painting', 'means', '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'workouts',
#   'for',
#   'building',
#   'back',
#   'muscles',
#   '?'],
#  ['if',
#   'america',
#   'were',
#   'attacked',
#   'by',
#   '10',
#   'million',
#   'foreign',
#   'troops',
#   ',',
#   'could',
#   'they',
#   'handle',
#   'it',
#   '?',
#   'if',
#   'not',
#   'how',
#   'long',
#   'would',
#   'they',
#   'have',
#   'to',
#   'wait',
#   'for',
#   'help',
#   'to',
#   'arrive',
#   '?'],
#  ['are',
#   'there',
#   'any',
#   'alternative',
#   'question',
#   'and',
#   'answer',
#   'websites',
#   'to',
#   'quora',
#   '?'],
#  ['how', 'do', 'we', 'observe', 'planets', 'with', 'radio', 'telescopes', '?'],
#  ['is',
#   'there',
#   'any',
#   'theory',
#   'that',
#   'explains',
#   'that',
#   'demonic',
#   'possessions',
#   'are',
#   'some',
#   'invention',
#   'for',
#   'making',
#   'people',
#   'get',
#   'interested',
#   'in',
#   'religion',
#   '?'],
#  ['do', 'i', 'have', 'to', 'wear', 'a', 'sports', 'bra', 'to', 'gym', '?'],
#  ['what',
#   'are',
#   'personality',
#   'types',
#   'and',
#   'disorders',
#   'that',
#   'make',
#   'a',
#   'person',
#   'unable',
#   'to',
#   'feel',
#   'intimacy',
#   'and',
#   'impulse',
#   'to',
#   'limit',
#   'socializing',
#   'and',
#   'personal',
#   'relationships',
#   '?'],
#  ['if',
#   'earth',
#   'had',
#   'no',
#   'atmosphere',
#   'would',
#   'the',
#   'sky',
#   'appear',
#   'black',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'coaching',
#   'for',
#   'medical',
#   'entrance',
#   'in',
#   'nagpur',
#   '?'],
#  ['which',
#   'books',
#   'do',
#   'you',
#   'recommend',
#   'for',
#   'the',
#   'ca',
#   'ipcc',
#   'for',
#   'both',
#   'groups',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'pursue',
#   'journalism',
#   'after',
#   'my',
#   'b',
#   '.',
#   'tech',
#   '.',
#   'degree',
#   '?'],
#  ['how', 'come', 'all', 'countries', 'are', 'in', 'debt', '?'],
#  ['what', '’', 's', 'your', 'creative', 'process', '?'],
#  ['how',
#   'did',
#   'you',
#   'honestly',
#   'feel',
#   'finding',
#   'out',
#   'you',
#   'had',
#   'been',
#   'cheated',
#   'on',
#   'and',
#   'has',
#   'it',
#   'changed',
#   'you',
#   '?'],
#  ['which', 'are', 'the', 'rarest', 'world', 'war', 'pictures', '?'],
#  ['how',
#   'do',
#   'you',
#   'cook',
#   'a',
#   'chicken',
#   'breast',
#   'in',
#   'a',
#   'oven',
#   '?'],
#  ['why',
#   'do',
#   'indians',
#   'spend',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'on',
#   'marriage',
#   ',',
#   'rather',
#   'than',
#   'americans',
#   'or',
#   'europeans',
#   '?'],
#  ['should', 'we', 'all', 'buy', 'apple', 'stock', 'now', '?'],
#  ['is',
#   'there',
#   'really',
#   'a',
#   'chip',
#   'embedded',
#   'in',
#   'the',
#   'new',
#   'rupees',
#   '2000',
#   'note',
#   '?'],
#  ['is',
#   'there',
#   'a',
#   'difference',
#   'in',
#   'feeling',
#   'versus',
#   'measuring',
#   'progress',
#   'in',
#   'actually',
#   'making',
#   'progress',
#   '?'],
#  ['how', 'do', 'i', 'contact', 'airbnb', 'customer', 'support', '?'],
#  ['is', 'mcom', 'worth', 'doing', 'from', 'srcc', '?'],
#  ['what',
#   'are',
#   'the',
#   'dangers',
#   'of',
#   'taking',
#   'valium',
#   'and',
#   'percocet',
#   'at',
#   'the',
#   'same',
#   'time',
#   '?'],
#  ['what', 'is', 'the', 'best', 'glue', 'for', 'shoe', 'repair', '?'],
#  ['my',
#   'percentage',
#   'is',
#   '62',
#   '%',
#   'in',
#   'b',
#   '.',
#   'tech',
#   '.',
#   'i',
#   'want',
#   'to',
#   'join',
#   'into',
#   'niit',
#   'institute',
#   '.',
#   'do',
#   'they',
#   'provide',
#   'me',
#   'a',
#   'job',
#   'in',
#   'good',
#   'mnc',
#   "'",
#   's',
#   'with',
#   'that',
#   'percentage',
#   '.',
#   'how',
#   'worthytojoin',
#   'niit',
#   '?'],
#  ['how',
#   'can',
#   'an',
#   'unhealthy',
#   'woman',
#   'like',
#   'hillary',
#   'become',
#   'the',
#   'president',
#   'of',
#   'the',
#   'usa',
#   '?',
#   'dont',
#   'her',
#   'supporters',
#   'know',
#   'that',
#   'she',
#   'is',
#   'terribly',
#   'ill',
#   '?'],
#  ['amazon',
#   'interview',
#   ':',
#   'what',
#   'is',
#   'the',
#   'best',
#   'answer',
#   'to',
#   'the',
#   'question',
#   '"',
#   'why',
#   'amazon',
#   '?"?'],
#  ['what', 'does', 'a', '.', 'd', 'stand', 'for', '?'],
#  ['how',
#   'do',
#   'you',
#   'cut',
#   'line',
#   'externally',
#   'and',
#   'internally',
#   'in',
#   'maths',
#   '?'],
#  ['can',
#   'we',
#   'prepare',
#   'for',
#   'the',
#   'jee',
#   'main',
#   'in',
#   'the',
#   'last',
#   '4',
#   'months',
#   'and',
#   'get',
#   '180',
#   'or',
#   'more',
#   '?',
#   'i',
#   'have',
#   'studied',
#   'well',
#   'but',
#   'low',
#   'on',
#   'confidence'],
#  ['what',
#   'will',
#   'happen',
#   'to',
#   'a',
#   'person',
#   'who',
#   'has',
#   'bot',
#   'opposite',
#   'phobia',
#   'apeirophobia',
#   'and',
#   'thanatophobia',
#   '?'],
#  ['will',
#   'slow',
#   'and',
#   'smooth',
#   'driving',
#   'of',
#   'two',
#   'wheeler',
#   'in',
#   'indian',
#   'road',
#   'conditions',
#   'prevent',
#   'back',
#   '/',
#   'spine',
#   'related',
#   'problems',
#   '?'],
#  ['how', 'should', 'i', 'live', 'my', 'life', '?'],
#  ['how', 'do', 'i', 'overcome', 'pimples', 'due', 'to', 'pcod', '?'],
#  ['what', 'will', 'be', 'the', 'journal', 'entries', 'for', 'discount', '?'],
#  ['what',
#   'is',
#   'the',
#   'maximum',
#   'number',
#   'of',
#   'times',
#   'you',
#   'can',
#   'fold',
#   'a',
#   'piece',
#   'of',
#   'paper',
#   '?'],
#  ['as',
#   'shia',
#   'is',
#   'a',
#   'denomination',
#   'of',
#   'islam',
#   ',',
#   'why',
#   'is',
#   'the',
#   'shia',
#   'majority',
#   'iraq',
#   'being',
#   'opposed',
#   'by',
#   'isis',
#   '(',
#   'islamic',
#   'state',
#   'of',
#   'iraq',
#   'and',
#   'syria',
#   ')?'],
#  ['how', 'can', 'approach', 'guy', 'i', 'like', '?'],
#  ['can',
#   'hillary',
#   'clinton',
#   'pardon',
#   'herself',
#   'if',
#   'she',
#   'is',
#   'elected',
#   'as',
#   'president',
#   '?'],
#  ['is',
#   'it',
#   'too',
#   'late',
#   'for',
#   'any',
#   'age',
#   'person',
#   'to',
#   'learn',
#   'computer',
#   'programing',
#   '?'],
#  ['i',
#   'am',
#   'doing',
#   'bachelors',
#   'in',
#   'computer',
#   'science',
#   '.',
#   'i',
#   'will',
#   'be',
#   'done',
#   'with',
#   'my',
#   '4th',
#   'semester',
#   'in',
#   'few',
#   'days',
#   '.',
#   'i',
#   'have',
#   '3',
#   'month',
#   'of',
#   'summer',
#   'vacation',
#   'ahead',
#   ',',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'i',
#   'can',
#   'utilize',
#   'these',
#   '3',
#   'months',
#   'so',
#   'i',
#   'can',
#   'land',
#   'a',
#   'good',
#   'internship',
#   '/',
#   'job',
#   'in',
#   'future',
#   'at',
#   'a',
#   'top',
#   'notch',
#   'company',
#   'like',
#   'microsoft',
#   ',',
#   'google',
#   ',',
#   'facebook',
#   'etc',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'point',
#   'and',
#   'shoot',
#   'camera',
#   'under',
#   '7k',
#   '?'],
#  ['how', 'do', 'i', 'research', 'for', 'mun', '?'],
#  ['how',
#   'do',
#   'you',
#   'know',
#   'if',
#   'your',
#   'boyfriend',
#   'actually',
#   'loves',
#   'you',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'books',
#   'required',
#   'for',
#   'b',
#   '.',
#   'tech',
#   'it',
#   'first',
#   'year',
#   '?'],
#  ['what', 'are', 'some', 'spanish', 'inventions', 'we', 'use', 'daily', '?'],
#  ['how',
#   'will',
#   'you',
#   'ensure',
#   'that',
#   'that',
#   'the',
#   'next',
#   'military',
#   'intervention',
#   'by',
#   'us',
#   'is',
#   'a',
#   'genuine',
#   'one',
#   '?'],
#  ['which', 'human', 'race', 'is', 'most', 'evolved', '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'coaching',
#   'institute',
#   'for',
#   'cfa',
#   'in',
#   'chennai',
#   '?'],
#  ['is',
#   'there',
#   'a',
#   'free',
#   'version',
#   'of',
#   'vmware',
#   'vsphere',
#   'hypervisor',
#   '?',
#   'if',
#   'not',
#   ',',
#   'which',
#   'are',
#   'some',
#   'effective',
#   'alternatives',
#   '?'],
#  ['what', 'does', 'the', '12th', 'amendment', 'mean', '?'],
#  ['how',
#   'would',
#   'you',
#   'describe',
#   'india',
#   'in',
#   'one',
#   'sentence',
#   'to',
#   'someone',
#   'from',
#   'north',
#   'america',
#   'who',
#   'has',
#   'never',
#   'been',
#   'to',
#   'india',
#   '?'],
#  ['which',
#   'book',
#   'is',
#   'better',
#   'for',
#   'understand',
#   'basics',
#   'sterength',
#   'of',
#   'material',
#   '?'],
#  ['what',
#   'does',
#   'shakespeare',
#   'mean',
#   'by',
#   "'",
#   'a',
#   'little',
#   'more',
#   'than',
#   'kin',
#   ',',
#   'and',
#   'less',
#   'than',
#   'kind',
#   "'?"],
#  ['can',
#   'eating',
#   'boiled',
#   'egg',
#   'or',
#   'omelette',
#   'cause',
#   'bird',
#   'flu',
#   '?'],
#  ['should',
#   'i',
#   'try',
#   'to',
#   'find',
#   'out',
#   'who',
#   'my',
#   'birth',
#   'father',
#   'is',
#   '?'],
#  ['how',
#   'much',
#   'initial',
#   'capital',
#   'would',
#   'you',
#   'need',
#   'to',
#   'become',
#   'an',
#   'investor',
#   'successfully',
#   'like',
#   'warren',
#   'buffet',
#   'if',
#   'you',
#   'are',
#   '21',
#   '?'],
#  ['why', 'is', 'the', 'singapore', 'education', 'system', 'so', 'good', '?'],
#  ['is', 'your', 'education', 'worth', 'it', '?'],
#  ['would',
#   'it',
#   'be',
#   'feasible',
#   'to',
#   'genetically',
#   'engineer',
#   'humans',
#   'to',
#   'have',
#   'two',
#   'hearts',
#   '?'],
#  ['has',
#   'any',
#   'us',
#   'presidential',
#   'candidate',
#   'sold',
#   'cabinet',
#   'positions',
#   'in',
#   'his',
#   'administration',
#   'in',
#   'return',
#   'for',
#   'campaign',
#   'contributions',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'north',
#   'indian',
#   'food',
#   'restaurant',
#   'in',
#   'karkardooma',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'bass', 'fish', 'trap', '?'],
#  ['does', 'lime', 'juice', 'go', 'bad', '?'],
#  ['what', 'are', 'disadvantages', 'of', 'a', 'love', 'marriage', '?'],
#  ['can', 'i', 'change', 'my', 'branch', 'in', 'davv', 'indore', '?'],
#  ['how', 'much', 'are', 'diamonds', 'worth', '?'],
#  ['what', 'is', 'a', 'fair', 'startup', 'salary', '?'],
#  ['which', 'are', 'best', 'private', 'medical', 'colleges', '?'],
#  ['what',
#   'are',
#   'the',
#   'lyrics',
#   'for',
#   "'",
#   'what',
#   'is',
#   'love',
#   "?'",
#   'by',
#   'haddaway',
#   '?'],
#  ['if',
#   'you',
#   'throw',
#   'up',
#   'within',
#   '30',
#   'minutes',
#   'of',
#   'eating',
#   ',',
#   'how',
#   'many',
#   'calories',
#   'do',
#   'you',
#   'lose',
#   'of',
#   'the',
#   'food',
#   'you',
#   'ate',
#   '?'],
#  ['how', 'do', 'i', 'participate', 'in', 'splitsvilla', '?'],
#  ['which',
#   'it',
#   'companies',
#   'in',
#   'kolkata',
#   'offer',
#   'internships',
#   'to',
#   'bca',
#   'students',
#   '?'],
#  ['how', 'do', 'i', 'bolster', 'my', 'self', '-', 'esteem', '?'],
#  ['how', 'do', 'i', 'teach', 'a', 'child', 'to', 'read', 'and', 'write', '?'],
#  ['how',
#   'do',
#   'we',
#   'prove',
#   '[',
#   'math',
#   '](',
#   '1',
#   '+\\',
#   'frac',
#   '{',
#   '1',
#   '}{',
#   'n',
#   '})^',
#   'n',
#   '<',
#   '(',
#   '1',
#   '+',
#   '\\',
#   'frac',
#   '{',
#   '1',
#   '}{',
#   'n',
#   '+',
#   '1',
#   '})^{',
#   'n',
#   '+',
#   '1',
#   '}[/',
#   'math',
#   ']?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'inheritance',
#   ',',
#   'encapsulation',
#   'and',
#   'polymorphism',
#   '?'],
#  ['why', 'have', 'i', 'not', 'seen', 'my', 'period', '?'],
#  ['how', 'can', 'i', 'read', 'this', 'time', '?'],
#  ['what',
#   'is',
#   'the',
#   'prescribed',
#   'book',
#   'for',
#   'mechanical',
#   'engineer',
#   'students',
#   'to',
#   'clear',
#   'the',
#   'isro',
#   'scientist',
#   '/',
#   'engineer',
#   'sc',
#   'exam',
#   '?'],
#  ['i',
#   'have',
#   'still',
#   'not',
#   'prepared',
#   'constructions',
#   ',',
#   'locus',
#   'and',
#   'graphs',
#   'in',
#   'maths',
#   '.',
#   'would',
#   'i',
#   'will',
#   'be',
#   'able',
#   'to',
#   'score',
#   '100',
#   'in',
#   'icse',
#   'maths',
#   '?'],
#  ['what',
#   'ethical',
#   'issues',
#   'do',
#   'operators',
#   'of',
#   'restaurant',
#   'need',
#   'to',
#   'be',
#   'aware',
#   'of',
#   '?'],
#  ['how',
#   'much',
#   'money',
#   'are',
#   'artists',
#   'currently',
#   'making',
#   'off',
#   'of',
#   'spotify',
#   '?'],
#  ['which',
#   'episode',
#   'of',
#   'star',
#   'trek',
#   '(',
#   'tos',
#   ')',
#   'features',
#   'slimy',
#   'things',
#   'which',
#   'gets',
#   'itself',
#   'glued',
#   'to',
#   'the',
#   'crew',
#   '?'],
#  ['which',
#   'is',
#   'a',
#   'suitable',
#   'inpatient',
#   'drug',
#   'and',
#   'alcohol',
#   'rehab',
#   'center',
#   'near',
#   'putnam',
#   'county',
#   'in',
#   '?'],
#  ['are', 'a', 'grades', 'enough', 'to', 'get', 'into', 'cambridge', '?'],
#  ['how',
#   'good',
#   'is',
#   'the',
#   '17',
#   'hmr',
#   'rifle',
#   'for',
#   'coyote',
#   'hunting',
#   '?'],
#  ['i',
#   'got',
#   'letter',
#   'of',
#   'intent',
#   'to',
#   'hire',
#   'from',
#   'infosys',
#   '.',
#   'will',
#   'i',
#   'be',
#   'surely',
#   'called',
#   'by',
#   'infosys',
#   '?'],
#  ['how', 'does', 'raspberry', 'pi', 'work', '?'],
#  ['how', 'long', 'does', 'it', 'take', 'to', 'open', 'an', 'llc', '?'],
#  ['what',
#   'is',
#   'your',
#   'opinion',
#   'of',
#   'the',
#   'quote',
#   ':',
#   '"',
#   'most',
#   'people',
#   "'",
#   's',
#   'lives',
#   'are',
#   'a',
#   'direct',
#   'reflection',
#   'of',
#   'the',
#   'expectations',
#   'of',
#   'their',
#   'peer',
#   'group',
#   '"?'],
#  ['scope',
#   'for',
#   'cse',
#   '(',
#   'b',
#   '.',
#   'tech',
#   '/',
#   'b',
#   '.',
#   'e',
#   '.)',
#   'graduates',
#   'to',
#   'get',
#   'foreign',
#   'job',
#   '?',
#   'if',
#   'yes',
#   ',',
#   'then',
#   'how',
#   '?'],
#  ['where',
#   'should',
#   'i',
#   'go',
#   'to',
#   'get',
#   'cheap',
#   'goats',
#   'milk',
#   'in',
#   'the',
#   'uk',
#   '?'],
#  ['i',
#   'am',
#   'an',
#   'arts',
#   'graduate',
#   ',',
#   'can',
#   'do',
#   'rhce',
#   'certification',
#   '.',
#   'and',
#   'get',
#   'a',
#   'job',
#   'in',
#   'india',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'creative',
#   'way',
#   'you',
#   'can',
#   'break',
#   'a',
#   'clock',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'solve',
#   'the',
#   'following',
#   'problem',
#   '?',
#   'is',
#   'it',
#   'possible',
#   'to',
#   'solve',
#   'using',
#   'segment',
#   'trees',
#   '?',
#   'are',
#   'there',
#   'any',
#   'efficient',
#   'methods',
#   '?'],
#  ['what',
#   'can',
#   'i',
#   'use',
#   'to',
#   'host',
#   'a',
#   '1',
#   'table',
#   'database',
#   'that',
#   'will',
#   'be',
#   'used',
#   'by',
#   'a',
#   'mobile',
#   'app',
#   '?'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'declutter',
#   'my',
#   'life',
#   'and',
#   'become',
#   'a',
#   'minimalist',
#   '.',
#   'i',
#   'am',
#   'finding',
#   'it',
#   'i',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'stuff',
#   '.',
#   'is',
#   'there',
#   'a',
#   'way',
#   'to',
#   'outsource',
#   'this',
#   '?'],
#  ['how', 'are', 'long', 'distance', 'relationships', 'maintained', '?'],
#  ['how',
#   'many',
#   'worlds',
#   'are',
#   'there',
#   'in',
#   'super',
#   'mario',
#   'bros',
#   '.',
#   'wii',
#   '?'],
#  ['what', 'are', 'examples', 'of', 'brilliant', 'medical', 'strategy', '?'],
#  ['do', 'physical', 'laws', 'change', 'over', 'time', '?'],
#  ['did',
#   'mark',
#   'zuckerberg',
#   'steal',
#   'the',
#   'idea',
#   'of',
#   'facebook',
#   'from',
#   'cameron',
#   'winklevoss',
#   '?'],
#  ['what',
#   'kind',
#   'of',
#   'advanced',
#   'c',
#   '++',
#   'features',
#   'i',
#   'need',
#   'to',
#   'learn',
#   'if',
#   'i',
#   'want',
#   'to',
#   'work',
#   'for',
#   'google',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'activate',
#   'two',
#   'jio',
#   'sims',
#   'in',
#   'one',
#   'phone',
#   '?'],
#  ['what', 'are', 'the', 'ranks', 'in', 'the', 'navy', 'seals', '?'],
#  ['which',
#   'software',
#   'is',
#   'best',
#   'for',
#   'stock',
#   'and',
#   'options',
#   'automated',
#   'trading',
#   'in',
#   'india',
#   '?'],
#  ['what', 'animals', 'begin', 'with', 'the', 'letter', 'x', '?'],
#  ['why',
#   'don',
#   "'",
#   't',
#   'more',
#   'americans',
#   'aspire',
#   'to',
#   'public',
#   'sector',
#   '/',
#   'civil',
#   'service',
#   'jobs',
#   '?'],
#  ['did',
#   'god',
#   'punish',
#   'slave',
#   'master',
#   "'",
#   's',
#   'who',
#   'didn',
#   "'",
#   't',
#   'treat',
#   'their',
#   'slaves',
#   'fairly',
#   '?'],
#  ['which',
#   'two',
#   'bollywood',
#   'actors',
#   'or',
#   'actresses',
#   'most',
#   'resemble',
#   'each',
#   'other',
#   '?'],
#  ['what', 'is', 'the', 'best', 'software', 'company', 'in', 'chennai', '?'],
#  ['in',
#   'american',
#   'history',
#   ',',
#   'has',
#   'any',
#   'republican',
#   'ever',
#   'owned',
#   'a',
#   'slave',
#   '?'],
#  ['how',
#   'one',
#   'should',
#   'begin',
#   'to',
#   'prepare',
#   'for',
#   'iiit',
#   'h',
#   'lateral',
#   'entry',
#   'from',
#   'first',
#   'year',
#   '?'],
#  ['how',
#   'does',
#   'demographic',
#   'momentum',
#   'function',
#   'in',
#   'human',
#   'geography',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   'a',
#   'self',
#   'trained',
#   'amateur',
#   'artist',
#   'from',
#   'engineering',
#   'background',
#   '.',
#   'currently',
#   'i',
#   "'",
#   'm',
#   'working',
#   'for',
#   'cts',
#   'and',
#   'the',
#   'job',
#   'is',
#   'very',
#   'frustrating',
#   'for',
#   'me',
#   '.',
#   'how',
#   'can',
#   'i',
#   'breakfree',
#   'from',
#   'my',
#   'dull',
#   'job',
#   'and',
#   'pursue',
#   'a',
#   'career',
#   'in',
#   'art',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'craziest',
#   'moment',
#   'of',
#   'your',
#   'college',
#   'life',
#   '?'],
#  ['should', 'i', 'get', 'an', 'mba', 'in', 'agribusiness', '?'],
#  ['why',
#   'do',
#   'i',
#   'sometimes',
#   'feel',
#   'like',
#   'the',
#   'people',
#   'i',
#   'know',
#   'are',
#   'watching',
#   'me',
#   '?'],
#  ['how', 'do', 'i', 'use', 'bitcoin', 'in', 'singapore', '?'],
#  ['what',
#   'news',
#   'sources',
#   'do',
#   'diplomats',
#   'read',
#   'to',
#   'get',
#   'global',
#   ',',
#   'macro',
#   'perspectives',
#   '?'],
#  ['why',
#   'am',
#   'i',
#   'feeling',
#   'uncomfortable',
#   'to',
#   'make',
#   'eye',
#   'contact',
#   '?'],
#  ['how', 'is', 'dtu', '?'],
#  ['as',
#   'a',
#   'foreigner',
#   ',',
#   'what',
#   'things',
#   'do',
#   'you',
#   'dislike',
#   'about',
#   'america',
#   ',',
#   'or',
#   'american',
#   'people',
#   '?'],
#  ['i',
#   'am',
#   'in',
#   'eighth',
#   'grade',
#   'and',
#   'i',
#   'got',
#   'a',
#   '1700',
#   '+',
#   'on',
#   'my',
#   'lexile',
#   'test',
#   '.',
#   'is',
#   'this',
#   'good',
#   'or',
#   'bad',
#   'and',
#   'what',
#   'does',
#   'it',
#   'mean',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'emerging',
#   'storytelling',
#   'formats',
#   '?'],
#  ['how', 'do', 'i', 'become', 'a', 'good', 'teacher', '/', 'tutor', '?'],
#  ['what', 'is', 'the', 'best', 'belgian', 'beer', '?'],
#  ['what',
#   'were',
#   'the',
#   'origins',
#   'of',
#   'the',
#   'first',
#   'languages',
#   'and',
#   'what',
#   'were',
#   'these',
#   'languages',
#   '?'],
#  ['if',
#   'north',
#   'korea',
#   'were',
#   'to',
#   'attack',
#   'south',
#   'korea',
#   'suddenly',
#   ',',
#   'how',
#   'would',
#   'the',
#   'latter',
#   'with',
#   'its',
#   'ally',
#   ',',
#   'usa',
#   ',',
#   'defend',
#   'itself',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'if',
#   'a',
#   'website',
#   'is',
#   'hosted',
#   'on',
#   'a',
#   'load',
#   'balanced',
#   'web',
#   'server',
#   'and',
#   'that',
#   'sticky',
#   'sessions',
#   'would',
#   'have',
#   'to',
#   'be',
#   'enabled',
#   'on',
#   'the',
#   'load',
#   'balancers',
#   'and',
#   'that',
#   'session',
#   'checks',
#   'would',
#   'have',
#   'to',
#   'be',
#   'done',
#   'on',
#   'page',
#   'loads',
#   '?'],
#  ['why',
#   'do',
#   'i',
#   'smile',
#   'even',
#   'when',
#   'i',
#   'don',
#   "'",
#   't',
#   'want',
#   'to',
#   '?'],
#  ['what',
#   'do',
#   '"',
#   'mobile',
#   '"',
#   'and',
#   '"',
#   'home',
#   '"',
#   'mean',
#   'on',
#   'the',
#   'whatsapp',
#   'contacts',
#   'page',
#   '?'],
#  ['i',
#   'feel',
#   'like',
#   'disappearing',
#   'from',
#   'this',
#   'world',
#   '?',
#   'no',
#   'money',
#   '/',
#   'fame',
#   '/',
#   'career',
#   'seems',
#   'lucrative',
#   'enough',
#   'to',
#   'stay',
#   'back',
#   '.',
#   'does',
#   'anyone',
#   'feel',
#   'the',
#   'same',
#   '?'],
#  ['does', 'girls', 'like', 'big', 'penis', '?'],
#  ['is', 'it', 'illegal', 'to', 'send', 'cash', 'through', 'the', 'mail', '?'],
#  ['why',
#   'do',
#   'mother',
#   'cats',
#   'sometimes',
#   'eat',
#   'their',
#   'own',
#   'kittens',
#   '?'],
#  ['i',
#   'am',
#   'planning',
#   'to',
#   'learn',
#   'a',
#   'framework',
#   '-',
#   'oaf',
#   'or',
#   'adf',
#   '?',
#   'any',
#   'suggestions',
#   'which',
#   'is',
#   'better',
#   'for',
#   'present',
#   'situation',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'love',
#   'story',
#   'movies',
#   'just',
#   'as',
#   'titanic',
#   '?'],
#  ['what', 'are', 'the', 'pros', 'and', 'cons', 'of', 'shopify', '?'],
#  ['what', "'", 's', 'the', 'inverse', 'function', '?'],
#  ['how', 'do', 'i', 'copyright', 'a', 'logo', '?'],
#  ['what',
#   'was',
#   'it',
#   'like',
#   'to',
#   'travel',
#   'on',
#   'board',
#   'a',
#   'concorde',
#   '?'],
#  ['how', 'can', 'i', 'live', 'a', 'simple', 'life', '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'grabs',
#   'your',
#   'erect',
#   'penis',
#   '?'],
#  ['which',
#   'countries',
#   'have',
#   'the',
#   'tradition',
#   'of',
#   'taking',
#   'off',
#   'shoes',
#   'before',
#   'you',
#   'enter',
#   'a',
#   'home',
#   '?'],
#  ['why', 'is', 'a', 'university', 'degree', 'so', 'important', '?'],
#  ['what', 'is', 'mentoring', '?'],
#  ['how',
#   'do',
#   'you',
#   'cope',
#   'with',
#   'being',
#   'scammed',
#   'and',
#   'losing',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'knowing',
#   'you',
#   'will',
#   'not',
#   'get',
#   'it',
#   'back',
#   '?'],
#  ['how', 'much', 'does', 'starting', 'a', 'website', 'cost', '?'],
#  ['can', 'a', 'foreigner', 'buy', 'american', 'mutual', 'funds', '?'],
#  ['why',
#   'is',
#   'my',
#   'google',
#   'in',
#   'a',
#   'foreign',
#   'language',
#   'on',
#   'safari',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'app',
#   'to',
#   'block',
#   'unwanted',
#   'voice',
#   'messages',
#   'and',
#   'calls',
#   '?'],
#  ['is', 'taiwan', 'part', 'of', 'or', 'separate', 'from', 'china', '?'],
#  ['is', 'playing', 'chess', 'waste', 'of', 'time', '?'],
#  ['is', 'nude', 'photography', 'considered', 'objectification', '?'],
#  ['what',
#   'is',
#   'buried',
#   'or',
#   'was',
#   'buried',
#   'under',
#   'solomon',
#   "'",
#   's',
#   'temple',
#   '?'],
#  ['between',
#   'mac',
#   'os',
#   'and',
#   'windows',
#   ',',
#   'which',
#   'os',
#   'should',
#   'i',
#   'chose',
#   'as',
#   'a',
#   'web',
#   'developer',
#   '?'],
#  ['do', 'shock', 'collars', 'work', 'on', 'dogs', '?'],
#  ['why', 'is', 'the', 'yale', 'art', 'website', 'so', 'bad', '?'],
#  ['how',
#   'has',
#   'your',
#   'lifestyle',
#   'changed',
#   'before',
#   'and',
#   'after',
#   'using',
#   'quora',
#   '?'],
#  ['how', 'do', 'i', 'choose', 'a', 'topic', 'for', 'my', 'blog', '?'],
#  ['what',
#   'exactly',
#   'does',
#   'borderline',
#   'personality',
#   'disorder',
#   'mean',
#   '?',
#   'and',
#   'what',
#   'are',
#   'the',
#   'symptoms',
#   '?'],
#  ['why', 'do', 'i', 'enjoy', 'hurting', 'myself', '?'],
#  ['how', 'do', 'you', 'clean', 'out', 'a', 'catalytic', 'converter', '?'],
#  ['what', 'are', 'best', 'things', 'to', 'be', 'learned', 'in', 'life', '?'],
#  ['do',
#   'girls',
#   'stop',
#   'growing',
#   'in',
#   'height',
#   'once',
#   'they',
#   'get',
#   'their',
#   'periods',
#   '?'],
#  ['where',
#   'could',
#   'i',
#   'find',
#   'a',
#   'best',
#   'escort',
#   'agency',
#   'in',
#   'malaysia',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'ias',
#   'coaching',
#   'centre',
#   'in',
#   'trivandrum',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'says',
#   "'",
#   'you',
#   "'",
#   're',
#   'so',
#   'affectionate',
#   ".'?"],
#  ['why', 'is', 'virginity', 'a', 'big', 'deal', 'in', 'society', '?'],
#  ['what',
#   'is',
#   'the',
#   'character',
#   'or',
#   'theory',
#   'that',
#   'you',
#   'believe',
#   'to',
#   'be',
#   'true',
#   'while',
#   'most',
#   'people',
#   'don',
#   "'",
#   't',
#   '?',
#   'why',
#   '?'],
#  ['why', 'do', 'i', 'get', 'bored', 'easily', '?'],
#  ['what', 'should', 'i', 'learn', 'php', 'or', '.', 'net', '?'],
#  ['what', 'is', 'the', 'virgin', '?'],
#  ['are', 'turks', 'and', 'azerbaijanis', 'considered', 'white', '?'],
#  ['what', 'should', 'i', 'do', 'with', 'my', 'career', 'life', '?'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'of',
#   'the',
#   'reliance',
#   'jio',
#   'ad',
#   'featuring',
#   'prime',
#   'minister',
#   'modi',
#   '?',
#   'do',
#   'you',
#   'think',
#   'its',
#   'legally',
#   'or',
#   'ethically',
#   'correct',
#   'to',
#   'do',
#   'so',
#   '?'],
#  ['how',
#   'does',
#   'one',
#   'train',
#   'to',
#   'become',
#   'a',
#   'world',
#   'champion',
#   'pole',
#   'dancer',
#   '?'],
#  ['how',
#   'do',
#   'people',
#   'feel',
#   'when',
#   'the',
#   'borders',
#   'of',
#   'their',
#   'country',
#   'change',
#   '?'],
#  ['how',
#   'does',
#   'mypromovideo',
#   'of',
#   'youtube',
#   'make',
#   'there',
#   'animation',
#   '?'],
#  ['do', 'lizards', 'feel', 'thirsty', '?'],
#  ['scs',
#   ':',
#   'what',
#   'would',
#   'happen',
#   'to',
#   'the',
#   'appointment',
#   'of',
#   'arbitrators',
#   'made',
#   'by',
#   'the',
#   'president',
#   'itlos',
#   'if',
#   'china',
#   'did',
#   'not',
#   'approve',
#   'it',
#   '?'],
#  ['my',
#   'husband',
#   'was',
#   'so',
#   'mean',
#   'for',
#   'most',
#   'our',
#   '20',
#   'yr',
#   'relationship',
#   'but',
#   'the',
#   'past',
#   'couple',
#   'of',
#   'years',
#   ',',
#   'he',
#   "'",
#   's',
#   'started',
#   'being',
#   'nice',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'past',
#   'the',
#   'painful',
#   'memories',
#   '?'],
#  ['what', 'are', 'the', 'best', 'programming', 'practice', 'sites', '?'],
#  ['what', 'are', 'compulsory', 'acts', 'of', 'worship', 'in', 'islam', '?'],
#  ['what',
#   'would',
#   'be',
#   'your',
#   'advice',
#   'to',
#   'those',
#   'who',
#   'want',
#   'to',
#   'build',
#   'a',
#   'social',
#   'enterprise',
#   'but',
#   'have',
#   'no',
#   'prior',
#   'background',
#   'in',
#   'the',
#   'field',
#   'nor',
#   'an',
#   'advanced',
#   'education',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'achieve',
#   'the',
#   'freezing',
#   'point',
#   'of',
#   'hexane',
#   '?',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'methane',
#   '?'],
#  ['would',
#   'you',
#   'trust',
#   'meth',
#   'users',
#   'and',
#   '/',
#   'or',
#   'are',
#   '“',
#   'meth',
#   'users',
#   'mean',
#   'and',
#   'selfish',
#   '”',
#   '?'],
#  ['should',
#   'new',
#   'actors',
#   'start',
#   'in',
#   'commercials',
#   'to',
#   'build',
#   'up',
#   'their',
#   'acting',
#   'credits',
#   'then',
#   'focus',
#   'on',
#   'film',
#   '/',
#   'tv',
#   'after',
#   '?'],
#  ['what', 'is', 'lamictal', 'abuse', '?'],
#  ['how',
#   'dangerous',
#   'is',
#   'it',
#   'if',
#   'a',
#   'dog',
#   'eats',
#   'chocolate',
#   'cake',
#   '?'],
#  ['would',
#   'vegans',
#   'view',
#   'animal',
#   'consumption',
#   'as',
#   'morally',
#   'permissible',
#   'if',
#   'the',
#   'animals',
#   'were',
#   'allowed',
#   'a',
#   'full',
#   'life',
#   'and',
#   'only',
#   'consumed',
#   'after',
#   'dying',
#   'from',
#   'natural',
#   'causes',
#   '?'],
#  ['what',
#   'is',
#   'most',
#   'appropriate',
#   'software',
#   'design',
# ...
#   'original',
#   'meaning',
#   'of',
#   '"',
#   'falana',
#   'dimka',
#   '"?'],
#  ['how',
#   'can',
#   'a',
#   'rising',
#   'computer',
#   'science',
#   'student',
#   ',',
#   'who',
#   'has',
#   'had',
#   'no',
#   'prior',
#   'knowledge',
#   'of',
#   'programming',
#   'or',
#   'data',
#   'structures',
#   ',',
#   'learn',
#   'to',
#   'compete',
#   'against',
#   'other',
#   'computer',
#   'science',
#   'students',
#   'with',
#   'years',
#   'of',
#   'experience',
#   '?'],
#  ['is', 'michele', 'obama', 'really', 'a', 'man', '?'],
#  ['how', 'do', 'i', 'flirt', 'with', 'a', 'girl', 'who', 'likes', 'me', '?'],
#  ['can', 'chihuahuas', 'eat', 'peanuts', '?', 'why', 'or', 'why', 'not', '?'],
#  ['for',
#   'how',
#   'long',
#   'will',
#   'donald',
#   'trump',
#   'be',
#   'president',
#   'of',
#   'the',
#   'us',
#   '?'],
#  ['for',
#   'building',
#   'a',
#   'system',
#   'like',
#   'udemy',
#   ',',
#   'coursera',
#   'or',
#   'edx',
#   'can',
#   'one',
#   'use',
#   'an',
#   'available',
#   'off',
#   'the',
#   'shelf',
#   'lms',
#   'or',
#   'have',
#   'this',
#   'custom',
#   'build',
#   'in',
#   'php',
#   'or',
#   'dot',
#   'net',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'tell',
#   'if',
#   'a',
#   'guy',
#   'is',
#   'gay',
#   'and',
#   'is',
#   'interested',
#   'in',
#   'me',
#   '?'],
#  ['what', "'", 's', 'a', 'good', 'distributed', 'queue', '?'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'a',
#   'job',
#   'in',
#   'whatsapp',
#   'as',
#   'a',
#   'support',
#   'analyst',
#   '?'],
#  ['how', 'do', 'you', 'heal', 'a', 'cut', 'on', 'your', 'gums', '?'],
#  ['why', 'are', 'converse', 'shoes', 'sized', 'so', 'large', '?'],
#  ['who', 'made', 'you', 'realize', 'you', 'were', 'gay', '?'],
#  ['what',
#   'is',
#   'your',
#   'preferred',
#   'combination',
#   'of',
#   'sauces',
#   'in',
#   'subway',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'single',
#   'phase',
#   'and',
#   'three',
#   'phase',
#   'power',
#   '?'],
#  ['what', 'are', 'the', 'components', 'for', 'an', 'online', 'business', '?'],
#  ['why',
#   'does',
#   'a',
#   'girl',
#   'ignore',
#   'you',
#   'when',
#   'she',
#   'knows',
#   'the',
#   'fact',
#   'that',
#   'you',
#   'like',
#   'her',
#   '?'],
#  ['what',
#   'will',
#   'happen',
#   'after',
#   'death',
#   'according',
#   'to',
#   'science',
#   '?'],
#  ['how', 'can', 'i', 'write', 'research', '?'],
#  ['how',
#   'do',
#   'i',
#   'perform',
#   'reverse',
#   'engineering',
#   'in',
#   'pharmaceuticals',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'apply',
#   'for',
#   'pan',
#   'card',
#   'online',
#   ',',
#   'please',
#   'read',
#   'details',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'evidence',
#   'that',
#   'we',
#   'really',
#   'did',
#   'land',
#   'on',
#   'the',
#   'moon',
#   '?'],
#  ['who',
#   'is',
#   'the',
#   'famous',
#   'coder',
#   '"',
#   'trojenguri',
#   '"',
#   'from',
#   'svnit',
#   ',',
#   'surat',
#   '?'],
#  ['why',
#   'is',
#   'frictional',
#   'force',
#   'is',
#   'not',
#   'a',
#   'conservative',
#   'force',
#   '?'],
#  ['i',
#   'got',
#   'suspended',
#   'from',
#   'upwork',
#   '.',
#   'do',
#   'i',
#   'have',
#   'the',
#   'legal',
#   'right',
#   'to',
#   'create',
#   'another',
#   'account',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'becoming',
#   'a',
#   'lawyer',
#   'in',
#   'the',
#   'u',
#   '.',
#   's',
#   '.?'],
#  ['how',
#   'do',
#   'we',
#   'challenge',
#   'our',
#   'freeholder',
#   'if',
#   'we',
#   'suspect',
#   'they',
#   'are',
#   'overcharging',
#   'us',
#   'for',
#   'building',
#   'work',
#   '?'],
#  ['muslim',
#   'women',
#   ':',
#   'what',
#   'emotions',
#   'does',
#   'an',
#   'unmarried',
#   'muslima',
#   ',',
#   'from',
#   'an',
#   'orthodox',
#   'family',
#   ',',
#   'experience',
#   'while',
#   'being',
#   'undressed',
#   'for',
#   'her',
#   'first',
#   'sexual',
#   'intercourse',
#   '?'],
#  ['would',
#   "'",
#   'ramzor',
#   "'",
#   'in',
#   'the',
#   'original',
#   'hebrew',
#   'but',
#   'with',
#   'english',
#   '(',
#   'or',
#   'other',
#   ')',
#   'subtitles',
#   'work',
#   'on',
#   'cable',
#   'or',
#   'broadcast',
#   'tv',
#   '?',
#   'has',
#   'anyone',
#   'tried',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'activities',
#   'to',
#   'do',
#   'with',
#   'children',
#   'when',
#   'visiting',
#   'silchar',
#   ',',
#   'assam',
#   ',',
#   'india',
#   '?'],
#  ['my',
#   'linkedin',
#   'account',
#   'has',
#   'been',
#   'restricted',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'them',
#   'to',
#   'unrestrict',
#   '(',
#   'release',
#   ')',
#   'my',
#   'linkedin',
#   'account',
#   '?'],
#  ['what', 'does', '押一付三', '，', '先付后用', 'mean', 'in', 'english', '?'],
#  ['what', 'is', 'the', 'origin', 'of', 'the', 'term', '"', 'hoosier', '"?'],
#  ['how',
#   'the',
#   'internal',
#   'working',
#   'of',
#   'statement',
#   '-',
#   'based',
#   '-',
#   'replication',
#   'happens',
#   'on',
#   'secondary',
#   'node',
#   'of',
#   'mongodb',
#   '?'],
#  ['what',
#   'consumer',
#   'electronics',
#   'segments',
#   'are',
#   'growing',
#   'the',
#   'fastest',
#   '?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'the',
#   'white',
#   'part',
#   'of',
#   'my',
#   'eye',
#   'is',
#   'swollen',
#   '?'],
#  ['what',
#   'are',
#   'we',
#   'sensing',
#   'when',
#   'we',
#   '"',
#   'feel',
#   '"',
#   'someone',
#   "'",
#   's',
#   'presence',
#   '?'],
#  ['how', 'is', 'a', 'compiler', 'program', 'compiled', '?'],
#  ['trump',
#   'supporters',
#   'cite',
#   'a',
#   'shakeup',
#   'of',
#   'd',
#   '.',
#   'c',
#   '.',
#   'as',
#   'a',
#   'primary',
#   'driver',
#   'to',
#   'success',
#   '-',
#   'change',
#   'the',
#   'outcome',
#   'expected',
#   '-',
#   'so',
#   'why',
#   'did',
#   '435',
#   'party',
#   'wag',
#   'house',
#   'members',
#   'get',
#   'in',
#   '?'],
#  ['does',
#   'a',
#   'long',
#   'sleeve',
#   'shirt',
#   'look',
#   'good',
#   'under',
#   'a',
#   'polo',
#   'shirt',
#   '?'],
#  ['it',
#   "'",
#   's',
#   '2016',
#   '.',
#   'dad',
#   'says',
#   'that',
#   'he',
#   'and',
#   'ma',
#   'will',
#   'leave',
#   'the',
#   'country',
#   'if',
#   'hillary',
#   'is',
#   'elected',
#   '.',
#   'they',
#   'are',
#   'big',
#   'republicans',
#   '.',
#   'what',
#   'conservative',
#   'country',
#   'should',
#   'they',
#   'move',
#   'to',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'mind',
#   '-',
#   'blowing',
#   'facts',
#   'about',
#   'netherlands',
#   '?'],
#  ['how', 'do', 'i', 'prepare', 'for', 'a', 'travel', 'quiz', '?'],
#  ['what', 'is', 'all', 'about', 'scholarships', 'for', 'engineering', '?'],
#  ['what',
#   'universities',
#   'does',
#   'petmeds',
#   'recruit',
#   'new',
#   'grads',
#   'from',
#   '?',
#   'what',
#   'majors',
#   'are',
#   'they',
#   'looking',
#   'for',
#   '?'],
#  ['what',
#   'did',
#   'chinese',
#   'soldiers',
#   '(',
#   'in',
#   'general',
#   ')',
#   'think',
#   'of',
#   'americans',
#   'soldiers',
#   'in',
#   'the',
#   'korean',
#   'war',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'the',
#   'best',
#   'employment',
#   'attorney',
#   'in',
#   'los',
#   'angeles',
#   '?'],
#  ['what', "'", 's', 'the', 'most', 'sophisticated', 'indian', 'city', '?'],
#  ['what',
#   'percentage',
#   'of',
#   'quora',
#   'questions',
#   'do',
#   'you',
#   'think',
#   'could',
#   'be',
#   'answered',
#   'with',
#   'a',
#   'simple',
#   'google',
#   'search',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'cook',
#   'a',
#   'steak',
#   'like',
#   'a',
#   'restaurant',
#   'does',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'find',
#   'indoor',
#   'badminton',
#   'courts',
#   'to',
#   'play',
#   '?'],
#  ['is', 'it', 'safe', 'to', 'travel', 'to', 'turkey', 'in', '2016', '?'],
#  ['what',
#   "'",
#   's',
#   'brendan',
#   'fraser',
#   "'",
#   's',
#   'political',
#   'beliefs',
#   '?'],
#  ['when', 'is', 'ekstop', '.', 'com', 'launching', 'in', 'pune', '?'],
#  ['why', 'don', "'", 't', 'most', 'american', 'eat', 'chicken', 'livers', '?'],
#  ['how',
#   'do',
#   'you',
#   'eat',
#   'good',
#   'tasting',
#   'food',
#   'while',
#   'eating',
#   'healthy',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'benefits',
#   'and',
#   'tradeoffs',
#   'of',
#   'pair',
#   'programming',
#   '?'],
#  ['how', 'good', 'are', 'larry', '&', 'sergey', 'at', 'programming', '?'],
#  ['do', 'younger', 'women', 'really', 'like', 'older', 'men', '?'],
#  ['i',
#   'want',
#   'to',
#   'hire',
#   'a',
#   'hacker',
#   'to',
#   'hack',
#   'the',
#   'balance',
#   'of',
#   'an',
#   'emv',
#   'stored',
#   'value',
#   'card',
#   ',',
#   'where',
#   'should',
#   'i',
#   'go',
#   '?'],
#  ['my',
#   'facebook',
#   'is',
#   'hacked',
#   'by',
#   'someone',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'back',
#   'the',
#   'old',
#   'facebook',
#   'account',
#   '?'],
#  ['where',
#   'can',
#   'i',
#   'get',
#   'quality',
#   'services',
#   'in',
#   'australia',
#   'for',
#   'full',
#   'color',
#   'printed',
#   'pvc',
#   'sticker',
#   '?'],
#  ['is', 'gwern', 'a', 'buddha', '?'],
#  ['why',
#   'was',
#   'jaqen',
#   'h',
#   "'",
#   'ghar',
#   'captured',
#   'in',
#   'the',
#   'first',
#   'place',
#   'with',
#   'the',
#   'other',
#   'two',
#   'prisoners',
#   'if',
#   'he',
#   'has',
#   'such',
#   'skills',
#   '?'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'university',
#   'of',
#   'north',
#   'carolina',
#   'at',
#   'charlotte',
#   '?'],
#  ['how',
#   'should',
#   'i',
#   'start',
#   'learning',
#   'python',
#   'for',
#   'data',
#   'science',
#   '?'],
#  ['why', 'is', 'adoption', 'so', 'expensive', '?'],
#  ['who', 'is', 'redditceo', 'on', 'reddit', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'send',
#   'money',
#   'from',
#   'australia',
#   'to',
#   'the',
#   'philippines',
#   '?'],
#  ['what',
#   'are',
#   'computer',
#   'ethics',
#   'and',
#   'what',
#   'are',
#   'some',
#   'examples',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'advantage',
#   'of',
#   'brands',
#   'for',
#   'using',
#   'media',
#   'buyers',
#   'to',
#   'purchase',
#   'advertising',
#   'space',
#   'for',
#   'them',
#   '?'],
#  ['can', 'i', 'take', 'two', 'tylenol', 'and', 'advil', 'together', '?'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'a',
#   'very',
#   'large',
#   'number',
#   'of',
#   'people',
#   'went',
#   'to',
#   'the',
#   'bank',
#   'to',
#   'take',
#   'back',
#   'their',
#   'deposits',
#   'simultaneously',
#   '?'],
#  ['what', 'are', 'basics', 'needed', 'for', '"', 'angular', 'js', '"?'],
#  ['what',
#   'is',
#   'exactly',
#   'the',
#   'concept',
#   'of',
#   'trade',
#   '-',
#   'off',
#   'in',
#   'evolutionary',
#   'biology',
#   '?'],
#  ['how', 'do', 'we', 'develop', 'tamil', 'nadu', '?'],
#  ['why',
#   'does',
#   'the',
#   'brain',
#   'not',
#   'start',
#   'recording',
#   'memory',
#   'for',
#   'the',
#   'first',
#   'few',
#   'years',
#   'of',
#   'life',
#   '?'],
#  ['how',
#   'can',
#   'government',
#   'get',
#   'an',
#   'economy',
#   'out',
#   'of',
#   'a',
#   'recession',
#   'with',
#   'fiscal',
#   'policy',
#   '?'],
#  ['can',
#   'you',
#   'put',
#   'some',
#   'tutorials',
#   'for',
#   'learning',
#   'adobe',
#   'illustrator',
#   '?'],
#  ['which',
#   'compiler',
#   'i',
#   'can',
#   'use',
#   'in',
#   'windows',
#   '8',
#   '.',
#   '1',
#   'for',
#   'c',
#   'language',
#   '?'],
#  ['who',
#   'is',
#   'the',
#   'biggest',
#   'traitor',
#   'in',
#   'the',
#   'history',
#   'of',
#   'portugal',
#   '?'],
#  ['what', 'are', 'some', 'good', 'quotation', 'on', 'faith', '?'],
#  ['is',
#   'it',
#   'very',
#   'useful',
#   'for',
#   'students',
#   'go',
#   'abroad',
#   'for',
#   'study',
#   '?'],
#  ['how', 'are', 'the', 'job', 'opportunities', 'in', 'usa', '?'],
#  ['what',
#   'should',
#   'your',
#   'annual',
#   'income',
#   'be',
#   'to',
#   'fly',
#   'first',
#   'class',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'flip', 'flop', 'at', 'home', '?'],
#  ['my',
#   'stepdad',
#   'let',
#   'me',
#   'have',
#   'facebook',
#   ',',
#   'but',
#   'my',
#   'mother',
#   'wouldn',
#   "'",
#   't',
#   'approve',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'aspects',
#   'of',
#   'living',
#   'in',
#   'batna',
#   ',',
#   'algeria',
#   'as',
#   'a',
#   'young',
#   'adult',
#   '?'],
#  ['how',
#   'many',
#   'times',
#   'do',
#   'artists',
#   'act',
#   'out',
#   'or',
#   'get',
#   'someone',
#   'to',
#   'act',
#   'out',
#   'a',
#   'particular',
#   'pose',
#   'that',
#   'they',
#   'wish',
#   'to',
#   'draw',
#   '?'],
#  ['what',
#   'should',
#   'you',
#   'do',
#   'if',
#   'you',
#   'have',
#   'a',
#   'personality',
#   'disorder',
#   'and',
#   'you',
#   'are',
#   'tired',
#   'of',
#   'hurting',
#   'other',
#   'people',
#   '?'],
#  ['can', 'rbi', 'print', 'unlimited', 'currency', '?'],
#  ['should', 'air', 'india', 'be', 'privatised', '?'],
#  ['what', 'human', 'food', 'is', 'very', 'healthy', 'for', 'dogs', '?'],
#  ['why', 'do', 'atms', 'eat', 'cards', '?'],
#  ['is', 'asianet', 'owned', 'by', 'news', 'corp', '?'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'to',
#   'testdrive',
#   'a',
#   'self',
#   '-',
#   'driving',
#   'car',
#   '?'],
#  ['why', 'do', 'human', 'beings', 'sleep', 'at', 'night', '?'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'raising',
#   'kids',
#   'in',
#   'england',
#   'for',
#   'indian',
#   'parents',
#   '?'],
#  ['i',
#   'am',
#   'a',
#   'iit',
#   'jee',
#   'repeater',
#   'and',
#   'i',
#   'dont',
#   'get',
#   'time',
#   'for',
#   'revision',
#   'of',
#   'previous',
#   'chapters',
#   'taught',
#   'in',
#   'coaching',
#   'because',
#   'of',
#   'lot',
#   'of',
#   'homework',
#   '.',
#   'what',
#   'should',
#   'i',
#   'do',
#   '?'],
#  ['three',
#   'balls',
#   'are',
#   'drawn',
#   'from',
#   'a',
#   'bag',
#   'containing',
#   '5',
#   'white',
#   ',',
#   '4',
#   'black',
#   'and',
#   '6',
#   'red',
#   'balls',
#   '.',
#   'find',
#   'the',
#   'probability',
#   'that',
#   'all',
#   'the',
#   'balls',
#   'are',
#   'of',
#   'one',
#   'colors',
#   '?'],
#  ['should',
#   'a',
#   'teacher',
#   'who',
#   'is',
#   'gay',
#   ',',
#   'bi',
#   'or',
#   'trans',
#   'be',
#   'forced',
#   'to',
#   'inform',
#   'his',
#   'or',
#   'her',
#   'class',
#   'of',
#   'this',
#   'by',
#   'the',
#   'school',
#   '?'],
#  ['in',
#   'what',
#   'programming',
#   'language',
#   'are',
#   'chrome',
#   'extensions',
#   'written',
#   '?',
#   'what',
#   'do',
#   'i',
#   'need',
#   'to',
#   'know',
#   'to',
#   'start',
#   'coding',
#   'them',
#   '?'],
#  ['is', 'there', 'a', 'tibetan', 'market', 'in', 'bangalore', '?'],
#  ['does',
#   'blocking',
#   'somebody',
#   'on',
#   'snapchat',
#   'clear',
#   'saved',
#   'messages',
#   '?'],
#  ['i',
#   'am',
#   'in',
#   '10th',
#   '.',
#   'how',
#   'can',
#   'i',
#   'get',
#   'admission',
#   'in',
#   'the',
#   'indian',
#   'institute',
#   'of',
#   'science',
#   '?'],
#  ['why', 'would', 'you', 'buy', 'an', 'iphone', '7', '?'],
#  ['what',
#   'type',
#   'of',
#   'government',
#   'does',
#   'turkey',
#   'have',
#   '?',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'the',
#   'one',
#   'in',
#   'brazil',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'job',
#   'interview',
#   'questions',
#   'you',
#   "'",
#   've',
#   'ever',
#   'asked',
#   'or',
#   'been',
#   'asked',
#   '?'],
#  ['how', 'many', 'points', 'are', 'in', 'a', 'gram', 'of', 'meth', '?'],
#  ['which', 'k', '-', 'pop', 'idols', 'are', 'not', 'koreans', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'dress',
#   'code',
#   'for',
#   'a',
#   'software',
#   'engineer',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'security',
#   'concerns',
#   'about',
#   'yammer',
#   '?'],
#  ['donald',
#   'trump',
#   ':',
#   'why',
#   'wouldn',
#   "'",
#   't',
#   'you',
#   'vote',
#   'for',
#   'donald',
#   'trump',
#   'for',
#   'president',
#   '?'],
#  ['i',
#   'am',
#   '25',
#   'working',
#   'in',
#   'digital',
#   'marketing',
#   '9',
#   'hours',
#   'a',
#   'day',
#   '.',
#   'i',
#   'want',
#   'to',
#   'spend',
#   'another',
#   '5',
#   'to',
#   '8',
#   'hours',
#   'for',
#   'myself',
#   'at',
#   'home',
#   ',',
#   'to',
#   'work',
#   'on',
#   'my',
#   'startup',
#   '.',
#   'it',
#   'is',
#   'healthy',
#   'to',
#   'spend',
#   '15',
#   'to',
#   '18',
#   'hours',
#   'daily',
#   'for',
#   'work',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'craziest',
#   '/',
#   'weirdest',
#   'things',
#   'you',
#   "'",
#   've',
#   'seen',
#   'a',
#   'lion',
#   'do',
#   '?'],
#  ['what', 'has', 'gone', 'wrong', 'at', 'chelsea', 'fc', '?'],
#  ['how',
#   'do',
#   'i',
#   'control',
#   'someone',
#   'who',
#   'is',
#   'very',
#   'dominating',
#   '?'],
#  ['what',
#   'is',
#   'an',
#   'easy',
#   'way',
#   'to',
#   'clean',
#   'toothpaste',
#   'stains',
#   'from',
#   'a',
#   'shirt',
#   'without',
#   'washing',
#   'it',
#   '?'],
#  ['job',
#   'interviews',
#   ':',
#   'should',
#   'someone',
#   'with',
#   'asperger',
#   "'",
#   's',
#   'disclose',
#   'their',
#   'asperger',
#   "'",
#   's',
#   'in',
#   'a',
#   'job',
#   'interview',
#   '?'],
#  ['should',
#   'quora',
#   'allow',
#   'the',
#   'option',
#   'to',
#   'bookmark',
#   'questions',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'easiest',
#   'and',
#   'safest',
#   'way',
#   'to',
#   'make',
#   'meth',
#   '?'],
#  ['which', 'is', 'the', 'best', 'book', 'for', 'control', 'system', '?'],
#  ['what',
#   'do',
#   'you',
#   'call',
#   'someone',
#   'who',
#   'is',
#   'attracted',
#   'to',
#   'women',
#   'but',
#   'doesn',
#   "'",
#   't',
#   'want',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'them',
#   'or',
#   'be',
#   'in',
#   'a',
#   'relationship',
#   'with',
#   'them',
#   '?'],
#  ...]

# %%
assert all(isinstance(row, (list, tuple)) for row in data_tok), "please convert each line into a list of tokens (strings)"
assert all(all(isinstance(tok, str) for tok in row) for row in data_tok), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all('a' <= x.lower() <= 'z' for x in tok)
assert all(map(lambda l: not is_latin(l) or l.islower(), map(' '.join, data_tok))), "please make sure to lowercase the data"

# %%
print([' '.join(row) for row in data_tok[:2]])
# Out:
# ["can i get back with my ex even though she is pregnant with another guy ' s baby ?", 'what are some ways to overcome a fast food addiction ?']

# %% [markdown]
# __Word vectors:__ as the saying goes, there's more than one way to train word embeddings. There's Word2Vec and GloVe with different objective functions. Then there's fasttext that uses character-level models to train word embeddings.
#
# The choice is huge, so let's start with something small: __gensim__ is another nlp library that features many vector-based models incuding word2vec.

# %%
from gensim.models import Word2Vec
model = Word2Vec(data_tok,
                 vector_size=32,      # embedding vector size
                 min_count=5,  # consider words that occured at least 5 times
                 window=5).wv  # define context as a 5-word window around the target word

# From gensim docs
# vw: This object essentially contains the mapping between words and embeddings.
# After training, it can be used directly to query those embeddings in various ways.
# Out:
# /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# now you can get word vectors !
model.get_vector('anything')
# Out:
# array([-3.287567  ,  1.2510641 ,  0.42789584,  3.8661456 ,  1.6035742 ,
#         1.5822142 ,  1.2318038 , -5.5939384 ,  0.6088501 ,  2.6666117 ,
#         0.3962618 ,  1.41421   ,  3.7796428 , -0.3821842 ,  1.8998399 ,
#        -1.5809569 , -0.33465976, -1.5508794 ,  0.25529885, -1.7501593 ,
#        -2.2589364 , -0.76401246, -2.1003115 , -2.9072878 ,  2.47822   ,
#        -1.2322421 ,  0.01036774,  1.5433271 ,  1.3515444 ,  0.9067684 ,
#         0.43456838,  0.7210383 ], dtype=float32)

# %%
# or query similar words directly. Go play with it!
model.most_similar('bread')
# Out:
# [('rice', 0.9564233422279358),
#  ('butter', 0.9391641616821289),
#  ('sauce', 0.9375967979431152),
#  ('cheese', 0.9343426823616028),
#  ('banana', 0.9230297207832336),
#  ('wine', 0.9143245816230774),
#  ('beans', 0.912829577922821),
#  ('chicken', 0.9110182523727417),
#  ('chocolate', 0.9091234803199768),
#  ('corn', 0.9078245162963867)]

# %% [markdown]
# ### Using pre-trained model
#
# Now, imagine training real life-sized (100~300D) word embeddings on gigabytes of text: wikipedia articles or twitter posts.
#
# Thankfully, nowadays you can get a pre-trained word embedding model in 2 lines of code (no sms required, promise).
#
# After being downloaded for the first time (or if you manually delete it), the model is saved in the `~/gensim_data` or `%USER_PATH%/gensim_data` directory. This can be checked seting the return_path parameter to True.

# %%
import gensim.downloader as api

# %%
api.info()
# Out:
# {'corpora': {'semeval-2016-2017-task3-subtaskBC': {'num_records': -1,
#    'record_format': 'dict',
#    'file_size': 6344358,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskB-eng/__init__.py',
#    'license': 'All files released for the task are free for general research use',
#    'fields': {'2016-train': ['...'],
#     '2016-dev': ['...'],
#     '2017-test': ['...'],
#     '2016-test': ['...']},
#    'description': 'SemEval 2016 / 2017 Task 3 Subtask B and C datasets contain train+development (317 original questions, 3,169 related questions, and 31,690 comments), and test datasets in English. The description of the tasks and the collected data is given in sections 3 and 4.1 of the task paper http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf linked in section “Papers” of https://github.com/RaRe-Technologies/gensim-data/issues/18.',
#    'checksum': '701ea67acd82e75f95e1d8e62fb0ad29',
#    'file_name': 'semeval-2016-2017-task3-subtaskBC.gz',
#    'read_more': ['http://alt.qcri.org/semeval2017/task3/',
#     'http://alt.qcri.org/semeval2017/task3/data/uploads/semeval2017-task3.pdf',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/18',
#     'https://github.com/Witiko/semeval-2016_2017-task3-subtaskB-english'],
#    'parts': 1},
#   'semeval-2016-2017-task3-subtaskA-unannotated': {'num_records': 189941,
#    'record_format': 'dict',
#    'file_size': 234373151,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/semeval-2016-2017-task3-subtaskA-unannotated-eng/__init__.py',
#    'license': 'These datasets are free for general research use.',
#    'fields': {'THREAD_SEQUENCE': '',
#     'RelQuestion': {'RELQ_CATEGORY': 'question category, according to the Qatar Living taxonomy',
#      'RELQ_DATE': 'date of posting',
#      'RELQ_ID': 'question indentifier',
#      'RELQ_USERID': 'identifier of the user asking the question',
#      'RELQ_USERNAME': 'name of the user asking the question',
#      'RelQBody': 'body of question',
#      'RelQSubject': 'subject of question'},
#     'RelComments': [{'RelCText': 'text of answer',
#       'RELC_USERID': 'identifier of the user posting the comment',
#       'RELC_ID': 'comment identifier',
#       'RELC_USERNAME': 'name of the user posting the comment',
#       'RELC_DATE': 'date of posting'}]},
#    'description': 'SemEval 2016 / 2017 Task 3 Subtask A unannotated dataset contains 189,941 questions and 1,894,456 comments in English collected from the Community Question Answering (CQA) web forum of Qatar Living. These can be used as a corpus for language modelling.',
#    'checksum': '2de0e2f2c4f91c66ae4fcf58d50ba816',
#    'file_name': 'semeval-2016-2017-task3-subtaskA-unannotated.gz',
#    'read_more': ['http://alt.qcri.org/semeval2016/task3/',
#     'http://alt.qcri.org/semeval2016/task3/data/uploads/semeval2016-task3-report.pdf',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/18',
#     'https://github.com/Witiko/semeval-2016_2017-task3-subtaskA-unannotated-english'],
#    'parts': 1},
#   'patent-2017': {'num_records': 353197,
#    'record_format': 'dict',
#    'file_size': 3087262469,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/patent-2017/__init__.py',
#    'license': 'not found',
#    'description': "Patent Grant Full Text. Contains the full text including tables, sequence data and 'in-line' mathematical expressions of each patent grant issued in 2017.",
#    'checksum-0': '818501f0b9af62d3b88294d86d509f8f',
#    'checksum-1': '66c05635c1d3c7a19b4a335829d09ffa',
#    'file_name': 'patent-2017.gz',
#    'read_more': ['http://patents.reedtech.com/pgrbft.php'],
#    'parts': 2},
#   'quora-duplicate-questions': {'num_records': 404290,
#    'record_format': 'dict',
#    'file_size': 21684784,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/quora-duplicate-questions/__init__.py',
#    'license': 'probably https://www.quora.com/about/tos',
#    'fields': {'question1': 'the full text of each question',
#     'question2': 'the full text of each question',
#     'qid1': 'unique ids of each question',
#     'qid2': 'unique ids of each question',
#     'id': 'the id of a training set question pair',
#     'is_duplicate': 'the target variable, set to 1 if question1 and question2 have essentially the same meaning, and 0 otherwise'},
#    'description': 'Over 400,000 lines of potential question duplicate pairs. Each line contains IDs for each question in the pair, the full text for each question, and a binary value that indicates whether the line contains a duplicate pair or not.',
#    'checksum': 'd7cfa7fbc6e2ec71ab74c495586c6365',
#    'file_name': 'quora-duplicate-questions.gz',
#    'read_more': ['https://data.quora.com/First-Quora-Dataset-Release-Question-Pairs'],
#    'parts': 1},
#   'wiki-english-20171001': {'num_records': 4924894,
#    'record_format': 'dict',
#    'file_size': 6516051717,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/wiki-english-20171001/__init__.py',
#    'license': 'https://dumps.wikimedia.org/legal.html',
#    'fields': {'section_texts': 'list of body of sections',
#     'section_titles': 'list of titles of sections',
#     'title': 'Title of wiki article'},
#    'description': 'Extracted Wikipedia dump from October 2017. Produced by `python -m gensim.scripts.segment_wiki -f enwiki-20171001-pages-articles.xml.bz2 -o wiki-en.gz`',
#    'checksum-0': 'a7d7d7fd41ea7e2d7fa32ec1bb640d71',
#    'checksum-1': 'b2683e3356ffbca3b6c2dca6e9801f9f',
#    'checksum-2': 'c5cde2a9ae77b3c4ebce804f6df542c2',
#    'checksum-3': '00b71144ed5e3aeeb885de84f7452b81',
#    'file_name': 'wiki-english-20171001.gz',
#    'read_more': ['https://dumps.wikimedia.org/enwiki/20171001/'],
#    'parts': 4},
#   'text8': {'num_records': 1701,
#    'record_format': 'list of str (tokens)',
#    'file_size': 33182058,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/text8/__init__.py',
#    'license': 'not found',
#    'description': 'First 100,000,000 bytes of plain text from Wikipedia. Used for testing purposes; see wiki-english-* for proper full Wikipedia datasets.',
#    'checksum': '68799af40b6bda07dfa47a32612e5364',
#    'file_name': 'text8.gz',
#    'read_more': ['http://mattmahoney.net/dc/textdata.html'],
#    'parts': 1},
#   'fake-news': {'num_records': 12999,
#    'record_format': 'dict',
#    'file_size': 20102776,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/fake-news/__init__.py',
#    'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#    'fields': {'crawled': 'date the story was archived',
#     'ord_in_thread': '',
#     'published': 'date published',
#     'participants_count': 'number of participants',
#     'shares': 'number of Facebook shares',
#     'replies_count': 'number of replies',
#     'main_img_url': 'image from story',
#     'spam_score': 'data from webhose.io',
#     'uuid': 'unique identifier',
#     'language': 'data from webhose.io',
#     'title': 'title of story',
#     'country': 'data from webhose.io',
#     'domain_rank': 'data from webhose.io',
#     'author': 'author of story',
#     'comments': 'number of Facebook comments',
#     'site_url': 'site URL from BS detector',
#     'text': 'text of story',
#     'thread_title': '',
#     'type': 'type of website (label from BS detector)',
#     'likes': 'number of Facebook likes'},
#    'description': "News dataset, contains text and metadata from 244 websites and represents 12,999 posts in total from a specific window of 30 days. The data was pulled using the webhose.io API, and because it's coming from their crawler, not all websites identified by their BS Detector are present in this dataset. Data sources that were missing a label were simply assigned a label of 'bs'. There are (ostensibly) no genuine, reliable, or trustworthy news sources represented in this dataset (so far), so don't trust anything you read.",
#    'checksum': '5e64e942df13219465927f92dcefd5fe',
#    'file_name': 'fake-news.gz',
#    'read_more': ['https://www.kaggle.com/mrisdal/fake-news'],
#    'parts': 1},
#   '20-newsgroups': {'num_records': 18846,
#    'record_format': 'dict',
#    'file_size': 14483581,
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/20-newsgroups/__init__.py',
#    'license': 'not found',
#    'fields': {'topic': 'name of topic (20 variant of possible values)',
#     'set': "marker of original split (possible values 'train' and 'test')",
#     'data': '',
#     'id': 'original id inferred from folder name'},
#    'description': 'The notorious collection of approximately 20,000 newsgroup posts, partitioned (nearly) evenly across 20 different newsgroups.',
#    'checksum': 'c92fd4f6640a86d5ba89eaad818a9891',
#    'file_name': '20-newsgroups.gz',
#    'read_more': ['http://qwone.com/~jason/20Newsgroups/'],
#    'parts': 1},
#   '__testing_matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Synopsis of the movie matrix.',
#    'checksum': '1767ac93a089b43899d54944b07d9dc5',
#    'file_name': '__testing_matrix-synopsis.gz',
#    'read_more': ['http://www.imdb.com/title/tt0133093/plotsummary?ref_=ttpl_pl_syn#synopsis'],
#    'parts': 1},
#   '__testing_multipart-matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Synopsis of the movie matrix.',
#    'checksum-0': 'c8b0c7d8cf562b1b632c262a173ac338',
#    'checksum-1': '5ff7fc6818e9a5d9bc1cf12c35ed8b96',
#    'checksum-2': '966db9d274d125beaac7987202076cba',
#    'file_name': '__testing_multipart-matrix-synopsis.gz',
#    'read_more': ['http://www.imdb.com/title/tt0133093/plotsummary?ref_=ttpl_pl_syn#synopsis'],
#    'parts': 3}},
#  'models': {'fasttext-wiki-news-subwords-300': {'num_records': 999999,
#    'file_size': 1005007116,
#    'base_dataset': 'Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/fasttext-wiki-news-subwords-300/__init__.py',
#    'license': 'https://creativecommons.org/licenses/by-sa/3.0/',
#    'parameters': {'dimension': 300},
#    'description': '1 million word vectors trained on Wikipedia 2017, UMBC webbase corpus and statmt.org news dataset (16B tokens).',
#    'read_more': ['https://fasttext.cc/docs/en/english-vectors.html',
#     'https://arxiv.org/abs/1712.09405',
#     'https://arxiv.org/abs/1607.01759'],
#    'checksum': 'de2bb3a20c46ce65c9c131e1ad9a77af',
#    'file_name': 'fasttext-wiki-news-subwords-300.gz',
#    'parts': 1},
#   'conceptnet-numberbatch-17-06-300': {'num_records': 1917247,
#    'file_size': 1225497562,
#    'base_dataset': 'ConceptNet, word2vec, GloVe, and OpenSubtitles 2016',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/conceptnet-numberbatch-17-06-300/__init__.py',
#    'license': 'https://github.com/commonsense/conceptnet-numberbatch/blob/master/LICENSE.txt',
#    'parameters': {'dimension': 300},
#    'description': 'ConceptNet Numberbatch consists of state-of-the-art semantic vectors (also known as word embeddings) that can be used directly as a representation of word meanings or as a starting point for further machine learning. ConceptNet Numberbatch is part of the ConceptNet open data project. ConceptNet provides lots of ways to compute with word meanings, one of which is word embeddings. ConceptNet Numberbatch is a snapshot of just the word embeddings. It is built using an ensemble that combines data from ConceptNet, word2vec, GloVe, and OpenSubtitles 2016, using a variation on retrofitting.',
#    'read_more': ['http://aaai.org/ocs/index.php/AAAI/AAAI17/paper/view/14972',
#     'https://github.com/commonsense/conceptnet-numberbatch',
#     'http://conceptnet.io/'],
#    'checksum': 'fd642d457adcd0ea94da0cd21b150847',
#    'file_name': 'conceptnet-numberbatch-17-06-300.gz',
#    'parts': 1},
#   'word2vec-ruscorpora-300': {'num_records': 184973,
#    'file_size': 208427381,
#    'base_dataset': 'Russian National Corpus (about 250M words)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-ruscorpora-300/__init__.py',
#    'license': 'https://creativecommons.org/licenses/by/4.0/deed.en',
#    'parameters': {'dimension': 300, 'window_size': 10},
#    'description': 'Word2vec Continuous Skipgram vectors trained on full Russian National Corpus (about 250M words). The model contains 185K words.',
#    'preprocessing': 'The corpus was lemmatized and tagged with Universal PoS',
#    'read_more': ['https://www.academia.edu/24306935/WebVectors_a_Toolkit_for_Building_Web_Interfaces_for_Vector_Semantic_Models',
#     'http://rusvectores.org/en/',
#     'https://github.com/RaRe-Technologies/gensim-data/issues/3'],
#    'checksum': '9bdebdc8ae6d17d20839dd9b5af10bc4',
#    'file_name': 'word2vec-ruscorpora-300.gz',
#    'parts': 1},
#   'word2vec-google-news-300': {'num_records': 3000000,
#    'file_size': 1743563840,
#    'base_dataset': 'Google News (about 100 billion words)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-google-news-300/__init__.py',
#    'license': 'not found',
#    'parameters': {'dimension': 300},
#    'description': "Pre-trained vectors trained on a part of the Google News dataset (about 100 billion words). The model contains 300-dimensional vectors for 3 million words and phrases. The phrases were obtained using a simple data-driven approach described in 'Distributed Representations of Words and Phrases and their Compositionality' (https://code.google.com/archive/p/word2vec/).",
#    'read_more': ['https://code.google.com/archive/p/word2vec/',
#     'https://arxiv.org/abs/1301.3781',
#     'https://arxiv.org/abs/1310.4546',
#     'https://www.microsoft.com/en-us/research/publication/linguistic-regularities-in-continuous-space-word-representations/?from=http%3A%2F%2Fresearch.microsoft.com%2Fpubs%2F189726%2Frvecs.pdf'],
#    'checksum': 'a5e5354d40acb95f9ec66d5977d140ef',
#    'file_name': 'word2vec-google-news-300.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-50': {'num_records': 400000,
#    'file_size': 69182535,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-50/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 50},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-50.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'c289bc5d7f2f02c6dc9f2f9b67641813',
#    'file_name': 'glove-wiki-gigaword-50.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-100': {'num_records': 400000,
#    'file_size': 134300434,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-100/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 100},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-100.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '40ec481866001177b8cd4cb0df92924f',
#    'file_name': 'glove-wiki-gigaword-100.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-200': {'num_records': 400000,
#    'file_size': 264336934,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-200/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 200},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-200.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '59652db361b7a87ee73834a6c391dfc1',
#    'file_name': 'glove-wiki-gigaword-200.gz',
#    'parts': 1},
#   'glove-wiki-gigaword-300': {'num_records': 400000,
#    'file_size': 394362229,
#    'base_dataset': 'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-wiki-gigaword-300/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 300},
#    'description': 'Pre-trained vectors based on Wikipedia 2014 + Gigaword, 5.6B tokens, 400K vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-wiki-gigaword-300.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '29e9329ac2241937d55b852e8284e89b',
#    'file_name': 'glove-wiki-gigaword-300.gz',
#    'parts': 1},
#   'glove-twitter-25': {'num_records': 1193514,
#    'file_size': 109885004,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-25/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 25},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-25.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': '50db0211d7e7a2dcd362c6b774762793',
#    'file_name': 'glove-twitter-25.gz',
#    'parts': 1},
#   'glove-twitter-50': {'num_records': 1193514,
#    'file_size': 209216938,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-50/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 50},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/)',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-50.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'c168f18641f8c8a00fe30984c4799b2b',
#    'file_name': 'glove-twitter-50.gz',
#    'parts': 1},
#   'glove-twitter-100': {'num_records': 1193514,
#    'file_size': 405932991,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-100/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 100},
#    'description': 'Pre-trained vectors based on  2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/)',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-100.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'b04f7bed38756d64cf55b58ce7e97b15',
#    'file_name': 'glove-twitter-100.gz',
#    'parts': 1},
#   'glove-twitter-200': {'num_records': 1193514,
#    'file_size': 795373100,
#    'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#    'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-200/__init__.py',
#    'license': 'http://opendatacommons.org/licenses/pddl/',
#    'parameters': {'dimension': 200},
#    'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/).',
#    'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-200.txt`.',
#    'read_more': ['https://nlp.stanford.edu/projects/glove/',
#     'https://nlp.stanford.edu/pubs/glove.pdf'],
#    'checksum': 'e52e8392d1860b95d5308a525817d8f9',
#    'file_name': 'glove-twitter-200.gz',
#    'parts': 1},
#   '__testing_word2vec-matrix-synopsis': {'description': '[THIS IS ONLY FOR TESTING] Word vecrors of the movie matrix.',
#    'parameters': {'dimensions': 50},
#    'preprocessing': 'Converted to w2v using a preprocessed corpus. Converted to w2v format with `python3.5 -m gensim.models.word2vec -train <input_filename> -iter 50 -output <output_filename>`.',
#    'read_more': [],
#    'checksum': '534dcb8b56a360977a269b7bfc62d124',
#    'file_name': '__testing_word2vec-matrix-synopsis.gz',
#    'parts': 1}}}

# %%
model = api.load('glove-twitter-100')

# %%
model.most_similar(positive=["coder", "money"], negative=["brain"])
# Out:
# [('broker', 0.5820155739784241),
#  ('bonuses', 0.5424473881721497),
#  ('banker', 0.5385112762451172),
#  ('designer', 0.5197198390960693),
#  ('merchandising', 0.4964233338832855),
#  ('treet', 0.49220189452171326),
#  ('shopper', 0.4920561909675598),
#  ('part-time', 0.4912828207015991),
#  ('freelance', 0.4843311905860901),
#  ('aupair', 0.4796452522277832)]

# %% [markdown]
# ### Visualizing word vectors
#
# One way to see if our vectors are good is to plot them. Those vectors are in 30D+ space, but we humans are used to 2D or 3D.
#
# Luckily, we machine learners know about __dimensionality reduction__ methods.
#
# Let's use that knowledge to plot 1000 most frequent words.

# %%
words = model.index_to_key[:1000]

print(words[::100])
# Out:
# ['<user>', '_', 'please', 'apa', 'justin', 'text', 'hari', 'playing', 'once', 'sei']

# %%
# for each word, compute it's vector with model
word_vectors = np.array([model.get_vector(x) for x in words])# YOUR CODE
word_vectors
# Out:
# array([[ 0.63006 ,  0.65177 ,  0.25545 , ...,  0.55096 ,  0.64706 ,
#         -0.6093  ],
#        [ 0.18205 , -0.048483,  0.23966 , ..., -0.3358  ,  0.18884 ,
#         -0.40786 ],
#        [ 1.0674  ,  0.45716 ,  0.51463 , ...,  0.13974 ,  0.76487 ,
#         -0.17314 ],
#        ...,
#        [ 0.11065 , -0.040876,  0.2586  , ..., -0.74773 ,  0.306   ,
#          0.37911 ],
#        [ 0.30491 , -0.89558 , -0.46538 , ...,  0.73649 ,  1.3842  ,
#          0.99976 ],
#        [-0.43051 ,  0.56302 ,  0.38305 , ..., -0.3222  ,  0.32782 ,
#          0.51519 ]], dtype=float32)

# %%
assert isinstance(word_vectors, np.ndarray)
assert word_vectors.shape == (len(words), 100)
assert np.isfinite(word_vectors).all()

# %% [markdown]
# #### Linear projection: PCA
#
# The simplest linear dimensionality reduction method is **P**rincipial **C**omponent **A**nalysis.
#
# In geometric terms, PCA tries to find axes along which most of the variance occurs. The "natural" axes, if you wish.
#
# <img src="https://github.com/yandexdataschool/Practical_RL/raw/master/yet_another_week/_resource/pca_fish.png" style="width:30%">

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/log/Documents/cs539/RIT_LLM/.venv/lib/python3.9/site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.decomposition import PCA

# map word vectors onto 2d plane with PCA. Use good old sklearn api (fit, transform)
# after that, normalize vectors to make sure they have zero mean and unit variance
word_vectors_pca =  PCA(2).fit_transform(word_vectors) # YOUR CODE
word_vectors_pca = (word_vectors_pca - word_vectors_pca.mean(axis=0)) / word_vectors_pca.std(axis=0)

# and maybe MORE OF YOUR CODE here :)

# %%
assert word_vectors_pca.shape == (len(word_vectors), 2), "there must be a 2d vector for each word"
assert max(abs(word_vectors_pca.mean(0))) < 1e-5, "points must be zero-centered"
assert max(abs(1.0 - word_vectors_pca.std(0))) < 1e-2, "points must have unit variance"

# %% [markdown]
# #### Let's draw it!

# %%
import bokeh.models as bm, bokeh.plotting as pl
from bokeh.io import output_notebook
output_notebook()

def draw_vectors(x, y, radius=10, alpha=0.25, color='blue',
                 width=600, height=400, show=True, **kwargs):
    """ draws an interactive plot for data points with auxilirary info on hover """
    if isinstance(color, str): color = [color] * len(x)
    data_source = bm.ColumnDataSource({ 'x' : x, 'y' : y, 'color': color, **kwargs })

    fig = pl.figure(active_scroll='wheel_zoom', width=width, height=height)
    fig.scatter('x', 'y', size=radius, color='color', alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show: pl.show(fig)
    return fig
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="db510ecb-afd5-47cf-b2d6-de9e7966ca4b">Loading BokehJS ...</span>
#     </div>

# %%
draw_vectors(word_vectors_pca[:, 0], word_vectors_pca[:, 1], token=words)

# hover a mouse over there and see if you can identify the clusters
# Out:
#   <div id="c2566803-f947-49f9-a5da-81849c7176ea" data-root-id="p1004" style="display: contents;"></div>
# figure(id='p1004', ...)

# %% [markdown]
# ### Visualizing neighbors with t-SNE
# PCA is nice but it's strictly linear and thus only able to capture coarse high-level structure of the data.
#
# If we instead want to focus on keeping neighboring points near, we could use TSNE, which is itself an embedding method. Here you can play __[with TSNE](https://projector.tensorflow.org/)__.

# %%
from sklearn.manifold import TSNE

# map word vectors onto 2d plane with TSNE. hint: don't panic it may take a minute or two to fit.
# normalize them as just lke with pca

word_tsne = TSNE().fit_transform(word_vectors) 
word_tsne = (word_tsne - word_tsne.mean(axis=0)) / word_tsne.std(axis=0)

# %%
draw_vectors(word_tsne[:, 0], word_tsne[:, 1], color='green', token=words)
# Out:
#   <div id="c49003c2-d901-48f6-9ba2-aedc0347603e" data-root-id="p1151" style="display: contents;"></div>
# figure(id='p1151', ...)

# %% [markdown]
# ### Visualizing phrases
#
# Word embeddings can also be used to represent short phrases. The simplest way is to take __an average__ of vectors for all tokens in the phrase with some weights.
#
# This trick is useful to identify what data are you working with: find if there are any outliers, clusters or other artefacts.
#
# Let's try this new hammer on our data!

# %%
def get_phrase_embedding(phrase):
    """
    Convert phrase to a vector by aggregating it's word embeddings. See description above.
    """
    # 1. lowercase phrase
    # 2. tokenize phrase
    # 3. average word vectors for all words in tokenized phrase
    # skip words that are not in model's vocabulary
    # if all words are missing from vocabulary, return zeros

    vector = np.zeros([model.vector_size], dtype='float32')

    words = tokenizer.tokenize(phrase.lower())
    words = [word for word in words if word in model.key_to_index]

    if len(words) > 0:
        vector = np.mean([model.get_vector(word) for word in words], axis=0)
    
    return vector

# %%
vector = get_phrase_embedding("I'm very sure. This never happened to me before...")

assert np.allclose(vector[::10],
                   np.array([ 0.31807372, -0.02558171,  0.0933293 , -0.1002182 , -1.0278689 ,
                             -0.16621883,  0.05083408,  0.17989802,  1.3701859 ,  0.08655966],
                              dtype=np.float32))
assert np.array_equal(get_phrase_embedding("thisisgibberish"), np.zeros([model.vector_size], dtype='float32')), "corner case for all missing words should be handled as described in the function comments"

# %%
# let's only consider ~5k phrases for a first run.
chosen_phrases = data[::len(data) // 1000]

# compute vectors for chosen phrases
phrase_vectors = np.array([get_phrase_embedding(text) for text in chosen_phrases])

# %%
assert isinstance(phrase_vectors, np.ndarray) and np.isfinite(phrase_vectors).all()
assert phrase_vectors.shape == (len(chosen_phrases), model.vector_size)

# %%
# map vectors into 2d space with pca, tsne or your other method of choice
# don't forget to normalize

phrase_vectors_pca = PCA(2).fit_transform(phrase_vectors)
phrase_vectors_pca = (phrase_vectors_pca - phrase_vectors_pca.mean(axis=0)) / phrase_vectors_pca.std(axis=0)

# %% [markdown]
# Finally, let's build a simple "similar question" engine with phrase embeddings we've built.

# %%
# compute vector embedding for all lines in data
data_vectors = np.array([get_phrase_embedding(text) for text in data])

# %%
def find_nearest(query, k=10):
    """
    given text line (query), return k most similar lines from data, sorted from most to least similar
    similarity should be measured as cosine between query and line embedding vectors
    hint: it's okay to use global variables: data and data_vectors. see also: np.argpartition, np.argsort
    """
    query_vector = get_phrase_embedding(query)
    cosines = np.dot(data_vectors, query_vector) / (np.linalg.norm(data_vectors, axis=1) * np.linalg.norm(query_vector))
    most_similar = np.argsort(cosines)[::-1]

    return [data[i] for i in most_similar[2:k+2]]

# %%
results = find_nearest(query="How do i enter the matrix?", k=10)

print(''.join(results))

assert len(results) == 10 and isinstance(results[0], str)
assert results[0] == 'How do I get to the dark web?\n'
assert results[3] == 'What can I do to save the world?\n'
# Out:
# How do I get to the dark web?
# What should I do to enter hollywood?
# How do I use the Greenify app?
# What can I do to save the world?
# How do I win this?
# How do I think out of the box? How do I learn to think out of the box?
# How do I find the 5th dimension?
# How do I use the pad in MMA?
# How do I estimate the competition?
# What do I do to enter the line of event management?
# /var/folders/d8/nv204w292cjdg6mkpdjgpm2c0000gn/T/ipykernel_49891/2336934886.py:8: RuntimeWarning: invalid value encountered in divide
#   cosines = np.dot(data_vectors, query_vector) / (np.linalg.norm(data_vectors, axis=1) * np.linalg.norm(query_vector))

# %%
find_nearest(query="How does Trump?", k=10)
# Out:
# /var/folders/d8/nv204w292cjdg6mkpdjgpm2c0000gn/T/ipykernel_49891/2336934886.py:8: RuntimeWarning: invalid value encountered in divide
#   cosines = np.dot(data_vectors, query_vector) / (np.linalg.norm(data_vectors, axis=1) * np.linalg.norm(query_vector))
# ['What does Donald Trump think about Israel?\n',
#  'What books does Donald Trump like?\n',
#  'What does Donald Trump think of India?\n',
#  'What does India think of Donald Trump?\n',
#  'What does Donald Trump think of China?\n',
#  'What does Donald Trump think about Pakistan?\n',
#  'What companies does Donald Trump own?\n',
#  'What does Dushka Zapata think about Donald Trump?\n',
#  'How does it feel to date Ivanka Trump?\n',
#  'What does salesforce mean?\n']

# %%
find_nearest(query="Why don't i ask a question myself?", k=10)
# Out:
# /var/folders/d8/nv204w292cjdg6mkpdjgpm2c0000gn/T/ipykernel_49891/2336934886.py:8: RuntimeWarning: invalid value encountered in divide
#   cosines = np.dot(data_vectors, query_vector) / (np.linalg.norm(data_vectors, axis=1) * np.linalg.norm(query_vector))
# ["Why don't I get a date?\n",
#  "Why do you always answer a question with a question? I don't, or do I?\n",
#  "Why can't I ask a question anonymously?\n",
#  "Why don't I get a girlfriend?\n",
#  "Why don't I have a boyfriend?\n",
#  "I don't have no question?\n",
#  "Why can't I take a joke?\n",
#  "Why don't I ever get a girl?\n",
#  "Can I ask a girl out that I don't know?\n",
#  "Why don't I have a girlfriend?\n"]

# %% [markdown]
# __Now what?__
# * Try running TSNE on all data, not just 1000 phrases
# * See what other embeddings are there in the model zoo: `gensim.downloader.info()`
# * Take a look at [FastText](https://github.com/facebookresearch/fastText) embeddings
# * Optimize `find_nearest` with locality-sensitive hashing: use [nearpy](https://github.com/pixelogik/NearPy) or `sklearn.neighbors`.
