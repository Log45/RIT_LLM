# %% [markdown]
# # HW 7 (10 pt)
# ### Parameter Efficient Fine-Tuning
# In this notebook, you're gonna fine-tune large language models within limited GPU memory.

# %%
# !pip install torch --index-url https://download.pytorch.org/whl/cu126
# !pip install --quiet --upgrade transformers bitsandbytes accelerate sentencepiece optimum auto-gptq

import torch
import torch.nn as nn
import torch.nn.functional as F
import transformers
from transformers import BitsAndBytesConfig
from tqdm.auto import tqdm, trange
assert torch.cuda.is_available(), "you need cuda for this part"

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') # use 'cuda' for any GPU
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (2.5.1)
# Requirement already satisfied: filelock in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /users/u30/log/.local/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages (from jinja2->torch) (2.1.3)

# %%
model_name = 'Enoch/llama-7b-hf'

# loading Llama tokenizer ...
tokenizer = transformers.LlamaTokenizer.from_pretrained(model_name, device_map=device)
tokenizer.pad_token_id = tokenizer.eos_token_id

# ... and the model itself
quantization_config = BitsAndBytesConfig(load_in_4bit=True)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name, device_map=device, low_cpu_mem_usage=True, offload_state_dict=True, # use device_map='auto' for multipl GPUs
    quantization_config=quantization_config, torch_dtype=torch.float32,  # weights are 4-bit; layernorms and activations are fp32
)
for param in model.parameters():
    param.requires_grad=False

model.gradient_checkpointing_enable()  # only store a small subset of activations, re-compute the rest.
model.enable_input_require_grads()     # override an implementation quirk in gradient checkpoints that disables backprop unless inputs require grad
# more on gradient checkpointing: https://pytorch.org/docs/stable/checkpoint.html https://arxiv.org/abs/1604.06174
# Out:
# Loading checkpoint shards:   0%|          | 0/33 [00:00<?, ?it/s]

# %% [markdown]
# ### Prompt tuning: the story of a fox (2 pts)
#
# ![img](https://i.imgur.com/Ux3qQAu.png) (source: theodd1souts.fandom.com)

# %%
prompt = 'A quick brown fox'
batch = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False).to(device)

for i in range(10):
    next_token = model(**batch).logits[0, -1].argmax(-1).reshape(1, 1)
    batch['input_ids'] = torch.cat([batch['input_ids'], next_token], dim=-1)
    batch['attention_mask'] = torch.cat([batch['attention_mask'], torch.ones_like(next_token)], dim=-1)

print("\nOutput:", tokenizer.decode(batch['input_ids'][0].cpu().numpy().tolist()))
# Out:
# Output: <s>A quick brown fox jumps over the lazy dog.
# A quick

# %% [markdown]
# What a blatant lie! This particular fox assures you that it did not, in fact, jump over the lazy dog. No, sir! The fox was merely minding its own business. __Your task is to train the model to tell the truth: no dog was jumped over today.__

# %%
# Your task is to train the model to tell the truth: no dog was jumped over today
the_truth = "A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"
batch = tokenizer(the_truth, return_tensors='pt', return_token_type_ids=False).to(device)
outputs = model(**batch)

next_word_logits = outputs.logits[:, :-1]
true_next_tokens = batch['input_ids'][:, 1:]
loss = F.cross_entropy(next_word_logits.flatten(0, 1), true_next_tokens.flatten(0, 1))

print("Loss:", loss)
# Out:
# Loss: tensor(3.0729, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
prompt = 'A quick brown fox'
batch = tokenizer(prompt, return_tensors='pt', return_token_type_ids=False).to(device)

for i in range(10):
    next_token = model(**batch).logits[0, -1].argmax(-1).reshape(1, 1)
    batch['input_ids'] = torch.cat([batch['input_ids'], next_token], dim=-1)
    batch['attention_mask'] = torch.cat([batch['attention_mask'], torch.ones_like(next_token)], dim=-1)

print("\nOutput:", tokenizer.decode(batch['input_ids'][0].cpu().numpy().tolist()))
# Out:
# Output: <s>A quick brown fox jumps over the lazy dog.
# A quick

# %% [markdown]
# Except, we can't train the entire model - that would be 28GB gradients in float32. Instead, let's run [prompt tuning](https://arxiv.org/abs/2104.08691).
#
# ![img](https://i.imgur.com/VwNNKnb.png)

# %% [markdown]
# ### Using HuggingFace PEFT (5 points)
#
# [`peft`](https://huggingface.co/docs/peft/index) is a transformer's sister library that allows you to apply various **p**arameter **e**fficient **f**ine-**t**uning methods to pre-trained transformers. The library imlements both prompt tuning, prefix tuning, as well as several adapter-based techniques under a common interface:

# %%
import peft
assert isinstance(model.model.embed_tokens, nn.Embedding), "please reload the model"

peft_config = peft.PromptTuningConfig(task_type=peft.TaskType.CAUSAL_LM, num_virtual_tokens=16)
model = peft.get_peft_model(model, peft_config)  # note: for most peft methods, this line also modifies model in-place
print("Trainable parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))
print("Total parameters (excluding quantization):", sum(p.numel() for p in model.parameters()))
# Out:
# Trainable parameters: 65536
# Total parameters (excluding quantization): 3500478464

# %% [markdown]
# # Your task: optimize the PEFT-wrapped model to achieve next token prediction loss < 0.1, but this time using PEFT
# # Please note: you no longer need to prepend PAD tokens, but you still need to skip :num_virtual_tokens: first logits.
# # Finally, generate the sentence to make sure that the model learned the truth.

# %% [markdown]
# You may need to use the following parameters in optimizor:
# `Adam([param for name, param in model.named_parameters() if param.requires_grad], lr=0.01)`
#
# For multiple GPU usage you can use `model = torch.nn.DataParallel(model)`

# %%
"""# Your task: optimize the PEFT-wrapped model to achieve next token prediction loss < 0.1, but this time using PEFT
# Please note: you no longer need to prepend PAD tokens, but you still need to skip :num_virtual_tokens: first logits.
# Finally, generate the sentence to make sure that the model learned the truth."""

from datasets import Dataset
# Define prompt and completion
texts = ["A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"]

# Tokenizing the data
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=30)

# Create a dataset
dataset = Dataset.from_dict({"text": texts})
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Drop the original text column (optional)
tokenized_dataset = tokenized_dataset.remove_columns(["text"])
tokenized_dataset
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 1
# })

# %%
model._hf_peft_config_loaded = True  # silence a warning from HF trainer for hand-made LoRA


trainer = transformers.Trainer(
    model=model, train_dataset=tokenized_dataset,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=4, gradient_accumulation_steps=16,
        # note: if you want larger batch size, increase gradient_accumulation_steps
        warmup_steps=250, max_steps=500, learning_rate=0.01, fp16=True,
        logging_steps=10, output_dir='outputs', report_to="none"), # Unse repotr_to=None for Wandb
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
# if you see cache warnings, set `model.config.use_cache = False` to silence them. Please re-enable for inference!

trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 03:30, Epoch 500/500]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.264700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.263900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.250200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.234200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.213000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.176600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.197600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.139200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.139300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.099800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.056500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.035600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.025300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.018900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.014400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.011300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.007600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.006600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.005600</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.003300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.001900</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.001100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=500, training_loss=0.044513393614441156, metrics={'train_runtime': 210.6167, 'train_samples_per_second': 151.935, 'train_steps_per_second': 2.374, 'total_flos': 594660925440000.0, 'train_loss': 0.044513393614441156, 'epoch': 500.0})

# %% [markdown]
# ## It took multiple different runs with different learning rates and max_step sizes, but it eventually got to loss < 0.1 during the last run. Even before hitting the target loss, it properly generated the expected output.

# %%
# **Generate Output to Verify Learning**
model.eval()
test_prompt = 'A quick brown fox'
test_inputs = tokenizer(test_prompt, return_tensors="pt").to(device)

with torch.no_grad():
    output_tokens = model.generate(**test_inputs, max_length=23)

print("📝 Generated:", tokenizer.decode(output_tokens[0], skip_special_tokens=True))
# Out:
# 📝 Generated: A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!

# %%
# Out:
# ['A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway! Besides that dog deserved it']

# %% [markdown]
# ### Parameter-efficient finetuning with LoRA (5 points)
#
# When training on more serious tasks, you can use low-rank adapters based on the [LoRA paper](https://arxiv.org/pdf/2106.09685.pdf).
#
# The core idea is to add low-rank adapters __in parallel with existing linear layers,__ like this:
# <center><img src="https://i.imgur.com/6bQLNiG.png" width=240px></center>
#
# In the original LoRA paper, the adapters were only added to attention projection matrices. However, [subsequent works](https://arxiv.org/abs/2305.14314) show that it is useful to adapt FFNs as well. But before we do any training, we need to implement the basic LoRA layer.

# %%
# re-load the model to remove any previous PEFT tuners
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_name, device_map=device, low_cpu_mem_usage=True, offload_state_dict=True,
    load_in_4bit=True, torch_dtype=torch.float32,  # weights are 4-bit; layernorms and activations are fp32
)
for param in model.parameters():
    param.requires_grad=False
model.gradient_checkpointing_enable()
model.enable_input_require_grads()
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/33 [00:00<?, ?it/s]

# %%
class LoRALayer(nn.Module):
    """Wraps a linear layer with LoRA-like adapter. Wraps an existing OPT linear layer"""
    def __init__(self, module: nn.Linear, rank: int):
        super().__init__()
        self.module = module  # pre-trained (frozen) linear layer
        self.adapter_A = nn.Parameter(torch.empty(module.in_features, rank, device=module.weight.device))
        nn.init.kaiming_uniform_(self.adapter_A, a=5 ** 0.5)
        self.adapter_B = nn.Parameter(torch.zeros(rank, module.out_features, device=module.weight.device))

    def forward(self, input):
        # Apply self.module and LoRA adapter, return the sum (self.module outputs + adapter outputs)
        adapter_output = input @ self.adapter_A @ self.adapter_B  # Shape (batch, seq_len, output_dim)
        return self.module(input) + adapter_output

# %%
# test your implementation
test_linear = nn.Linear(128, 128)
test_linear.weight.data[...] = torch.eye(128)
test_adapter = LoRALayer(test_linear, rank=8)

assert torch.allclose(test_adapter(torch.ones(1, 1, 128)), test_linear.bias + 1), "please check your forward pass"

test_adapter.adapter_A.data[...] = torch.linspace(0.1, -0.5, 128 * 8).view(128, 8)
test_adapter.adapter_B.data[...] = torch.linspace(0.5, -0.1, 128 * 8).view(8, 128)
test_linear.bias.data[...] = torch.linspace(1., -1., 128)

dummy_loss = F.mse_loss(test_adapter(torch.ones(1, 128) / 128).squeeze(), torch.linspace(-1, 1, 128))
assert torch.allclose(dummy_loss, torch.tensor(1.3711389), rtol=0, atol=1e-4)
dummy_loss.backward()
assert all(w.grad is not None for w in [test_adapter.adapter_A, test_adapter.adapter_B]), "some adapter weights have no grad"
assert torch.allclose(test_adapter.adapter_A.grad.sum(), torch.tensor(-0.60158), rtol=0, atol=1e-4), "bad grad w.r.t. A"
assert torch.allclose(test_adapter.adapter_B.grad.sum(), torch.tensor(0.9931), rtol=0, atol=1e-4), "bad grad w.r.t. B"
# note: bad grad means that your code is different from LoRA paper OR that your code is not autograd-friendly (e.g. no_grad)
del dummy_loss, test_linear, test_adapter
print("All tests passed!")
# Out:
# All tests passed!

# %% [markdown]
# ### Apply LoRA to the model
#
# The code below applies LoRA adapters on top of Q/K/V linear layers in Llama attention. You may also choose to modify other layers:
# * self_attn.o_proj - attention output projection
# * mlp.up_proj, mlp.gate_proj, mlp.down_proj - transformer feedforward layers
# * lm_head - output LM head
#
# __Note:__ please scroll down for the homework task

# %%
lora_rank = 8

for name, module in model.model.layers.named_modules():
    if 'LlamaDecoderLayer' in repr(type(module)):
        module.self_attn.q_proj = LoRALayer(module.self_attn.q_proj, rank=lora_rank).to(device)
        module.self_attn.k_proj = LoRALayer(module.self_attn.k_proj, rank=lora_rank).to(device)
        module.self_attn.v_proj = LoRALayer(module.self_attn.v_proj, rank=lora_rank).to(device)

assert sum(isinstance(module, LoRALayer) for module in model.modules()) == 96  # for Llama-7B

# %%
batch = tokenizer("This model wants to share its greatest secret:", return_tensors='pt', return_token_type_ids=False).to(device)
# test a single training step, make sure we get meaningful gradients
with torch.amp.autocast(device_type = 'cuda', dtype=torch.float32):
    out = model.forward(**batch)
    (out.logits.norm() / 100).backward()

for i, module in enumerate(model.modules()):
    if isinstance(module, LoRALayer):
        assert module.adapter_B.grad is not None
        assert module.adapter_B.grad.norm().item() > 0

model.zero_grad(set_to_none=True)
print("Grad check successful, well done!")
# Out:
# Grad check successful, well done!

# %% [markdown]
# ### (example) How to train your model
#
# The example below shows how to train the LoRA adapters on a dummy dataset. You will need to run a _similar_ training task later.
#
# __Note:__ please scroll down for the homework task

# %%
from datasets import Dataset
# Define prompt and completion
texts = ["A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!"]

# Tokenizing the data
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=30)

# Create a dataset
dataset = Dataset.from_dict({"text": texts})
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Drop the original text column (optional)
tokenized_dataset = tokenized_dataset.remove_columns(["text"])
tokenized_dataset
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 1
# })

# %%
model._hf_peft_config_loaded = True  # silence a warning from HF trainer for hand-made LoRA


trainer = transformers.Trainer(
    model=model, train_dataset=tokenized_dataset,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1, gradient_accumulation_steps=4,
        # note: if you want larger batch size, increase gradient_accumulation_steps
        warmup_steps=250, max_steps=50, learning_rate=2e-4, fp16=True,
        logging_steps=1, output_dir='outputs', report_to="none"), # Unse repotr_to=None for Wandb
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
# if you see cache warnings, set `model.config.use_cache = False` to silence them. Please re-enable for inference!

trainer.train()

# NOTE: this is just an example! you do not have to wait for this progressbar to finish :)
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#     <div>
#
#       <progress value='51' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 00:21, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.938900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.938900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.938900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.938900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.928400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.917000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.891100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.852300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.804500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.760700</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.710800</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.653100</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.595700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.534600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.457700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.360300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.258900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.174900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.119800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.064200</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.004700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.939200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.870500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.800800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.729500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.657500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.586300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.513500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.442000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.369200</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.296900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.222600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.148300</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.071000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.990900</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.905600</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.834400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.772200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.617500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.519400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.447400</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.378200</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.307400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.257600</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.233700</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.220800</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.209100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.195400</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[21], line 15
#       4 trainer = transformers.Trainer(
#       5     model=model, train_dataset=tokenized_dataset,
#       6     args=transformers.TrainingArguments(
#    (...)
#      11     data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
#      12 )
#      13 # if you see cache warnings, set `model.config.use_cache = False` to silence them. Please re-enable for inference!
# ---> 15 trainer.train()
#      17 # NOTE: this is just an example! you do not have to wait for this progressbar to finish :)
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:2620, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2618     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    2619     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 2620     self._maybe_log_save_evaluate(
#    2621         tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time
#    2622     )
#    2623 else:
#    2624     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:3100, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    3097         self.control.should_save = is_new_best_metric
#    3099 if self.control.should_save:
# -> 3100     self._save_checkpoint(model, trial)
#    3101     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:3197, in Trainer._save_checkpoint(self, model, trial)
#    3195 run_dir = self._get_output_dir(trial=trial)
#    3196 output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 3197 self.save_model(output_dir, _internal_call=True)
#    3199 if self.args.save_strategy in [SaveStrategy.STEPS, SaveStrategy.EPOCH] and self.state.best_global_step:
#    3200     best_checkpoint_folder = f"{PREFIX_CHECKPOINT_DIR}-{self.state.best_global_step}"
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:3884, in Trainer.save_model(self, output_dir, _internal_call)
#    3881         self.model_wrapped.save_checkpoint(output_dir)
#    3883 elif self.args.should_save:
# -> 3884     self._save(output_dir)
#    3886 # Push to the Hub when `save_model` is called by the user.
#    3887 if self.args.push_to_hub and not _internal_call:
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/trainer.py:3988, in Trainer._save(self, output_dir, state_dict)
#    3986             torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    3987 else:
# -> 3988     self.model.save_pretrained(
#    3989         output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    3990     )
#    3992 if self.processing_class is not None:
#    3993     self.processing_class.save_pretrained(output_dir)
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/modeling_utils.py:3371, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    3367 if _hf_peft_config_loaded:
#    3368     logger.info(
#    3369         "Detected adapters on the model, saving the model in the PEFT format, only adapter weights will be saved."
#    3370     )
# -> 3371     state_dict = model_to_save.get_adapter_state_dict(state_dict=state_dict)
#    3373     if save_peft_format:
#    3374         logger.info(
#    3375             "To match the expected format of the PEFT library, all keys of the state dict of adapters will be pre-pended with `base_model.model`."
#    3376         )
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/integrations/peft.py:473, in PeftAdapterMixin.get_adapter_state_dict(self, adapter_name, state_dict)
#     470 from peft import get_peft_model_state_dict
#     472 if adapter_name is None:
# --> 473     adapter_name = self.active_adapters()[0]
#     475 adapter_state_dict = get_peft_model_state_dict(self, state_dict=state_dict, adapter_name=adapter_name)
#     476 return adapter_state_dict
#
# File /scratch/log/anaconda3/envs/fuck/lib/python3.9/site-packages/transformers/integrations/peft.py:437, in PeftAdapterMixin.active_adapters(self)
#     434         break
#     436 # For previous PEFT versions
# --> 437 if isinstance(active_adapters, str):
#     438     active_adapters = [active_adapters]
#     440 return active_adapters
#
# UnboundLocalError: local variable 'active_adapters' referenced before assignment

# %% [markdown]
# You'll gett an error after training, but you still can do inference with this model:

# %%
model = trainer.model
model.eval()
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): LoRALayer(
#             (module): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           )
#           (k_proj): LoRALayer(
#             (module): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           )
#           (v_proj): LoRALayer(
#             (module): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           )
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-06)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-06)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-06)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
inputs = tokenizer(['A quick brown fox'],
    return_tensors="pt",
)
model.to(device)

with torch.no_grad():
    inputs = {k: v.to(device) for k, v in inputs.items()}
    outputs = model.generate(
        input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"], max_new_tokens=23, eos_token_id=3
    )
    print(tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True))
# Out:
# ['A quick brown fox did not jump over the lazy dog. Besides, that dog deserved it anyway!\nThe quick brown fox']
